# %%
import pandas as pd

# %%
# Column Names (['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link'],  dtype='object')
fullDataset = pd.read_csv("C:\\Repos\\MastersProject\\server\\Data\\amazon.csv", delimiter=",")

# %%
# ignore the columns that are not needed
products_dataset = fullDataset [
    [
        "product_id",
        "product_name",
        "category",
        "actual_price",
        "img_link",
        "product_link",
        "about_product",
        "rating",
        "rating_count"   
    ]
]
        
products_dataset.rename(columns={
    "actual_price": 'price',
    "about_product":'product_description',
    "rating_count":'no_of_ratings'
},inplace=True)


#df['Salary'].str.replace(',', '').str.replace('₹', '').astype(int)
products_dataset['no_of_ratings'] = products_dataset['no_of_ratings'].str.replace('[,]','', regex=True).astype(int)        
products_dataset['rating'] = (products_dataset['rating'].astype(float)).round(1)
products_dataset['price'] = (products_dataset['price'].str.replace('[\₹\,]','', regex=True).astype(float) / 80).round(2)
products_dataset["category"] = products_dataset["category"].str.split("|") 

products_dataset.drop_duplicates(subset=['product_id'], inplace=True)

products_json_dataset = products_dataset.to_dict(orient='records')
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_18092\1145458480.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_dataset.rename(columns={
# C:\Users\srile\AppData\Local\Temp\ipykernel_18092\1145458480.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_dataset['no_of_ratings'] = products_dataset['no_of_ratings'].str.replace('[,]','', regex=True).astype(int)
# C:\Users\srile\AppData\Local\Temp\ipykernel_18092\1145458480.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_dataset['rating'] = (products_dataset['rating'].astype(float)).round(1)
# C:\Users\srile\AppData\Local\Temp\ipykernel_18092\1145458480.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_dataset['price'] = (products_dataset['price'].str.replace('[\₹\,]','', regex=True).astype(float) / 80).round(2)
# C:\Users\srile\AppData\Local\Temp\ipykernel_18092\1145458480.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_dataset["category"] = products_dataset["category"].str.split("|")
# C:\Users\srile\AppData\Local\Temp\ipykernel_18092\1145458480.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products_dataset.drop_duplicates(subset=['product_id'], inplace=True)

# %%
len(products_dataset)
# Out:
# 1351

# %%
products_dataset
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  price  \
# 0     [Computers&Accessories, Accessories&Peripheral...  13.74
# 1     [Computers&Accessories, Accessories&Peripheral...   4.36
# 2     [Computers&Accessories, Accessories&Peripheral...  23.74
# 3     [Computers&Accessories, Accessories&Peripheral...   8.74
# 4     [Computers&Accessories, Accessories&Peripheral...   4.99
# ...                                                 ...    ...
# 1460  [Home&Kitchen, Kitchen&HomeAppliances, WaterPu...  11.49
# 1461  [Home&Kitchen, Kitchen&HomeAppliances, SmallKi...  38.06
# 1462  [Home&Kitchen, Heating,Cooling&AirQuality, Roo...  38.50
# 1463  [Home&Kitchen, Heating,Cooling&AirQuality, Fan...  23.62
# 1464  [Home&Kitchen, Kitchen&HomeAppliances, SmallKi...  46.12
#
#                                                img_link  \
# 0     https://m.media-amazon.com/images/W/WEBP_40237...
# 1     https://m.media-amazon.com/images/W/WEBP_40237...
# 2     https://m.media-amazon.com/images/W/WEBP_40237...
# 3     https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4     https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                 ...
# 1460  https://m.media-amazon.com/images/I/41fDdRtjfx...
# 1461  https://m.media-amazon.com/images/I/41gzDxk4+k...
# 1462  https://m.media-amazon.com/images/W/WEBP_40237...
# 1463  https://m.media-amazon.com/images/W/WEBP_40237...
# 1464  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link  \
# 0     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1     https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2     https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3     https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4     https://www.amazon.in/Portronics-Konnect-POR-1...
# ...                                                 ...
# 1460  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# 1461  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# 1462  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# 1463  https://www.amazon.in/Havells-Ventilair-230mm-...
# 1464  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
#                                     product_description  rating  no_of_ratings
# 0     High Compatibility : Compatible With iPhone 12...     4.2          24269
# 1     Compatible with all Type C enabled devices, be...     4.0          43994
# 2     【 Fast Charger& Data Sync】-With built-in safet...     3.9           7928
# 3     The boAt Deuce USB 300 2 in 1 cable is compati...     4.2          94363
# 4     [CHARGE & SYNC FUNCTION]- This cable comes wit...     4.2          16905
# ...                                                 ...     ...            ...
# 1460  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...     4.0           1090
# 1461                       230 Volts, 400 watts, 1 Year     4.1           4118
# 1462  International design and styling|Two heat sett...     3.6            468
# 1463  Fan sweep area: 230 MM ; Noise level: (40 - 45...     4.0           8031
# 1464  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...     4.3           6987
#
# [1351 rows x 9 columns]

# %%
type(products_dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
products_dataset = products_dataset.dropna()
        
popular_products = products_dataset[
            [
                'product_id',
                'no_of_ratings'
            ]
        ]
