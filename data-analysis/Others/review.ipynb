# %%
import pandas as pd

# %%
# Column Names (['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link'],  dtype='object')
fullDataset = pd.read_csv("C:\\Repos\\MastersProject\\server\\Data\\amazon.csv", delimiter=",")

# %%
review_dataset = fullDataset[
    [
        "review_id",
        "review_title",
        "review_content",
        "user_id",
        "product_id"
    ]
]
                
review_dataset["product_id"] = fullDataset["product_id"]
review_dataset["user_id"] = fullDataset["user_id"].str.split(",")
review_dataset["review_id"] = fullDataset["review_id"].str.split(",")
review_dataset["review_title"] = fullDataset["review_title"].str.split(",")
review_dataset["review_content"] = fullDataset["review_content"].str.split(",")
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_18852\1403176928.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_dataset["product_id"] = fullDataset["product_id"]
# C:\Users\srile\AppData\Local\Temp\ipykernel_18852\1403176928.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_dataset["user_id"] = fullDataset["user_id"].str.split(",")
# C:\Users\srile\AppData\Local\Temp\ipykernel_18852\1403176928.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_dataset["review_id"] = fullDataset["review_id"].str.split(",")
# C:\Users\srile\AppData\Local\Temp\ipykernel_18852\1403176928.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_dataset["review_title"] = fullDataset["review_title"].str.split(",")
# C:\Users\srile\AppData\Local\Temp\ipykernel_18852\1403176928.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_dataset["review_content"] = fullDataset["review_content"].str.split(",")

# %%
len(review_dataset)
# Out:
# 1465

# %%
review_dataset
# Out:
#                                               review_id  \
# 0     [R3HXWT0LRP0NMF, R2AJM3LFTLZHFO, R6AQJGUP6P86,...
# 1     [RGIQEG07R9HS2, R1SMWZQ86XIN8U, R2J3Y1WL29GWDE...
# 2     [R3J3EQQ9TZI5ZJ, R3E7WBGK7ID0KV, RWU79XKQ6I1QF...
# 3     [R3EEUZKKK9J36I, R3HJVYCLYOY554, REDECAZ7AMPQC...
# 4     [R1BP4L2HH9TFUP, R16PVJEXKV6QZS, R2UPDB81N66T4...
# ...                                                 ...
# 1460  [R3G3XFHPBFF0E8, R3C0BZCD32EIGW, R2EBVBCN9QPD9...
# 1461  [R3DDL2UPKQ2CK9, R2SYYU1OATVIU5, R1VM993161IYR...
# 1462  [R1TLRJVW4STY5I, R2O455KRN493R1, R3Q5MVGBRIAS2...
# 1463  [R39Q2Y79MM9SWK, R3079BG1NIH6MB, R29A31ZELTZNJ...
# 1464  [R20RBRZ0WEUJT9, ROKIFK9R2ISSE, R30EEG2FNJSN5I...
#
#                                            review_title  \
# 0     [Satisfied, Charging is really fast, Value for...
# 1     [A Good Braided Cable for Your Type C Device, ...
# 2     [Good speed for earlier versions, Good Product...
# 3     [Good product, Good one, Nice, Really nice pro...
# 4     [As good as original, Decent, Good one for sec...
# ...                                                 ...
# 1460  [Received the product without spanner, Excelle...
# 1461  [ok, everything was good couldn't return bcoz ...
# 1462  [very good, Work but front melt after 2 month,...
# 1463  [Fan Speed is slow, Good quality, Good product...
# 1464  [Works perfect, Ok good product, Nice Product....
#
#                                          review_content  \
# 0     [Looks durable Charging is fine tooNo complain...
# 1     [I ordered this cable to connect my phone to A...
# 2     [Not quite durable and sturdy, https://m.media...
# 3     [Good product, long wire, Charges good, Nice, ...
# 4     [Bought this instead of original apple,  does ...
# ...                                                 ...
# 1460  [I received product without spanner, Excellent...
# 1461  [ok, got everything as mentioned but the measu...
# 1462  [plastic but cool body , u have to find sturdy...
# 1463  [I have installed this in my kitchen working f...
# 1464  [It does it job perfectly..only issue is temp ...
#
#                                                 user_id  product_id
# 0     [AG3D6O4STAQKAY2UVGEUV46KN35Q, AHMY5CWJMMK5BJR...  B07JW9H4J1
# 1     [AECPFYFQVRUWC3KGNLJIOREFP5LQ, AGYYVPDD7YG7FYN...  B098NS6PVG
# 2     [AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA, AESFLDV2PT363T2...  B096MSW6CT
# 3     [AEWAZDZZJLQUYVOVGBEUKSLXHQ5A, AG5HTSFRRE6NL3M...  B08HDJ86NZ
# 4     [AE3Q6KSUK5P75D5HFYHCRAOLODSA, AFUGIFH5ZAFXRDS...  B08CF3B7N1
# ...                                                 ...         ...
# 1460  [AHITFY6AHALOFOHOZEOC6XBP4FEA, AFRABBODZJZQB6Z...  B08L7J3T31
# 1461  [AFG5FM3NEMOL6BNFRV2NK5FNJCHQ, AGEINTRN6Z563RM...  B01M6453MB
# 1462  [AGVPWCMAHYQWJOQKMUJN4DW3KM5Q, AF4Q3E66MY4SR7Y...  B009P2LIL4
# 1463  [AF2JQCLSCY3QJATWUNNHUSVUPNQQ, AFDMLUXC5LS5RXD...  B00J5DYCCA
# 1464  [AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA, AG7QNJ2SCS5VS5V...  B01486F4G6
#
# [1465 rows x 5 columns]

# %%
review_dataset.drop_duplicates(subset=['product_id'], inplace=True)
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_18852\61974645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_dataset.drop_duplicates(subset=['product_id'], inplace=True)

# %%
len(review_dataset)
# Out:
# 1351

# %%
temp_review_df = pd.DataFrame(columns = ['product_id','user_id','review_id','review_title','review_content'])

for index, row in review_dataset.iterrows():
    limit = len(row['user_id'])
    pid = row['product_id']
    #print(limit)
    for index in range(limit):
        temp_review_df.loc[len(temp_review_df)]=[pid,row['user_id'][index],row['review_id'][index],row['review_title'][index],row['review_content'][index]]
        
temp_review_json_dataset = temp_review_df.to_dict(orient='records')

#Print
temp_review_json_dataset
# Out:
# [{'product_id': 'B07JW9H4J1',
#   'user_id': 'AG3D6O4STAQKAY2UVGEUV46KN35Q',
#   'review_id': 'R3HXWT0LRP0NMF',
#   'review_title': 'Satisfied',
#   'review_content': 'Looks durable Charging is fine tooNo complains'},
#  {'product_id': 'B07JW9H4J1',
#   'user_id': 'AHMY5CWJMMK5BJRBBSNLYT3ONILA',
#   'review_id': 'R2AJM3LFTLZHFO',
#   'review_title': 'Charging is really fast',
#   'review_content': 'Charging is really fast'},
#  {'product_id': 'B07JW9H4J1',
#   'user_id': 'AHCTC6ULH4XB6YHDY6PCH2R772LQ',
#   'review_id': 'R6AQJGUP6P86',
#   'review_title': 'Value for money',
#   'review_content': ' good product.'},
#  {'product_id': 'B07JW9H4J1',
#   'user_id': 'AGYHHIERNXKA6P5T7CZLXKVPT7IQ',
#   'review_id': 'R1KD19VHEDV0OR',
#   'review_title': 'Product review',
#   'review_content': 'Till now satisfied with the quality.'},
#  {'product_id': 'B07JW9H4J1',
#   'user_id': 'AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q',
#   'review_id': 'R3C02RMYQMK6FC',
#   'review_title': 'Good quality',
#   'review_content': 'This is a good product . The charging speed is slower than the original iPhone cable'},
#  {'product_id': 'B07JW9H4J1',
#   'user_id': 'AENGU523SXMOS7JPDTW52PNNVWGQ',
#   'review_id': 'R39GQRVBUZBWGY',
#   'review_title': 'Good product',
#   'review_content': 'Good quality'},
#  {'product_id': 'B07JW9H4J1',
#   'user_id': 'AEQJHCVTNINBS4FKTBGQRQTGTE5Q',
#   'review_id': 'R2K9EDOE15QIRJ',
#   'review_title': 'Good Product',
#   'review_content': ' would recommend'},
#  {'product_id': 'B07JW9H4J1',
#   'user_id': 'AFC3FFC5PKFF5PMA52S3VCHOZ5FQ',
#   'review_id': 'R3OI7YT648TL8I',
#   'review_title': 'As of now seems good',
#   'review_content': 'https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/81---F1ZgHL._SY88.jpg'},
#  {'product_id': 'B098NS6PVG',
#   'user_id': 'AECPFYFQVRUWC3KGNLJIOREFP5LQ',
#   'review_id': 'RGIQEG07R9HS2',
#   'review_title': 'A Good Braided Cable for Your Type C Device',
#   'review_content': "I ordered this cable to connect my phone to Android Auto of car. The cable is really strong and the connection ports are really well made. I already has a Micro USB cable from Ambrane and it's still in good shape. I connected my phone to the car using the cable and it got connected well and no issues. I also connected it to the charging port and yes it has Fast Charging support."},
#  {'product_id': 'B098NS6PVG',
#   'user_id': 'AGYYVPDD7YG7FYNBXNGXZJT525AQ',
#   'review_id': 'R1SMWZQ86XIN8U',
#   'review_title': 'Good quality product from ambrane',
#   'review_content': "It quality is good at this price and the main thing is that i didn't ever thought that this cable will be so long it's good one and charging power is too good and also supports fast charging"},
#  {'product_id': 'B098NS6PVG',
#   'user_id': 'AHONIZU3ICIEHQIGQ6R2VFRSBXOQ',
#   'review_id': 'R2J3Y1WL29GWDE',
#   'review_title': 'Super cable',
#   'review_content': 'Value for money'},
#  {'product_id': 'B098NS6PVG',
#   'user_id': 'AFPHD2CRPDZMWMBL7WXRSVYWS5JA',
#   'review_id': 'RYGGS0M09S3KY',
#   'review_title': 'As',
#   'review_content': ' with extra length👍'},
#  {'product_id': 'B098NS6PVG',
#   'user_id': 'AEZ346GX3HJ4O4XNRPHCNHXQURMQ',
#   'review_id': 'R17KQRUTAN5DKS',
#   'review_title': 'Good quality',
#   'review_content': 'Good'},
#  {'product_id': 'B098NS6PVG',
#   'user_id': 'AEPSWFPNECKO34PUC7I56ITGXR6Q',
#   'review_id': 'R3AAQGS6HP2QUK',
#   'review_title': 'Good product',
#   'review_content': ' working fine'},
#  {'product_id': 'B098NS6PVG',
#   'user_id': 'AHWVEHR5DYLVFTO2KF3IZATFQSWQ',
#   'review_id': 'R1HDNOG6TO2CCA',
#   'review_title': 'its good',
#   'review_content': 'Product quality is good'},
#  {'product_id': 'B098NS6PVG',
#   'user_id': 'AH4QT33M55677I7ISQOAKEQWACYQ',
#   'review_id': 'R3PHKXYA5AFEOU',
#   'review_title': 'Good quality for the price but one issue with my unit',
#   'review_content': 'Good'},
#  {'product_id': 'B096MSW6CT',
#   'user_id': 'AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA',
#   'review_id': 'R3J3EQQ9TZI5ZJ',
#   'review_title': 'Good speed for earlier versions',
#   'review_content': 'Not quite durable and sturdy'},
#  {'product_id': 'B096MSW6CT',
#   'user_id': 'AESFLDV2PT363T2AQLWQOWZ4N3OA',
#   'review_id': 'R3E7WBGK7ID0KV',
#   'review_title': 'Good Product',
#   'review_content': 'https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/71rIggrbUCL._SY88.jpg'},
#  {'product_id': 'B096MSW6CT',
#   'user_id': 'AHTPQRIMGUD4BYR5YIHBH3CCGEFQ',
#   'review_id': 'RWU79XKQ6I1QF',
#   'review_title': 'Working good',
#   'review_content': 'Working good'},
#  {'product_id': 'B096MSW6CT',
#   'user_id': 'AEUVWXYP5LT7PZLLZENEO2NODPBQ',
#   'review_id': 'R25X4TBMPY91LX',
#   'review_title': 'Good for the price',
#   'review_content': 'https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/61bKp9YO6wL._SY88.jpg'},
#  {'product_id': 'B096MSW6CT',
#   'user_id': 'AHC7MPW55DOO6WNCOQVA2VHOD26A',
#   'review_id': 'R27OK7G99VK0TR',
#   'review_title': 'Good',
#   'review_content': 'Product'},
#  {'product_id': 'B096MSW6CT',
#   'user_id': 'AFDI6FRPFBTNBG7BAEB7JDJSMKDQ',
#   'review_id': 'R207CYDCHJJTCJ',
#   'review_title': 'Worth for money',
#   'review_content': 'Very nice product'},
#  {'product_id': 'B096MSW6CT',
#   'user_id': 'AFQKCEEEKXCOHTDG4WUN3XPPHJQQ',
#   'review_id': 'R3PCU8XMU173BT',
#   'review_title': 'Working nice',
#   'review_content': 'Working well'},
#  {'product_id': 'B096MSW6CT',
#   'user_id': 'AHKUUFNMBZIDLSSPA4FEHIO2EC7Q',
#   'review_id': 'R1IMONDOWRNU5V',
#   'review_title': "it's a really nice product",
#   'review_content': "It's a really nice product"},
#  {'product_id': 'B08HDJ86NZ',
#   'user_id': 'AEWAZDZZJLQUYVOVGBEUKSLXHQ5A',
#   'review_id': 'R3EEUZKKK9J36I',
#   'review_title': 'Good product',
#   'review_content': 'Good product'},
#  {'product_id': 'B08HDJ86NZ',
#   'user_id': 'AG5HTSFRRE6NL3M5SGCUQBP7YSCA',
#   'review_id': 'R3HJVYCLYOY554',
#   'review_title': 'Good one',
#   'review_content': 'long wire'},
#  {'product_id': 'B08HDJ86NZ',
#   'user_id': 'AH725ST5NW2Y4JZPKUNTIJCUK2BA',
#   'review_id': 'REDECAZ7AMPQC',
#   'review_title': 'Nice',
#   'review_content': 'Charges good'},
#  {'product_id': 'B08HDJ86NZ',
#   'user_id': 'AHV3TXIFCJPMS4D5JATCEUR266MQ',
#   'review_id': 'R1CLH2ULIVG5U3',
#   'review_title': 'Really nice product',
#   'review_content': 'Nice'},
#  {'product_id': 'B08HDJ86NZ',
#   'user_id': 'AGWIGDEMFIIUAOXYY2QATNBSUGHA',
#   'review_id': 'R2DMKIBGFKBD6R',
#   'review_title': 'Very first time change',
#   'review_content': 'I bought this cable for Rs.339 worthy product for this price'},
#  {'product_id': 'B08HDJ86NZ',
#   'user_id': 'AFSTSLQUV4EVEXWKBOLEFHL2H5YQ',
#   'review_id': 'RC89B5IAJUTR5',
#   'review_title': 'Good',
#   'review_content': ' i tested it in various charger adapters 33w and 18w it supports fast charging as well.'},
#  {'product_id': 'B08HDJ86NZ',
#   'user_id': 'AGAKDNBHY2FKX7I4ACRGILU7QL7A',
#   'review_id': 'R3B3DDON5FH8DS',
#   'review_title': 'Fine product but could be better',
#   'review_content': 'Good'},
#  {'product_id': 'B08HDJ86NZ',
#   'user_id': 'AFNWJUWJRHCC6HN52KMG5AKZY37Q',
#   'review_id': 'R13WAEJDI5RS36',
#   'review_title': "Very nice it's charging like jet",
#   'review_content': 'Ok'},
#  {'product_id': 'B08CF3B7N1',
#   'user_id': 'AE3Q6KSUK5P75D5HFYHCRAOLODSA',
#   'review_id': 'R1BP4L2HH9TFUP',
#   'review_title': 'As good as original',
#   'review_content': 'Bought this instead of original apple'},
#  {'product_id': 'B08CF3B7N1',
#   'user_id': 'AFUGIFH5ZAFXRDSZHM4QB2KPKFUQ',
#   'review_id': 'R16PVJEXKV6QZS',
#   'review_title': 'Decent',
#   'review_content': ' does the work for 150rs'},
#  {'product_id': 'B08CF3B7N1',
#   'user_id': 'AFK4NJOLFSJGWLOJIUIAROJF6YVA',
#   'review_id': 'R2UPDB81N66T4P',
#   'review_title': 'Good one for secondary use',
#   'review_content': ' not as fast as apple charger but its a good option if you want cheap and good product'},
#  {'product_id': 'B08CF3B7N1',
#   'user_id': 'AFUOTYRFUXVPEBGIXVZZ7DR3CZUA',
#   'review_id': 'R3KK4GT934ST3I',
#   'review_title': 'Best quality',
#   'review_content': " bought it for iPad pro 10.5 and it's working flawlessly"},
#  {'product_id': 'B08CF3B7N1',
#   'user_id': 'AFDLRSXKDZ6U3U3KD46SQLFGZQRA',
#   'review_id': 'RCFHMWUSBIJO',
#   'review_title': 'GOOD',
#   'review_content': ' build quality is ok'},
#  {'product_id': 'B08CF3B7N1',
#   'user_id': 'AH5VLM66SIK7J3IRG4NY7XVOQ55A',
#   'review_id': 'RDO7DACXMAJ84',
#   'review_title': 'Amazing product at a mind blowing price!',
#   'review_content': ' its not like i am gonna hang my clothes on it and i want a very strong cable'},
#  {'product_id': 'B08CF3B7N1',
#   'user_id': 'AE3MQNNHHLUHXURL5S7IAR7JTGNQ',
#   'review_id': 'R3A6MEZL3LY66Z',
#   'review_title': 'Nice Quality',
#   'review_content': ' even a braided cable stop working after a year'},
#  {'product_id': 'B08CF3B7N1',
#   'user_id': 'AFSEOFZY67MYC7UAJU264Z5NFTLA',
#   'review_id': 'R1ESIEKPGAYA29',
#   'review_title': 'Good product',
#   'review_content': " i have used both Anker and Apple store strong braided cable they all stop working after a year so please don't buy high end cables just for that instead choose a this one and even if it's stops working withing a year you only loose 150rs compares to 2000rs.UPDATE------------------------------------pin has stopped charging from one side"},
#  {'product_id': 'B08Y1TFSP6',
#   'user_id': 'AEQ2YMXSZWEOHK2EHTNLOS56YTZQ',
#   'review_id': 'R7S8ANNSDPR40',
#   'review_title': "It's pretty good",
#   'review_content': "It's a good product."},
#  {'product_id': 'B08Y1TFSP6',
#   'user_id': 'AGRVINWECNY7323CWFXZYYIZOFTQ',
#   'review_id': 'R3CLZFLHVJU26P',
#   'review_title': 'Average quality',
#   'review_content': 'Like'},
#  {'product_id': 'B08Y1TFSP6',
#   'user_id': 'AHBAT6VLOXWGYDL57KHCNCLPXAKA',
#   'review_id': 'RFF7U7MPQFUGR',
#   'review_title': 'very good and useful usb cable',
#   'review_content': 'Very good item strong and useful USB cableValue for moneyThanks to amazon and producer'},
#  {'product_id': 'B08Y1TFSP6',
#   'user_id': 'AF7NDY2H6JVYTSQOZP76GCATQ34Q',
#   'review_id': 'R1MV1NKC23DWPI',
#   'review_title': 'Good USB cable. My experience was very good it is long lasting',
#   'review_content': 'https://m.media-amazon.com/images/I/51112ZRE-1L._SY88.jpg'},
#  {'product_id': 'B08Y1TFSP6',
#   'user_id': 'AFV7ZA733ZLME4KNLZPMPCBUNPPA',
#   'review_id': 'R11D3U0V2XKDKF',
#   'review_title': 'Good',
#   'review_content': 'Good'},
#  {'product_id': 'B08Y1TFSP6',
#   'user_id': 'AHFAAPSY2MJ5HYOU2VQDJ7AQY4NQ',
#   'review_id': 'R18MP1KLUE18PC',
#   'review_title': 'Nice product and useful',
#   'review_content': 'Nice product and useful product'},
#  {'product_id': 'B08Y1TFSP6',
#   'user_id': 'AH2WGV2PEBUTICRPBEEVKF24G5LA',
#   'review_id': 'RWGJNVEH5ZQME',
#   'review_title': '-',
#   'review_content': '-'},
#  {'product_id': 'B08Y1TFSP6',
#   'user_id': 'AEP4MK3EKOBDKTGPJTRN5RBDIODA',
#   'review_id': 'R1XN72FU6Q37IH',
#   'review_title': 'Sturdy but does not support 33w charging',
#   'review_content': 'Sturdy but does not support 33w charging'},
#  {'product_id': 'B08WRWPM22',
#   'user_id': 'AG7C6DAADCTRQJG2BRS3RIKDT52Q',
#   'review_id': 'R8E73K2KWJRDS',
#   'review_title': 'Long durable.',
#   'review_content': 'Build quality is good and it is comes with 2 year warranty.'},
#  {'product_id': 'B08WRWPM22',
#   'user_id': 'AFU7BOMPVJ7Q3TTA4G67RASTGYIQ',
#   'review_id': 'RSD0JTIIWQQL8',
#   'review_title': 'good',
#   'review_content': 'Good Product'},
#  {'product_id': 'B08WRWPM22',
#   'user_id': 'AER5ZGIXXVYG3AWZTRZT7M2BYCEA',
#   'review_id': 'R64CRSTE9SLW1',
#   'review_title': 'Does not charge Lenovo m8 tab',
#   'review_content': "Bought it for charging my mobile & tab but it doesn't work for Lenovo m8 tab"},
#  {'product_id': 'B08WRWPM22',
#   'user_id': 'AHE76XQSOLGOP5ZEKTIW6KUPDWBQ',
#   'review_id': 'R2FRTNIIUFJE1F',
#   'review_title': 'Best charging cable',
#   'review_content': 'Guys this cable is is best compare of everyone over heat protection'},
#  {'product_id': 'B08WRWPM22',
#   'user_id': 'AGXTMB2XHZBEWZ2UIX7ODZ4XTU6Q',
#   'review_id': 'RWGNX3W7UOJ7W',
#   'review_title': 'good',
#   'review_content': ' quickly charging'},
#  {'product_id': 'B08WRWPM22',
#   'user_id': 'AHNM2XVU745EDPNGUOAG74PTSNRA',
#   'review_id': 'R32TYHHODHTF5D',
#   'review_title': 'Boat',
#   'review_content': ' but chance to shock circuit'},
#  {'product_id': 'B08WRWPM22',
#   'user_id': 'AH5RWQ4S72IVLZD6O75OPCFIVDXQ',
#   'review_id': 'RQL9ZMQUTY7P2',
#   'review_title': 'Product was good',
#   'review_content': 'good'},
#  {'product_id': 'B08WRWPM22',
#   'user_id': 'AG322TYKVPLPBDXE7ABEUK5QTALQ',
#   'review_id': 'R280XJ5VZUBOXV',
#   'review_title': '1.5 m का केबल मेरे लिए बहुत ही लाभदायक है ।',
#   'review_content': 'Nice'},
#  {'product_id': 'B08DDRGWTJ',
#   'user_id': 'AHW6E5LQ2BDYOIVLAJGDH45J5V5Q',
#   'review_id': 'R2X090D1YHACKR',
#   'review_title': 'Worth for money - suitable for Android auto',
#   'review_content': 'Worth for money - suitable for Android auto... my purpose served in car....got it for Rs.150'},
#  {'product_id': 'B08DDRGWTJ',
#   'user_id': 'AF74RSGCHPZITVFSZN76K6GKPICA',
#   'review_id': 'R32ZCIH9AFNJ60',
#   'review_title': 'Good Product',
#   'review_content': 'Everything is Okay. But packaging is not good feeling like seller gave is used cable.'},
#  {'product_id': 'B08DDRGWTJ',
#   'user_id': 'AHDD7ZNB47QA2JLYU53HD4ML3VNQ',
#   'review_id': 'R3N57EVVG0EHAF',
#   'review_title': 'Length',
#   'review_content': 'Good product'},
#  {'product_id': 'B08DDRGWTJ',
#   'user_id': 'AHV3ELGDSOWBYUQLXSPDCSHBQRHQ',
#   'review_id': 'R3QWLE8JHROKC1',
#   'review_title': 'Nice',
#   'review_content': 'Good product but cost is more.'},
#  {'product_id': 'B08DDRGWTJ',
#   'user_id': 'AEJU4L3ZM2GTILSJZZSNSF6VUOIA',
#   'review_id': 'R2VTSDOOUTSQ5X',
#   'review_title': 'Original',
#   'review_content': 'Original cable'},
#  {'product_id': 'B08DDRGWTJ',
#   'user_id': 'AFVD66VQMSHPDT3A6HBBBGKRXBZA',
#   'review_id': 'R3E6FZ75Q074KH',
#   'review_title': 'Very good quay Cable support fast charging.',
#   'review_content': 'I bought this cable at 129. Using this cable for Android auto in my car. Perfectly works without any glitch.'},
#  {'product_id': 'B08DDRGWTJ',
#   'user_id': 'AELKHQXVSSG6NHXLFJLLNEFRQQUQ',
#   'review_id': 'R1SYBQLTPFCW20',
#   'review_title': 'Original MI cable for charging upto 33 watt',
#   'review_content': 'Original MI cable. Will charge upto 33 watts. Got it for Rs 150.  I have 67 watt charger and I want a cable for my car so I went for it. I checked the performance with battery charging app. The charging speed is exactly half of my 67 watt original cable. Go for it.'},
#  {'product_id': 'B08DDRGWTJ',
#   'user_id': 'AGYSMAC6V6RFJJOHG2FIRPOZ6CSQ',
#   'review_id': 'RYQT96J8HPIXE',
#   'review_title': 'I am veri happy with this product as it provide turbo charging.',
#   'review_content': 'It provided me turbo charging. I recommend for all Redmi note 10s mobile phones. As it provide turbo charging. I am veri happy with this product.'},
#  {'product_id': 'B008IFXQFU',
#   'user_id': 'AGV3IEFANZCKECFGUM42MRH5FNOA',
#   'review_id': 'R1LW6NWSVTVZ2H',
#   'review_title': 'Works on linux for me. Get the model with antenna.',
#   'review_content': 'I use this to connect an old PC to internet. I tried lubuntu 20 and ubuntu 22'},
#  {'product_id': 'B008IFXQFU',
#   'user_id': 'AEBO7NWCNXKT4AESAN443HQH35FQ',
#   'review_id': 'R3VR5WFKUS15C5',
#   'review_title': 'Does what it say but other brands available at lesser price',
#   'review_content': ' it worked out of the box in both'},
#  {'product_id': 'B008IFXQFU',
#   'user_id': 'AE7GD3VRRYQEAHDR7FXJIR23INYA',
#   'review_id': 'R2F6GC79OYWUKQ',
#   'review_title': 'Easy Handle',
#   'review_content': " didn't have to do any setup. There's an extender cable so you can place this in a comfortable place. Get the model with antenna because otherwise you'll have range problems if you're not directly in line of sight from your wifi router."},
#  {'product_id': 'B008IFXQFU',
#   'user_id': 'AHPAW24BI5X2GCX5M2LHI72VSJJQ',
#   'review_id': 'R3QZ19MECGWG9A',
#   'review_title': 'Great product',
#   'review_content': 'The wifi dongle is a simple plug & play device'},
#  {'product_id': 'B008IFXQFU',
#   'user_id': 'AE2VXY4CFO36MDSIMPG43XHNF4GA',
#   'review_id': 'R2MPU42MYK7GPO',
#   'review_title': 'Perfect working',
#   'review_content': ' will start catching available networks right after you plug it into your USB port'},
#  {'product_id': 'B008IFXQFU',
#   'user_id': 'AHHQEKUNVETALN7DTRHUQ2WAWEKQ',
#   'review_id': 'R33DVXFB4VYPZZ',
#   'review_title': 'Speed is perfect',
#   'review_content': ' no additional installations/ softwares requires. Signal strength is good.... just wonder what would be different in other adapters of lesser known brands which are available at a much more competitive pricing'},
#  {'product_id': 'B008IFXQFU',
#   'user_id': 'AFMIFTNTUD5PIHGONWOTRMMZ5EBA',
#   'review_id': 'R1SQ7OGFR4JRUR',
#   'review_title': 'Great Design',
#   'review_content': ' hence a star less.'},
#  {'product_id': 'B008IFXQFU',
#   'user_id': 'AHOJBIZVVIIFJKRREY4B6ESVA4KA',
#   'review_id': 'R1S5F9QI0M1VBZ',
#   'review_title': ' Build',
#   'review_content': "Pros:*Easy to use & Portable*Can be connected to Mobile Hotspot and used in PC( Budget Friendly)*Less installation process*No heating issues & Good Coverage*Best alternative for USB Tethering (phone's battery may get damaged for long term run with Tethering)Cons:*Internet connection speed varies at times"},
#  {'product_id': 'B082LZGK39',
#   'user_id': 'AECPFYFQVRUWC3KGNLJIOREFP5LQ',
#   'review_id': 'RGIQEG07R9HS2',
#   'review_title': 'A Good Braided Cable for Your Type C Device',
#   'review_content': "I ordered this cable to connect my phone to Android Auto of car. The cable is really strong and the connection ports are really well made. I already has a Micro USB cable from Ambrane and it's still in good shape. I connected my phone to the car using the cable and it got connected well and no issues. I also connected it to the charging port and yes it has Fast Charging support."},
#  {'product_id': 'B082LZGK39',
#   'user_id': 'AGYYVPDD7YG7FYNBXNGXZJT525AQ',
#   'review_id': 'R1SMWZQ86XIN8U',
#   'review_title': 'Good quality product from ambrane',
#   'review_content': "It quality is good at this price and the main thing is that i didn't ever thought that this cable will be so long it's good one and charging power is too good and also supports fast charging"},
#  {'product_id': 'B082LZGK39',
#   'user_id': 'AHONIZU3ICIEHQIGQ6R2VFRSBXOQ',
#   'review_id': 'R2J3Y1WL29GWDE',
#   'review_title': 'Super cable',
#   'review_content': 'Value for money'},
#  {'product_id': 'B082LZGK39',
#   'user_id': 'AFPHD2CRPDZMWMBL7WXRSVYWS5JA',
#   'review_id': 'RYGGS0M09S3KY',
#   'review_title': 'As',
#   'review_content': ' with extra length👍'},
#  {'product_id': 'B082LZGK39',
#   'user_id': 'AEZ346GX3HJ4O4XNRPHCNHXQURMQ',
#   'review_id': 'R17KQRUTAN5DKS',
#   'review_title': 'Good quality',
#   'review_content': 'Good'},
#  {'product_id': 'B082LZGK39',
#   'user_id': 'AEPSWFPNECKO34PUC7I56ITGXR6Q',
#   'review_id': 'R3AAQGS6HP2QUK',
#   'review_title': 'Good product',
#   'review_content': ' working fine'},
#  {'product_id': 'B082LZGK39',
#   'user_id': 'AHWVEHR5DYLVFTO2KF3IZATFQSWQ',
#   'review_id': 'R1HDNOG6TO2CCA',
#   'review_title': 'its good',
#   'review_content': 'Product quality is good'},
#  {'product_id': 'B082LZGK39',
#   'user_id': 'AH4QT33M55677I7ISQOAKEQWACYQ',
#   'review_id': 'R3PHKXYA5AFEOU',
#   'review_title': 'Good quality for the price but one issue with my unit',
#   'review_content': 'Good'},
#  {'product_id': 'B08CF3D7QR',
#   'user_id': 'AGYLPKPZHVYKKZHOTHCTYVEDAJ4A',
#   'review_id': 'R11MQS7WD9C3I0',
#   'review_title': 'Good for fast charge but not for data transfer',
#   'review_content': 'The cable is efficient in fast charging but in quick data transfer. Overall fine.'},
#  {'product_id': 'B08CF3D7QR',
#   'user_id': 'AGTTU64JMX722LYCN3SOWLFPKPAQ',
#   'review_id': 'R2AKH69XQY8BY4',
#   'review_title': 'Good cable compares to local the brand.',
#   'review_content': 'I like the usb c  L shape. Nylon Shielded core wire it improves the life of the cable.'},
#  {'product_id': 'B08CF3D7QR',
#   'user_id': 'AFWD4ZTM7473CDWARHCDQKK73MTA',
#   'review_id': 'R8GBOLYUN5UP6',
#   'review_title': 'good but doesnt last',
#   'review_content': 'i think i buy these every 6 months or so. fast charging stops working after a while. probbly something to do with the cable design. the cable gets twisted over time and I suspect that breaks the high capacity wires inside. but i keep buying it because there arent too many options in an L shaped design'},
#  {'product_id': 'B08CF3D7QR',
#   'user_id': 'AEXCQM3FDLX3YL3UJWWUIAIUJT4A',
#   'review_id': 'R1AYVO4R25KJTA',
#   'review_title': 'Good product',
#   'review_content': "Good and durable product. Sometime the charges doesn't work on few adapters. there might be few cut off or something but works fine on apple adapter"},
#  {'product_id': 'B08CF3D7QR',
#   'user_id': 'AHUKYUWRUVRTB3IQGISXWTSPAWLQ',
#   'review_id': 'R1HT6XM787V7FV',
#   'review_title': 'Good Product',
#   'review_content': ' Car charger'},
#  {'product_id': 'B08CF3D7QR',
#   'user_id': 'AFWW4UEXAJH7EAB5LTMKMSGLUN2Q',
#   'review_id': 'R339XJL1GMKHA3',
#   'review_title': 'Good and worth it',
#   'review_content': ' USB'},
#  {'product_id': 'B08CF3D7QR',
#   'user_id': 'AFM5JL37WY7G6MLQUI4WAXUJME7Q',
#   'review_id': 'R175VFSB2A32HG',
#   'review_title': 'very good material quality charging speed is 15 watt',
#   'review_content': 'The product is really good at affordable price.'},
#  {'product_id': 'B08CF3D7QR',
#   'user_id': 'AFECO24WYFOU2KL7C3DMHTEHRU7Q',
#   'review_id': 'R35T9LXYBSP09G',
#   'review_title': 'Not a fast charger',
#   'review_content': 'Good and fast charging'},
#  {'product_id': 'B0789LZTCJ',
#   'user_id': 'AEWAZDZZJLQUYVOVGBEUKSLXHQ5A',
#   'review_id': 'R3EEUZKKK9J36I',
#   'review_title': 'Good product',
#   'review_content': 'Good product'},
#  {'product_id': 'B0789LZTCJ',
#   'user_id': 'AG5HTSFRRE6NL3M5SGCUQBP7YSCA',
#   'review_id': 'R3HJVYCLYOY554',
#   'review_title': 'Good one',
#   'review_content': 'long wire'},
#  {'product_id': 'B0789LZTCJ',
#   'user_id': 'AH725ST5NW2Y4JZPKUNTIJCUK2BA',
#   'review_id': 'REDECAZ7AMPQC',
#   'review_title': 'Nice',
#   'review_content': 'Charges good'},
#  {'product_id': 'B0789LZTCJ',
#   'user_id': 'AHV3TXIFCJPMS4D5JATCEUR266MQ',
#   'review_id': 'R1CLH2ULIVG5U3',
#   'review_title': 'Really nice product',
#   'review_content': 'Nice'},
#  {'product_id': 'B0789LZTCJ',
#   'user_id': 'AGWIGDEMFIIUAOXYY2QATNBSUGHA',
#   'review_id': 'R2DMKIBGFKBD6R',
#   'review_title': 'Very first time change',
#   'review_content': 'I bought this cable for Rs.339 worthy product for this price'},
#  {'product_id': 'B0789LZTCJ',
#   'user_id': 'AFSTSLQUV4EVEXWKBOLEFHL2H5YQ',
#   'review_id': 'RC89B5IAJUTR5',
#   'review_title': 'Good',
#   'review_content': ' i tested it in various charger adapters 33w and 18w it supports fast charging as well.'},
#  {'product_id': 'B0789LZTCJ',
#   'user_id': 'AGAKDNBHY2FKX7I4ACRGILU7QL7A',
#   'review_id': 'R3B3DDON5FH8DS',
#   'review_title': 'Fine product but could be better',
#   'review_content': 'Good'},
#  {'product_id': 'B0789LZTCJ',
#   'user_id': 'AFNWJUWJRHCC6HN52KMG5AKZY37Q',
#   'review_id': 'R13WAEJDI5RS36',
#   'review_title': "Very nice it's charging like jet",
#   'review_content': 'Ok'},
#  {'product_id': 'B07KSMBL2H',
#   'user_id': 'AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ',
#   'review_id': 'R1FKOKZ3HHKJBZ',
#   'review_title': "It's quite good and value for money",
#   'review_content': "I am using it for 14 days now. The experience is pretty good as of now. Picture quality is also not bad. Don't expect something out of the world at this price point. But you can go for it if you have a tight budget."},
#  {'product_id': 'B07KSMBL2H',
#   'user_id': 'AFY5TVFOMVHGBPBTIJODYDQRZM5Q',
#   'review_id': 'R2WNMZI1EXTA0H',
#   'review_title': 'Works well',
#   'review_content': 'Initial impressions: works as said'},
#  {'product_id': 'B07KSMBL2H',
#   'user_id': 'AE3O6366WGEQAANKJ76QETTUQQTQ',
#   'review_id': 'RCA1M3W4RIXUR',
#   'review_title': 'Hdmi cable',
#   'review_content': ' glad I didn’t go for cheaper options (not that it’s too costly) just plug and play. Will update if it screws up'},
#  {'product_id': 'B07KSMBL2H',
#   'user_id': 'AEQIJCPWSBCDKUO5VROXXHWX3PPA',
#   'review_id': 'R3BKCLL6D7ZLIX',
#   'review_title': 'Value for money',
#   'review_content': 'The hdmi cable is good to watch movie'},
#  {'product_id': 'B07KSMBL2H',
#   'user_id': 'AGVIAQK2HQ47P7UVXHW2NBAEU7YQ',
#   'review_id': 'REVSR0ILY3547',
#   'review_title': 'All good',
#   'review_content': 'sports and its gives better quality while connecting your laptop with TV and play 🎮.I loved it'},
#  {'product_id': 'B07KSMBL2H',
#   'user_id': 'AE3D5CJ2GDUP5SQ3AAYMVAGDTX7A',
#   'review_id': 'R15W5KMQB95IV5',
#   'review_title': 'Gets the job done',
#   'review_content': 'Works as expected. Length of the cable is short and it was mentioned also satisfied my requirement. If you need more length better look other options.'},
#  {'product_id': 'B07KSMBL2H',
#   'user_id': 'AH77IQRYD54XCRMCO7XEAIAYCLPA',
#   'review_id': 'R10PB68FRUHT5V',
#   'review_title': 'Delivery was good',
#   'review_content': 'All good'},
#  {'product_id': 'B07KSMBL2H',
#   'user_id': 'AEA2HQHMFG3ZGJFOLLJQ65WKIZUQ',
#   'review_id': 'R3TLCE9JSBU3UP',
#   'review_title': 'This one was my need to purchase',
#   'review_content': "It's the best HDMI cable at this price range. No problems yet. Just go for it !!"},
#  {'product_id': 'B085DTN6R2',
#   'user_id': 'AGUAYQHARAKR2VZTRP276KAGETKQ',
#   'review_id': 'R1QETDIPRCX4S0',
#   'review_title': 'Works',
#   'review_content': 'Definitely isn’t as good as the original cord but works. Fast charging and pretty sturdy'},
#  {'product_id': 'B085DTN6R2',
#   'user_id': 'AFKTST2773VUOKUHE7FCR6QCAURQ',
#   'review_id': 'RARQYQ8POOFA9',
#   'review_title': 'Nice Product',
#   'review_content': 'Worth it'},
#  {'product_id': 'B085DTN6R2',
#   'user_id': 'AEGLHOQOWUUUQEDV6EWXTSHIUE7A',
#   'review_id': 'R952F931MCOR5',
#   'review_title': 'Fast Charging as original',
#   'review_content': 'So I had a faulty cable. I was lazy and have a lot of money so instead of calling Apple I bought this for like 300 bucks. Didn’t expected much but for my surprise'},
#  {'product_id': 'B085DTN6R2',
#   'user_id': 'AEHQYGI5L4FFALBMC5XMT5KXSZCA',
#   'review_id': 'R3LLDHV3WXED9C',
#   'review_title': 'Good for data transfer',
#   'review_content': ' this cable actually works and has fast charging. JUST GO FOR IT'},
#  {'product_id': 'B085DTN6R2',
#   'user_id': 'AHJFXFGDAXEHIG2ZLUWVMZ3LWPBA',
#   'review_id': 'R282YHZ5A4GMY4',
#   'review_title': 'Average. Cost effective',
#   'review_content': 'Felt quite sturdy'},
#  {'product_id': 'B085DTN6R2',
#   'user_id': 'AEP4CW3UI7AJ7XM7PAAKVCB6U3ZA',
#   'review_id': 'R34W3B1C7RP98Q',
#   'review_title': 'Good quality',
#   'review_content': ' the connectors look premium and were easy to insert. I used this cable to switch all my data from iphone 7 to an m30s. Cable worked like charm while using smart switch app'},
#  {'product_id': 'B085DTN6R2',
#   'user_id': 'AHIWCPCQ2Z4HWEM7V4HGTLVZQM6Q',
#   'review_id': 'R1467F9VL3DLSY',
#   'review_title': 'Great Product',
#   'review_content': ' all my data including whatsapp data was transferred successfully. Satisfied with performance.'},
#  {'product_id': 'B085DTN6R2',
#   'user_id': 'AHT4JDEYWRIQGCA2WAQJ6E2POHCQ',
#   'review_id': 'R3KLQRR1UM44JG',
#   'review_title': 'Nice',
#   'review_content': 'Just good'},
#  {'product_id': 'B09KLVMZ3B',
#   'user_id': 'AF2XXVO7JUBUVAOBTJ3MNH4DGUFQ',
#   'review_id': 'R20XIOU25HEX80',
#   'review_title': 'Great but',
#   'review_content': 'Loosing charging cable of apple is costly affair. This wire was great purchase made to correct it'},
#  {'product_id': 'B09KLVMZ3B',
#   'user_id': 'AH6VDJLLPBXKCWXMLBKMBCQ2ESGA',
#   'review_id': 'R2X55FA2EEUEYM',
#   'review_title': 'Worked well for 6 six months that’s it',
#   'review_content': 'Worked well for six months that’s it'},
#  {'product_id': 'B09KLVMZ3B',
#   'user_id': 'AE642RIGZIT2VPQJOLNUZ34QVWJQ',
#   'review_id': 'R393Z224NBTDLN',
#   'review_title': 'Compatible with Apple iPad 2nd generation and charging very well.',
#   'review_content': ' now it’s stopped working'},
#  {'product_id': 'B09KLVMZ3B',
#   'user_id': 'AFLHNKQH5UQZU3ATISKSMRE2KEDQ',
#   'review_id': 'R3Q4ZCHWSAQD5B',
#   'review_title': 'CABLE',
#   'review_content': ' now planning to buy one more because the price has come down to 150'},
#  {'product_id': 'B09KLVMZ3B',
#   'user_id': 'AF2L4MCRCIDOOREQJN7QPQ4QBZCA',
#   'review_id': 'R1AE3A4NSVM9SC',
#   'review_title': 'The product is good but the phone gets disconnected at multiple occasions.',
#   'review_content': 'Very good product. Compatible with  iPad 2nd generation  and charging very well. Quality of the product is very good and also works fine. Totally worth for its price.'},
#  {'product_id': 'B09KLVMZ3B',
#   'user_id': 'AGKLZ4SUHAU47KJXDVHBBEWJODUA',
#   'review_id': 'R2U1YAAZE07I1V',
#   'review_title': 'Not a fast charging cable',
#   'review_content': 'Product is super'},
#  {'product_id': 'B09KLVMZ3B',
#   'user_id': 'AHESCOYXLCXB56F4JO45X4CZQCYA',
#   'review_id': 'R36NVL58WQ7D64',
#   'review_title': 'Good item. Value',
#   'review_content': "I'm using from last 6 month. Till now it was good functioning. Now I noticed phone gets disconnected at multiple occasions. might be cable may be damaged.Overall worked well for 6 month."},
#  {'product_id': 'B09KLVMZ3B',
#   'user_id': 'AGGHDE6KFZHEDUDJBD5R27AYMEWA',
#   'review_id': 'R1E7GPZ569TBIZ',
#   'review_title': 'Amazing product and value for money',
#   'review_content': 'Takes 5-6 hours to charge full.'},
#  {'product_id': 'B083342NKJ',
#   'user_id': 'AGSGSRTEZBQY64WO2HKQTV7TWFSA',
#   'review_id': 'R2JPQNKCOE10UK',
#   'review_title': 'Good product',
#   'review_content': 'I like it 👍👍'},
#  {'product_id': 'B083342NKJ',
#   'user_id': 'AEYD5HVYAJ23CR6PTWOOIKUOIDHA',
#   'review_id': 'RQI80JG2WZXNF',
#   'review_title': 'using this product 8months It is done  I have not faced any problem so far',
#   'review_content': 'Best charging power . I used this cable on note 8 pro mi. Using 8month also fast working.'},
#  {'product_id': 'B083342NKJ',
#   'user_id': 'AFRMNW6TDHDZBP2UHF2K3MEAEYUA',
#   'review_id': 'R2LYZ4CUWPMUJN',
#   'review_title': ' its build quality best',
#   'review_content': '350 might be a little expensive but physically it’s so good. Feels premium. But power limitation is there it is not suitable for fast charging.'},
#  {'product_id': 'B083342NKJ',
#   'user_id': 'AHICHCW6EC3BNV2IDAEAJPBG4HZQ',
#   'review_id': 'R1ZBD2ZB2ZYEWX',
#   'review_title': 'I really liked this one.',
#   'review_content': ''},
#  {'product_id': 'B083342NKJ',
#   'user_id': 'AGWFKE7RNP6EVC4JFLFSL76EEVVQ',
#   'review_id': 'R2ITEDC9KOCY3N',
#   'review_title': 'Very strong and support fast charging ',
#   'review_content': 'https://m.media-amazon.com/images/W/WEBP_402378-T1/images/I/61WnvIUaIwL._SY88.jpg'},
#  {'product_id': 'B083342NKJ',
#   'user_id': 'AGEOQQHGNELZNEUKJAJUA7NTPBLA',
#   'review_id': 'R1115HIQP3BKKJ',
#   'review_title': '',
#   'review_content': 'Best data cable charging fast'},
#  {'product_id': 'B083342NKJ',
#   'user_id': 'AFS3QBSOMCE2FAZFUYZ3NBFQDLMQ',
#   'review_id': 'R31OMS6DNMI7M',
#   'review_title': 'Nice cable',
#   'review_content': 'Very good quality and good durability'},
#  {'product_id': 'B083342NKJ',
#   'user_id': 'AGJYG6ZWCWD74WNE6Y37XZ2VUSMA',
#   'review_id': 'R2DCFXQMUNO93L',
#   'review_title': 'Best data cable charging fast',
#   'review_content': 'Overall good but need some improvement...'},
#  {'product_id': 'B0B6F7LX4C',
#   'user_id': 'AHEVOQADJSSRX7DS325HSFLMP7VQ',
#   'review_id': 'R13UTIA6KOF6QV',
#   'review_title': 'It is the best tv if you are getting it in 10-12k',
#   'review_content': 'Pros- xiomi 5a is best in budget-Nice picture quality-Very nice audio output- Full of featureCONS- sometimes tv lags-Sometimes stucksIn this prize range all tv having cons like this.::Overall nice tv'},
#  {'product_id': 'B0B6F7LX4C',
#   'user_id': 'AG7XYZRCSKX6G2OLO7DVZWIZ3PUQ',
#   'review_id': 'R2UGDZSGFF01K7',
#   'review_title': 'Good price but the OS lags',
#   'review_content': 'The product in this price range is good but as it is running in Android 12 it lags. I hope after few updates the lags problem will be resolved'},
#  {'product_id': 'B0B6F7LX4C',
#   'user_id': 'AE2THTCCQLBIUSWPF4CPXC6GGP7Q',
#   'review_id': 'RHHIZ45VYU5X6',
#   'review_title': 'GARBAGE QUALITY',
#   'review_content': 'Useless product and useless quality. Display issues within 7 months and service center is not upto the mark. Go for better brands where quality is assured. I would wish if there was option of negative stars.'},
#  {'product_id': 'B0B6F7LX4C',
#   'user_id': 'AHUJZOV34DFEN55QQ5XOYKVKHV6Q',
#   'review_id': 'R14N9HBE5EIUY0',
#   'review_title': 'Good product.',
#   'review_content': 'Uses as connectes TV the picture is very good. I was hopping a best level of song. Globaly it is a good product.'},
#  {'product_id': 'B0B6F7LX4C',
#   'user_id': 'AELX4DI77ZHURZTDLYFU7XMP7R6Q',
#   'review_id': 'R2WMW096T9Y0OU',
#   'review_title': 'Good quality',
#   'review_content': 'https://m.media-amazon.com/images/I/61spXDbojZL._SY88.jpg'},
#  {'product_id': 'B0B6F7LX4C',
#   'user_id': 'AE2ODWBBOBD2SITDDIEJ644OSRFQ',
#   'review_id': 'R1SHIIE6M72825',
#   'review_title': 'Great experience everything is fantastic 🤠',
#   'review_content': 'Greater then ever'},
#  {'product_id': 'B0B6F7LX4C',
#   'user_id': 'AFLW4WXYQ3G6HU5LBQORDDZO3FOQ',
#   'review_id': 'R22P6BE9DBME4F',
#   'review_title': 'Super picture quality and sound quality',
#   'review_content': 'Good quality'},
#  {'product_id': 'B0B6F7LX4C',
#   'user_id': 'AGGRC2P6M43GDEWCAHGYAILCSKTQ',
#   'review_id': 'R2TEINENXTIHT2',
#   'review_title': 'Awesome',
#   'review_content': 'Good 👍'},
#  {'product_id': 'B082LSVT4B',
#   'user_id': 'AECPFYFQVRUWC3KGNLJIOREFP5LQ',
#   'review_id': 'RGIQEG07R9HS2',
#   'review_title': 'A Good Braided Cable for Your Type C Device',
#   'review_content': "I ordered this cable to connect my phone to Android Auto of car. The cable is really strong and the connection ports are really well made. I already has a Micro USB cable from Ambrane and it's still in good shape. I connected my phone to the car using the cable and it got connected well and no issues. I also connected it to the charging port and yes it has Fast Charging support."},
#  {'product_id': 'B082LSVT4B',
#   'user_id': 'AGYYVPDD7YG7FYNBXNGXZJT525AQ',
#   'review_id': 'R1SMWZQ86XIN8U',
#   'review_title': 'Good quality product from ambrane',
#   'review_content': "It quality is good at this price and the main thing is that i didn't ever thought that this cable will be so long it's good one and charging power is too good and also supports fast charging"},
#  {'product_id': 'B082LSVT4B',
#   'user_id': 'AHONIZU3ICIEHQIGQ6R2VFRSBXOQ',
#   'review_id': 'R2J3Y1WL29GWDE',
#   'review_title': 'Super cable',
#   'review_content': 'Value for money'},
#  {'product_id': 'B082LSVT4B',
#   'user_id': 'AFPHD2CRPDZMWMBL7WXRSVYWS5JA',
#   'review_id': 'RYGGS0M09S3KY',
#   'review_title': 'As',
#   'review_content': ' with extra length👍'},
#  {'product_id': 'B082LSVT4B',
#   'user_id': 'AEZ346GX3HJ4O4XNRPHCNHXQURMQ',
#   'review_id': 'R17KQRUTAN5DKS',
#   'review_title': 'Good quality',
#   'review_content': 'Good'},
#  {'product_id': 'B082LSVT4B',
#   'user_id': 'AEPSWFPNECKO34PUC7I56ITGXR6Q',
#   'review_id': 'R3AAQGS6HP2QUK',
#   'review_title': 'Good product',
#   'review_content': ' working fine'},
#  {'product_id': 'B082LSVT4B',
#   'user_id': 'AHWVEHR5DYLVFTO2KF3IZATFQSWQ',
#   'review_id': 'R1HDNOG6TO2CCA',
#   'review_title': 'its good',
#   'review_content': 'Product quality is good'},
#  {'product_id': 'B082LSVT4B',
#   'user_id': 'AH4QT33M55677I7ISQOAKEQWACYQ',
#   'review_id': 'R3PHKXYA5AFEOU',
#   'review_title': 'Good quality for the price but one issue with my unit',
#   'review_content': 'Good'},
#  {'product_id': 'B08WRBG3XW',
#   'user_id': 'AFB5KJR4Q5FICAHBOPDPUTB3O7QQ',
#   'review_id': 'R2BP8Y5OJXKJLF',
#   'review_title': 'Good for charging and Data transfer',
#   'review_content': 'Check for offera before buying'},
#  {'product_id': 'B08WRBG3XW',
#   'user_id': 'AHW3QBHDOUMXODZ4EAMHD5JMDIDQ',
#   'review_id': 'R218813TNRHNSY',
#   'review_title': 'ਮਜ਼ਬੂਤ',
#   'review_content': '18w charging cable'},
#  {'product_id': 'B08WRBG3XW',
#   'user_id': 'AGXRGH7DLS3RVFS5KWU4PGR3H3GQ',
#   'review_id': 'R3VIKEVJ5DBF5G',
#   'review_title': 'Good Quality but less Power Delivery',
#   'review_content': ''},
#  {'product_id': 'B08WRBG3XW',
#   'user_id': 'AFLIHOX2HH7S2OJAD63UAHKMY34Q',
#   'review_id': 'R2PQNCTR8TQCT4',
#   'review_title': 'Fantastic!',
#   'review_content': 'Awesome cable!Charging'},
#  {'product_id': 'B08WRBG3XW',
#   'user_id': 'AEHBE4U3HD6G2TMSHKE7TNZYOWCA',
#   'review_id': 'R3FI11UEJC9ZOJ',
#   'review_title': 'Good',
#   'review_content': ' data transfer and durability is simply awesome'},
#  {'product_id': 'B08WRBG3XW',
#   'user_id': 'AFHKIURZM4R62UEXTOCZLI2FPQ6A',
#   'review_id': 'R3ULCCZZHBNLA4',
#   'review_title': 'Not useful',
#   'review_content': ' and there is not a single disconnection issue'},
#  {'product_id': 'B08WRBG3XW',
#   'user_id': 'AEW6K4E5A4RUWRFFUDINQE5WWBSQ',
#   'review_id': 'RELIQ4H7CYX2Q',
#   'review_title': "Doesn't fit properly",
#   'review_content': " which I always faced in original mi cable from box. Bought 1 more time as last cable damaged when phone fell on usb cable port as my phone is heavy and I never faced any issues so i bought one more time and didn't went for replacement as its waste of time and energy"},
#  {'product_id': 'B08WRBG3XW',
#   'user_id': 'AG4LMDCRAAKD4U2FZ6B6N75KTHXA',
#   'review_id': 'R3ALQNTJN4ER9N',
#   'review_title': "Can't support Oppo mobile for fast charging",
#   'review_content': ' i also have boat earphones that is also awesome..😄'},
#  {'product_id': 'B08DPLCM6T',
#   'user_id': 'AHBNKB74LGTYUOKPAJBSKNFV45CA',
#   'review_id': 'R2PNR69G0BQG2F',
#   'review_title': 'Sound quality',
#   'review_content': 'LG was always Good '},
#  {'product_id': 'B08DPLCM6T',
#   'user_id': 'AFIECTV45ADX5YPTE2VU6ORRHTGQ',
#   'review_id': 'R31A0WWDEYMKEW',
#   'review_title': 'Very nice',
#   'review_content': ' correct delivery'},
#  {'product_id': 'B08DPLCM6T',
#   'user_id': 'AFDUJI7KG7VMZF4JGJHV4DBCA4OA',
#   'review_id': 'R2C4XEWFLVU7JV',
#   'review_title': 'Value for money',
#   'review_content': ' good service but sound quality was poor. The speakers were fitted below the tv. No clear sound. That was the only problem.'},
#  {'product_id': 'B08DPLCM6T',
#   'user_id': 'AEUWKSX5ZL7DWOOYVDOWJKBHOVXA',
#   'review_id': 'RYWES5AT5FQO6',
#   'review_title': 'Good',
#   'review_content': 'Good videoGood vice'},
#  {'product_id': 'B08DPLCM6T',
#   'user_id': 'AHEJW5MYVFOQBEXD6BIUBB3PJBPQ',
#   'review_id': 'R1PGWAY5TEWLT4',
#   'review_title': 'Good for its price.',
#   'review_content': 'Picture quality is awesome.'},
#  {'product_id': 'B08DPLCM6T',
#   'user_id': 'AEM2Y22BKLFYL5BK7SC56Q75ODOQ',
#   'review_id': 'R32542OPR0QC4I',
#   'review_title': 'Good item',
#   'review_content': 'Good at that price'},
#  {'product_id': 'B08DPLCM6T',
#   'user_id': 'AHWDVB4OO4S3YS5RYQZIDBNV6BUQ',
#   'review_id': 'R2JDJEVZ2G7EEK',
#   'review_title': 'Budget friendly',
#   'review_content': 'Okay product'},
#  {'product_id': 'B08DPLCM6T',
#   'user_id': 'AFCEDQXVCB4LUUBWXRJS6KRU62FQ',
#   'review_id': 'R36EHHPAQNSSOF',
#   'review_title': 'Good',
#   'review_content': ' the OS has lags after about a year of use. This is the best you can get for the price tag it comes with.'},
#  {'product_id': 'B09C6HXFC1',
#   'user_id': 'AFNYIBWKJLJQKY4BGK77ZOTVMORA',
#   'review_id': 'R12D1BZF9MU8TN',
#   'review_title': 'Good cable for car',
#   'review_content': 'I trust this product! Works well with car play!'},
#  {'product_id': 'B09C6HXFC1',
#   'user_id': 'AFCTNNMP2LZLY5466YJ5AY3JE5ZA',
#   'review_id': 'R32MNCWO5LGFCG',
#   'review_title': 'Good substitute for orginal',
#   'review_content': 'Very good quality and charging is fine. As good as original'},
#  {'product_id': 'B09C6HXFC1',
#   'user_id': 'AG3XBWOAL65DJSBHJ7LQ2K54HJKQ',
#   'review_id': 'RZU3UK8OZKD6X',
#   'review_title': 'Better Value for money Product',
#   'review_content': 'Build quality is awesome'},
#  {'product_id': 'B09C6HXFC1',
#   'user_id': 'AF2ZFMLJS4UBCGZO4FMJTEPP6MHA',
#   'review_id': 'R3BSTKR3JUW6GY',
#   'review_title': 'Way better than the original',
#   'review_content': ' best lightening cable ever seen'},
#  {'product_id': 'B09C6HXFC1',
#   'user_id': 'AFBZMRHC4GXUU7KNAK4OBKORDF6Q',
#   'review_id': 'R1ARVYPXS4XPB7',
#   'review_title': 'Absolutely amazing.',
#   'review_content': ' better than a official  lightening from \uf8ffIf ur looking for a cable close your eyes and go for it 🔥 or you can buy a (Amazon basics) one I was using that for past 3 years that a bit a cheaper side'},
#  {'product_id': 'B09C6HXFC1',
#   'user_id': 'AHSIQL276K7X2UP72QOOOWNVRSXA',
#   'review_id': 'R1V6GDYE2IBX8O',
#   'review_title': 'Namm hi kafi hai',
#   'review_content': ' I recommend both these cables had better build quality and value for money'},
#  {'product_id': 'B09C6HXFC1',
#   'user_id': 'AF3D6X5NQWOBOEVVH2Y37N55AKZQ',
#   'review_id': 'R28EG2PXZTJL90',
#   'review_title': 'Very good',
#   'review_content': 'Gr8 product overall'},
#  {'product_id': 'B09C6HXFC1',
#   'user_id': 'AFWOTSQXCQJLZ653Y7ACEZADKGYQ',
#   'review_id': 'R2SQNU7OIOOLHT',
#   'review_title': 'As the names say Durable cell it a durable cable ;-)',
#   'review_content': 'Just loved it'},
#  {'product_id': 'B085194JFL',
#   'user_id': 'AEO5FHWNOSFBT554DKQAG4ICBGFQ',
#   'review_id': 'R1GYK05NN6747O',
#   'review_title': 'Good product ; Average Finishing',
#   'review_content': 'This connector has provided as a boon for my old Samsung LCD monitor and I am proactively using that monitor as the 2nd screen just if the finishing of the product can be improved then it would be a better purchase option.'},
#  {'product_id': 'B085194JFL',
#   'user_id': 'AGIQ5Y7Q4MKZ542KKVFZLAIZV6GQ',
#   'review_id': 'R1J21BZ29NGQF9',
#   'review_title': 'Save it purpose well without any issue. I am satisfied',
#   'review_content': 'Save it purpose well without any issue. I am satisfied'},
#  {'product_id': 'B085194JFL',
#   'user_id': 'AFD53TWXXCPJAYQJ7REZPW34AKKQ',
#   'review_id': 'R16JCHEILBYOMW',
#   'review_title': 'No issues',
#   'review_content': 'Working fine'},
#  {'product_id': 'B085194JFL',
#   'user_id': 'AHBMHE56M3IAD7Z4KXUKREAZX3WQ',
#   'review_id': 'R2WVVS88M7SH18',
#   'review_title': 'NO NEED TO PUT AUX CABLE FOR CONNECTING AUDIO FROM SECONDARY MONITOR',
#   'review_content': 'GO FOR IT'},
#  {'product_id': 'B085194JFL',
#   'user_id': 'AFR4YULNFZZC5DJOWH2KNFAOM6BQ',
#   'review_id': 'R2MQ3VB8ZTUS48',
#   'review_title': 'Good product',
#   'review_content': 'It’s works properly good product but poor quality'},
#  {'product_id': 'B085194JFL',
#   'user_id': 'AEP5UMK4KDMGZGBHBLZDB2R37OMA',
#   'review_id': 'RBJPTKHYQ7G7U',
#   'review_title': 'Not so Bad',
#   'review_content': 'I buy this product after so many reviews. this product is not so much clear. But it get the job done. you can buy to get display only. not so much clear. but still price is very good compare to other products.'},
#  {'product_id': 'B085194JFL',
#   'user_id': 'AHLKQWAPXICPCSCIPIF6C6FOENOQ',
#   'review_id': 'R37PKO5FUPJW35',
#   'review_title': 'Good',
#   'review_content': 'Good'},
#  {'product_id': 'B085194JFL',
#   'user_id': 'AHTBS46SCEBGWK4SUH3FOQEORR3Q',
#   'review_id': 'R38R2YC2J2BMWR',
#   'review_title': 'Worked will for only 3-4 months.',
#   'review_content': 'It worked really well for 3-4 months but now it started showing its "cheap chinese" side. Display keeps disconnecting randomly and will come back. It\'s a headache to read/work on external monitor now since it keeps disconnecting the external monitor and then reconnects it.'},
#  {'product_id': 'B09F6S8BT6',
#   'user_id': 'AHEVO4Q5NM4YXMG2HDDXC5XMBGRQ',
#   'review_id': 'R1SN0D4DFBKAZI',
#   'review_title': 'Good',
#   'review_content': 'Overall good.'},
#  {'product_id': 'B09F6S8BT6',
#   'user_id': 'AFZPH7ZAWX5VDY3HOBNYRDGIDBVA',
#   'review_id': 'R1SX5L77L2CD6V',
#   'review_title': 'Sound is very low another brand comparing in better',
#   'review_content': 'TV picture ok smart betterSound very low another brand'},
#  {'product_id': 'B09F6S8BT6',
#   'user_id': 'AFURD6VVHRG4HZ36KXGXYUTVUDLA',
#   'review_id': 'R1NAZ6M4QBUJMK',
#   'review_title': 'Service provider not meet my home refuse',
#   'review_content': 'Service provider refuse install my TV'},
#  {'product_id': 'B09F6S8BT6',
#   'user_id': 'AHJF5BZJNDLXJXSW74ZPLHGO7GUA',
#   'review_id': 'R25I5FXOJA76KS',
#   'review_title': ' tv i am not using bad service',
#   'review_content': ' bad service and samsung'},
#  {'product_id': 'B09F6S8BT6',
#   'user_id': 'AFUS52CHEA75E2YGQ6SYGP3PKBGA',
#   'review_id': 'R32V7DQLDSKJ99',
#   'review_title': 'Good product',
#   'review_content': ' I am calling 3 times service provider. Not meet my home address.why ? Bad bad'},
#  {'product_id': 'B09F6S8BT6',
#   'user_id': 'AGS3YC22FW2PCSH3I7ODDXETZ6BA',
#   'review_id': 'R8QWY8HXI120P',
#   'review_title': 'Ok super',
#   'review_content': 'They product did not come with the support stand or wall hanging hook to install the Tv'},
#  {'product_id': 'B09F6S8BT6',
#   'user_id': 'AGGI2H2AGOIX6IBDJRWULYUP5DPQ',
#   'review_id': 'R2OZPGGMUCLSC1',
#   'review_title': 'Floor stand does not come with it ...',
#   'review_content': 'Picture quality is very poor in cables'},
#  {'product_id': 'B09F6S8BT6',
#   'user_id': 'AG4TU4LCQXF2XTLMMGMFTNWL3OOA',
#   'review_id': 'R1G4SA1P865EIS',
#   'review_title': 'Good',
#   'review_content': 'Floor stand does not come with it ... You have to buy it seperately. Request Amazon to cleary mention it in the add . You will have to pay seperate charges for the installation guy to buy the floor mount .'},
#  {'product_id': 'B09NHVCHS9',
#   'user_id': 'AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA',
#   'review_id': 'R3F4T5TRYPTMIG',
#   'review_title': 'Worked on iPhone 7 and didn’t work on XR',
#   'review_content': 'Worked on iPhone 7 and didn’t work on iPhone XR'},
#  {'product_id': 'B09NHVCHS9',
#   'user_id': 'AE55KTFVNXYFD5FPYWP2OUPEYNPQ',
#   'review_id': 'R3DQIEC603E7AY',
#   'review_title': 'Good one',
#   'review_content': 'https://m.media-amazon.com/images/I/71qFFAlV9ZL._SY88.jpg'},
#  {'product_id': 'B09NHVCHS9',
#   'user_id': 'AEBWA5I4QFCA3P3OBEPMELBGN4GQ',
#   'review_id': 'R1O4Z15FD40PV5',
#   'review_title': 'Dull Physical Looks',
#   'review_content': 'Look-wise'},
#  {'product_id': 'B09NHVCHS9',
#   'user_id': 'AHMGAC6QM62UXNEOCZIHLHSXPP2Q',
#   'review_id': 'RDVX50PD4CTFE',
#   'review_title': 'Just Buy it',
#   'review_content': ' I didn’t like it. Still'},
#  {'product_id': 'B09NHVCHS9',
#   'user_id': 'AFHROSCGIXUPV3FYQ7H5QOD46Q7Q',
#   'review_id': 'R3H6WKG0TA5CGU',
#   'review_title': 'Go for it',
#   'review_content': ' I use it for my work.'},
#  {'product_id': 'B09NHVCHS9',
#   'user_id': 'AEAMIR3CMSA32IDEINSJKHRNANTA',
#   'review_id': 'R3Q3L1KP5QWPV3',
#   'review_title': 'About the product',
#   'review_content': 'Product is quite good and is fast charging.Loved it.'},
#  {'product_id': 'B09NHVCHS9',
#   'user_id': 'AF355FTXYAKFH5NYPRTE7SL3WO3Q',
#   'review_id': 'RU0LU2PAIIME',
#   'review_title': 'Get charging cable at the price',
#   'review_content': 'I like it . Looks last long.'},
#  {'product_id': 'B09NHVCHS9',
#   'user_id': 'AG5DWPD54QGSLWJ6QUFERLPNAX4Q',
#   'review_id': 'R20FTANBPFA653',
#   'review_title': 'Working well.',
#   'review_content': 'The sturdiness will depend on the manner of its use. But its speed of charging is great. Very good product for the average income group.'},
#  {'product_id': 'B0B1YVCJ2Y',
#   'user_id': 'AFSMISGEYDYIP3Z42UTQU4AKOYZQ',
#   'review_id': 'R1EBS3566VCSCG',
#   'review_title': 'Wonderful TV and Awful installation service from amazon',
#   'review_content': 'About the TV - Wonderful---------------------------------------------------------------Probably the best TV in this price range (INR13000).Good - Google interface'},
#  {'product_id': 'B0B1YVCJ2Y',
#   'user_id': 'AF5ILQY4KFDTO5XHHBJ42W5DXCZQ',
#   'review_id': 'R24MB66WRPSN2A',
#   'review_title': 'Acer Television Review',
#   'review_content': ' loaded with features'},
#  {'product_id': 'B0B1YVCJ2Y',
#   'user_id': 'AFBK3X6D3AHEHSYYXPL4L6JEMSLQ',
#   'review_id': 'R25UU2M1B9BO5X',
#   'review_title': "It's a good product for that price.",
#   'review_content': ' lightweight'},
#  {'product_id': 'B0B1YVCJ2Y',
#   'user_id': 'AFNB6YVNGE6IT3AWQVSIG2TJ5L3Q',
#   'review_id': 'R1NXW7PGVND2LE',
#   'review_title': 'Good for the price',
#   'review_content': ' 55 watt power consumption'},
#  {'product_id': 'B0B1YVCJ2Y',
#   'user_id': 'AGGKMIGXUM3JRNVY7HZ3JHPJ7WTQ',
#   'review_id': 'R3OSBPH7X9AQUK',
#   'review_title': 'Almost a complete package',
#   'review_content': ' stable designAverage - Sound and Picture quality is quite good but if you compare it with premium brands then obviously not that good.Features- Most of the streaming apps available and compatible- You can connect with WiFi'},
#  {'product_id': 'B0B1YVCJ2Y',
#   'user_id': 'AFMECPERM2GI2XQJSBWEPZKODISQ',
# ...
#  {'product_id': 'B08RP2L2NL',
#   'user_id': 'AH5QCHOEUTDOJFO6UV2CGMZU5SUQ',
#   'review_id': 'R4FCBHSKL92PJ',
#   'review_title': 'Not bad',
#   'review_content': "It doesn't support Apple car play connectivity. Good quality. BUT 👎When winding down the cable most of the times gets entangled."},
#  {'product_id': 'B08RP2L2NL',
#   'user_id': 'AH47N5DDNXGCIUMG3NVONJ6SERZA',
#   'review_id': 'R2XO77R7XKY30O',
#   'review_title': 'good to charge at home',
#   'review_content': 'Usefull'},
#  {'product_id': 'B08RP2L2NL',
#   'user_id': 'AF6N6OWYE2EZASDJCO4BOQD7AFIA',
#   'review_id': 'RS96LTGI8BWQ7',
#   'review_title': ' not in vehicles',
#   'review_content': 'charges'},
#  {'product_id': 'B08RP2L2NL',
#   'user_id': 'AFET7BHXMVHWJN5AS7AR3VHLW5ZA',
#   'review_id': 'RKYSZQWYQIFBV',
#   'review_title': 'Easy to store and use built in quality of plastic roll could have been better',
#   'review_content': " but doesn't support Apple car play"},
#  {'product_id': 'B08RP2L2NL',
#   'user_id': 'AFZL3ATLXN5TG5KBUMLEY2ABSMWA',
#   'review_id': 'R284MA5RVLO6CF',
#   'review_title': 'Good',
#   'review_content': 'Built in quality of plastic roll could have been better'},
#  {'product_id': 'B0B4G2MWSB',
#   'user_id': 'AF42EMTPEJAL4LNEPPX77TN77UHA',
#   'review_id': 'RZJR37WFGXR9B',
#   'review_title': 'A well-priced product.',
#   'review_content': 'i am writing this review after 2 months'},
#  {'product_id': 'B0B4G2MWSB',
#   'user_id': 'AHBMZRY43T2GTYDVNFMUVASIBTPA',
#   'review_id': 'R39X6O18GM16TM',
#   'review_title': 'Lenthy cord.',
#   'review_content': ' the first cable had a cut and had to be replaced'},
#  {'product_id': 'B0B4G2MWSB',
#   'user_id': 'AECCRE6ZTCPFGPVWDNY3IYYHCMOQ',
#   'review_id': 'R18ZQ09EKVWZ9R',
#   'review_title': 'Product is working as expected.',
#   'review_content': ' the second cable is working fine'},
#  {'product_id': 'B0B4G2MWSB',
#   'user_id': 'AHOURK4XKLPPC4VHEDJ25NP64NPQ',
#   'review_id': 'R3NHUC9S00KIR8',
#   'review_title': 'Lengthy cable',
#   'review_content': ' no issues'},
#  {'product_id': 'B0B4G2MWSB',
#   'user_id': 'AFC5K7RQQYKFB5PV47KAX2CHVIIQ',
#   'review_id': 'R30ZSNYE78E0O2',
#   'review_title': ' works for car dashcam',
#   'review_content': ' using it to charge me PS3 controller'},
#  {'product_id': 'B0B4G2MWSB',
#   'user_id': 'AHEVOBT5PFXMIS5A7GAXRG52XARQ',
#   'review_id': 'R2LVRBREQ4EFDM',
#   'review_title': 'Product is okay but they give 50rs for giving 5 stars.',
#   'review_content': ' works fine'},
#  {'product_id': 'B0B4G2MWSB',
#   'user_id': 'AHNOMOD65QU6QKFP3AMH5QPGQO6A',
#   'review_id': 'R1UJ8BCYXWICT8',
#   'review_title': 'Misleading length (1.2m)',
#   'review_content': ' at a good price'},
#  {'product_id': 'B0B4G2MWSB',
#   'user_id': 'AGN2VH6RTYG5CM3YVH34VGYJFO4A',
#   'review_id': 'R34RH86MGL4HFB',
#   'review_title': ' rest fine',
#   'review_content': ' planning to pick up another one as a spare.'},
#  {'product_id': 'B0B21C4BMX',
#   'user_id': 'AH4LJDHSBLPNJYLQGQ53EQ6DBVZA',
#   'review_id': 'R15R4BV0MI9SH1',
#   'review_title': "its not for fast charging as per my use and this don't support in car for android auto.",
#   'review_content': "i like the made of the product but it doesn't support fast charging  and it dont connect to android auto in car."},
#  {'product_id': 'B0B21C4BMX',
#   'user_id': 'AF4BWMWZI7TTQY2YTE2HTHRB3NHQ',
#   'review_id': 'R3L67FMAFHYG6H',
#   'review_title': 'Great',
#   'review_content': 'Great'},
#  {'product_id': 'B0B21C4BMX',
#   'user_id': 'AGG22XY7PCKPZDT6352IVLL2H34A',
#   'review_id': 'R1GR1N3BCB3VVZ',
#   'review_title': 'Can be used as spare in an emergency.',
#   'review_content': 'Connectors are compatible. Charging power delivery depends on the adapter used. Build quality is good. Suitable lenght.'},
#  {'product_id': 'B0B21C4BMX',
#   'user_id': 'AGTO2SOXJTD3K6T7WPUHCT6SUMKA',
#   'review_id': 'R1E0GBU7BQ6CSV',
#   'review_title': 'Good',
#   'review_content': '3 leads working'},
#  {'product_id': 'B0B21C4BMX',
#   'user_id': 'AF5CIA2LXA75JJFRVWLKGOLKZIHQ',
#   'review_id': 'R28IGDF71QMQZO',
#   'review_title': 'good for car drives',
#   'review_content': 'user friendly for car drives'},
#  {'product_id': 'B0B21C4BMX',
#   'user_id': 'AFVHCWF76EOX4NMKE2ZUU67CEOBQ',
#   'review_id': 'R3NFH3J30CCSO9',
#   'review_title': "Not worth Doesn't charge",
#   'review_content': "Doesn't charge proper"},
#  {'product_id': 'B0B21C4BMX',
#   'user_id': 'AGUZMT2E4HNC5VF25OWLAUF6KBGA',
#   'review_id': 'R3VCM9XQOZO7IX',
#   'review_title': 'Good one from portronics',
#   'review_content': ' tried all possible ways. It is so slow and can support only one device at a time.'},
#  {'product_id': 'B0B21C4BMX',
#   'user_id': 'AE3GY55N5USCMWLS2JIO7CZFS5FQ',
#   'review_id': 'RD2MZ0Y1MQGF2',
#   'review_title': 'Excellent cable',
#   'review_content': 'Quality'},
#  {'product_id': 'B084MZXJNK',
#   'user_id': 'AE2JTMRKTUOIVIZWS2WDGTMNTU4Q',
#   'review_id': 'R23AXPPZ5G7J6Q',
#   'review_title': 'Perfect product',
#   'review_content': 'Good cable. got original product and it is durable and light weight'},
#  {'product_id': 'B084MZXJNK',
#   'user_id': 'AF4QXCB32VC2DVE7O3DGFNQVFFNQ',
#   'review_id': 'R2U7YYESQ3433I',
#   'review_title': 'Better than the original cable',
#   'review_content': 'Quality is top notch and also tough as hell very much durable and charges the devices just like the original brand cable. Never have to worry about wear and tear of cables.'},
#  {'product_id': 'B084MZXJNK',
#   'user_id': 'AGAFYHMPFGVPR3MOS4QAZLAWPW3A',
#   'review_id': 'RMUJQEHAD3JV3',
#   'review_title': 'Better then original',
#   'review_content': 'Fast charging'},
#  {'product_id': 'B084MZXJNK',
#   'user_id': 'AGNNWLEF6V57TKIFJM7SWHNFAIQQ',
#   'review_id': 'R1SFABVO7E4KZO',
#   'review_title': 'Good',
#   'review_content': ' built quality super'},
#  {'product_id': 'B084MZXJNK',
#   'user_id': 'AFVIPOPKMOCVCX3CMXUJHMWDIMGA',
#   'review_id': 'R2DFBJB0TJUK4H',
#   'review_title': 'The Very Best',
#   'review_content': 'Using to charge I phone X with Samsung 25 watt charger'},
#  {'product_id': 'B084MZXJNK',
#   'user_id': 'AH6MFUU725GG4KA3XTALSTU2ILHA',
#   'review_id': 'R1A0YQ72E7P6KT',
#   'review_title': 'Works absolutely fine',
#   'review_content': ' it works fine'},
#  {'product_id': 'B084MZXJNK',
#   'user_id': 'AGQYTSKE2UBYARZYRBADQMX6BJPQ',
#   'review_id': 'R3AXDDTW3B5UGJ',
#   'review_title': 'Charging is very slow.',
#   'review_content': ' charges the phone in 90 minutes'},
#  {'product_id': 'B084MZXJNK',
#   'user_id': 'AG7F66F724JZ2HIJQY7NOU5M5D2Q',
#   'review_id': 'R3F3ZASCS3C7S3',
#   'review_title': 'Best Product',
#   'review_content': '  lets see how long it lasts '},
#  {'product_id': 'B0BHZCNC4P',
#   'user_id': 'AHY3QEA3CVS57POB64VVMQSPHHHA',
#   'review_id': 'R2RC9IQ0X5NHFU',
#   'review_title': 'Some buttons not working in first week of purchase',
#   'review_content': 'Some buttons not working in first week of purchase. Quality not upto the mark.'},
#  {'product_id': 'B0BHZCNC4P',
#   'user_id': 'AG633F2HW3BKLPJU3JCTLLLHWBHQ',
#   'review_id': 'ROE0YIUOFNATH',
#   'review_title': 'Good',
#   'review_content': 'https://m.media-amazon.com/images/I/61YEe372yJL._SY88.jpg'},
#  {'product_id': 'B0BHZCNC4P',
#   'user_id': 'AFU64BXF4ADZXV2SSZXAAAVLB7OQ',
#   'review_id': 'R1UUDX7FZOB74Y',
#   'review_title': '4',
#   'review_content': 'Works as expected.'},
#  {'product_id': 'B0BHZCNC4P',
#   'user_id': 'AFXDOEANKNDY342TWIUJUYEU55IQ',
#   'review_id': 'R3HADV1CIZ9873',
#   'review_title': 'Must buy product',
#   'review_content': 'Good product with great compatability with firestick'},
#  {'product_id': 'B0BHZCNC4P',
#   'user_id': 'AEI5OOS434KUVK3SPKYEZMBJUB5A',
#   'review_id': 'R3AD7NBWNZ4BF6',
#   'review_title': 'Quality of product is wonderful',
#   'review_content': 'Liked the utility'},
#  {'product_id': 'B0BHZCNC4P',
#   'user_id': 'AERD56GM7L442X34ICEOKG44MK2A',
#   'review_id': 'R2SFOHTIKJWFAA',
#   'review_title': 'Very bad experience as I have received a working remove and not being able to return it',
#   'review_content': ' build and finish'},
#  {'product_id': 'B0BHZCNC4P',
#   'user_id': 'AFH5RGXHECG6OFJEKVIAUWKFYU2Q',
#   'review_id': 'R1NXPLBQC25OFZ',
#   'review_title': 'Orignal product',
#   'review_content': "It's not working moreover not being able to initiate return/refund after so many tries"},
#  {'product_id': 'B0BHZCNC4P',
#   'user_id': 'AHOEADKKYXTHETSA2WOA6N4MQEVA',
#   'review_id': 'R1SNHI5TU1ORFH',
#   'review_title': 'Good product and good customer service',
#   'review_content': 'एक दम मस्त चलरहा है'},
#  {'product_id': 'B0B16KD737',
#   'user_id': 'AHKTEC7ZVRWNAA66KB3V5REUQG6A',
#   'review_id': 'R6H0LMQOYOUPR',
#   'review_title': "Value for money!! But don't expect Flagship quality.",
#   'review_content': 'Tv is good as such'},
#  {'product_id': 'B0B16KD737',
#   'user_id': 'AFMYMI6FWPFSDK7KXBHB2D7555OA',
#   'review_id': 'RNP5KTHVIELH4',
#   'review_title': 'Good',
#   'review_content': ' there are multiple issues for it'},
#  {'product_id': 'B0B16KD737',
#   'user_id': 'AEZTUFS2XNNKJ5ZCNRLE5JWWI4PQ',
#   'review_id': 'RQSOPFFP2W9UH',
#   'review_title': 'Good product',
#   'review_content': ' you get what you paid for so not going to brag about it. Picture looks crisp'},
#  {'product_id': 'B0B16KD737',
#   'user_id': 'AGVZ57S4TZDMQTXR67SMTWQOOKRA',
#   'review_id': 'R28G1GQ4YWOYOX',
#   'review_title': 'Good',
#   'review_content': ' sound is awful'},
#  {'product_id': 'B0B16KD737',
#   'user_id': 'AEJWYKZND5DTQQYR26RKWY5FWTOQ',
#   'review_id': 'R1ASISF519P4CO',
#   'review_title': 'God',
#   'review_content': ' light weight'},
#  {'product_id': 'B0B16KD737',
#   'user_id': 'AGBUVENL47YJ3NJFQJS2MKZC7NKA',
#   'review_id': 'R3VF5DEKULWSKF',
#   'review_title': 'Value for money',
#   'review_content': ' flimsy legs and body'},
#  {'product_id': 'B0B16KD737',
#   'user_id': 'AFI3EFAYZRL5L5TQXRQBQKWJQJTQ',
#   'review_id': 'RLQPU8GARVD9A',
#   'review_title': 'Nice product',
#   'review_content': " tv looks frame less unless you turn it on. This tv doesn't support Pre Video out of the box"},
#  {'product_id': 'B0B16KD737',
#   'user_id': 'AEQWP6WIVLFP2L3MSAWW3RENW3XQ',
#   'review_id': 'R5A7COKUGSUIQ',
#   'review_title': 'Youtub is slow but all perform best',
#   'review_content': ' reaching out to Customer care will easily resolve the issue. There are noticeable lag while casting/ screen share. Overall the product is good for small office'},
#  {'product_id': 'B099K9ZX65',
#   'user_id': 'AFP334GQV3WBH6XJIX5VITMYOH2A',
#   'review_id': 'R1Z33CAT0B5EQM',
#   'review_title': 'Hisense Vivid 4K TV Initial Impressions',
#   'review_content': 'Hi all'},
#  {'product_id': 'B099K9ZX65',
#   'user_id': 'AHAIKXSSOQ7R5GBPVSBR6VE72QVQ',
#   'review_id': 'R38KPAP35GXYOK',
#   'review_title': 'Picture quality',
#   'review_content': ' firstly'},
#  {'product_id': 'B099K9ZX65',
#   'user_id': 'AHTSXQI7JAQVYVVQE6DK4B2EJSPQ',
#   'review_id': 'R26YGSNK20I13P',
#   'review_title': 'Best in class Audio & picture quality',
#   'review_content': ' I was very skeptical to purchase TV through online. Secondary'},
#  {'product_id': 'B099K9ZX65',
#   'user_id': 'AH3DODDCISNEXGUHYV4MRDQ3H36Q',
#   'review_id': 'R2LRI9HDQ8EDA4',
#   'review_title': 'Good products',
#   'review_content': ' Iam a big fan of Sony and LG brands.'},
#  {'product_id': 'B099K9ZX65',
#   'user_id': 'AFNNLWHF3B35C5XQN3Y6T77GIJFQ',
#   'review_id': 'R1GGE338ZSBHFP',
#   'review_title': 'Amazing',
#   'review_content': ' Thirdly'},
#  {'product_id': 'B099K9ZX65',
#   'user_id': 'AHN73IF2MNKIJ2MEMND5ODN7XDFA',
#   'review_id': 'R195Z8O5JXM9OY',
#   'review_title': 'Good',
#   'review_content': 'as I have 4 year old kid at home I was so scared to spend money beyond 15k. Ofcourse at the first day sale for prime members when the Amazon great Indian festival started'},
#  {'product_id': 'B099K9ZX65',
#   'user_id': 'AGG44FGU5A2RZMRCILNFIV6SCYDA',
#   'review_id': 'R11CX4EPU303P9',
#   'review_title': 'Good product',
#   'review_content': ' I saw one Plus and Hisense A6H were priced at under 20k including bank offers and my favourite Sony 43inch was priced at 35k. But discarded Sony just bcz of expensive and scared if my kid whilst playing will break it. So I was continuously searching for budget friendly TVs like TCL'},
#  {'product_id': 'B099K9ZX65',
#   'user_id': 'AHFQGP45QKIEFKYOCYUH4DP63XGQ',
#   'review_id': 'R27JZDVM9VS7Y5',
#   'review_title': 'Good size for small leaving room of 18\'*9\'6" ',
#   'review_content': " Redmi Nokia and Iffalcon but didn't like the 32 inch TV. Suddenly out of the blue on Thursday that is on 20 October I saw this blowing offer on Hisense Vivid 4K TV but scared to buy"},
#  {'product_id': 'B08Y55LPBF',
#   'user_id': 'AG6WSLLXZY52HSQUY5PRCXTCYQYQ',
#   'review_id': 'R3CR9H6ABJ4Q4O',
#   'review_title': 'Worth the price',
#   'review_content': 'Worth the price. I use the local cable providers set up. With my previous tv (Samsung) I was not facing this problem.  The only problem I am facing is each time I turn off the tv from the mains'},
#  {'product_id': 'B08Y55LPBF',
#   'user_id': 'AHGJ2DNFP3OJWO73XW2R7TDXI7WA',
#   'review_id': 'R2S5VBYYN51ELA',
#   'review_title': 'Mi Smart Tv 32" :- 7/10 average.',
#   'review_content': ' I have to go to the settings and turn the settings on to tv speaker settings despite no other speaker or WiFi or blue tooth or cell phone being in the proximity. As a result I have stopped turning the tv off from the mains. I just use remote control to put it on stand by. BUT THIS IS A PROBLEM IN THE LONG RUN'},
#  {'product_id': 'B08Y55LPBF',
#   'user_id': 'AGIC6PASSVB4T3KTZHK6ADD23GCA',
#   'review_id': 'R1U0718A15KBBU',
#   'review_title': 'Worth using since 1.5 years',
#   'review_content': ''},
#  {'product_id': 'B08Y55LPBF',
#   'user_id': 'AH4TEK5IQCC2BSF2KSQNKQEXAPLA',
#   'review_id': 'R9YRKNJ667H1E',
#   'review_title': 'expect more from mi',
#   'review_content': "Display is very good. Sound is average iam using soundbar so no issues for me. Don't know how long it will last due to my previous mi 55 4 pro panel gone in 2.5 years. Bought this tv with 2 year warranty on panel."},
#  {'product_id': 'B08Y55LPBF',
#   'user_id': 'AFJIYRZTBOJBOWYQ5RNA36DBBXOA',
#   'review_id': 'RAWMG4UI4CZD3',
#   'review_title': 'Worth for money.',
#   'review_content': 'improve the software response and improve the picture quality. worth for money for this budget (4K).'},
#  {'product_id': 'B08Y55LPBF',
#   'user_id': 'AGCRWRS4RJYVGVKINV3VAR4CGDWA',
#   'review_id': 'R877Y6K5MW32G',
#   'review_title': 'Good product',
#   'review_content': 'I have used 2-4 days. Picture quality looks good and impressive. Go for it..Hope long-term quality is also good.'},
#  {'product_id': 'B08Y55LPBF',
#   'user_id': 'AEGPWBXEAWPF6XRT7EZJOYJQA6DQ',
#   'review_id': 'RC458V57ETXDN',
#   'review_title': 'It’s good',
#   'review_content': "This tv is very good but in this one thing bad is tha this tv some time get stop while playing only YouTube video but otherwise it's a good product"},
#  {'product_id': 'B08Y55LPBF',
#   'user_id': 'AF5BU6DZ446HN4DTCO7W7AWXBJBA',
#   'review_id': 'R2VOHT3T6361C5',
#   'review_title': 'Go for it without thinking twice.',
#   'review_content': 'It’s good and value for money'},
#  {'product_id': 'B015OW3M1W',
#   'user_id': 'AGLZUIR2UEQJFHZ6KGUGFYPYINNQ',
#   'review_id': 'R1O6L77S7X03S7',
#   'review_title': 'Worth Buying',
#   'review_content': "It's really worth it . I am using it to get output on another display from my laptop through this wire. Till now it's really good and build quality is really good."},
#  {'product_id': 'B015OW3M1W',
#   'user_id': 'AERVECDPABKJA75A3HLMML7JAQMQ',
#   'review_id': 'R2714TT5OK4DYJ',
#   'review_title': 'Good one!!',
#   'review_content': "I had problem with my last hdmi cable as anyone at home switch on/off any switch my desktop display goes off  for a secWith this dp to hdmi it's all good my problem has gone ."},
#  {'product_id': 'B015OW3M1W',
#   'user_id': 'AEPQHZHEBKKLM6Q7IKBZNILWVCBA',
#   'review_id': 'R2DVBD9OKCAEB5',
#   'review_title': 'Very nice seller service.',
#   'review_content': 'Excellent Product and Service . Value for Money'},
#  {'product_id': 'B015OW3M1W',
#   'user_id': 'AEXRU5ZQWDY2IGNVAFOF4UJQ6JQQ',
#   'review_id': 'R1TDHOL1G54W34',
#   'review_title': 'Nice cable',
#   'review_content': 'This cable is very useful if your CPU has display port out & monitor has HDMI port in. Other way'},
#  ...]

# %%
temp_review_df
# Out:
#        product_id                       user_id       review_id  \
# 0      B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q  R3HXWT0LRP0NMF
# 1      B07JW9H4J1  AHMY5CWJMMK5BJRBBSNLYT3ONILA  R2AJM3LFTLZHFO
# 2      B07JW9H4J1  AHCTC6ULH4XB6YHDY6PCH2R772LQ    R6AQJGUP6P86
# 3      B07JW9H4J1  AGYHHIERNXKA6P5T7CZLXKVPT7IQ  R1KD19VHEDV0OR
# 4      B07JW9H4J1  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  R3C02RMYQMK6FC
# ...           ...                           ...             ...
# 10593  B01486F4G6  AHXCDNSXAESERITAFELQABFVNLCA  R2ZC03S4QXOW4Y
# 10594  B01486F4G6  AGRZD6CHLCUNOLMMIMIHUCG7PIFA  R186H8YW34BQD5
# 10595  B01486F4G6  AFQZVGSOSOJHKFQQMCEI4725QEKQ  R10NC3D321N59G
# 10596  B01486F4G6  AEALVGXXIP46OZVXKRUXSDWZJMEA   REKF75G4SOAOX
# 10597  B01486F4G6  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ  R2G0ZT4JQX322I
#
#                                         review_title  \
# 0                                          Satisfied
# 1                            Charging is really fast
# 2                                    Value for money
# 3                                     Product review
# 4                                       Good quality
# ...                                              ...
# 10593                             Excellent product✌
# 10594               A good product for household use
# 10595  मुझे बिल्कुल भी मजा नहीं आया और वापस कर दिया।
# 10596                                   Best product
# 10597                                           Good
#
#                                           review_content
# 0         Looks durable Charging is fine tooNo complains
# 1                                Charging is really fast
# 2                                          good product.
# 3                   Till now satisfied with the quality.
# 4      This is a good product . The charging speed is...
# ...                                                  ...
# 10593                               It is a nice product
# 10594   easy to use. The grilling function is also wo...
# 10595                                  Very good product
# 10596           This is a pretty powerful sandwich maker
# 10597               for home use. The product looks good
#
# [10598 rows x 5 columns]

# %%
temp_review_df.drop_duplicates(subset=['review_id'], inplace=True)

# %%
len(temp_review_df)
# Out:
# 9263
