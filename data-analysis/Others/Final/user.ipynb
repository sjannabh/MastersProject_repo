# %%
import pandas as pd
import numpy as np

# %%
# Column Names (['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link'],  dtype='object')
fullDataset = pd.read_csv("C:\\Repos\\MastersProject\\data-analysis\\Data\\amazon_cleaned_data.csv", delimiter=",")

fullUserData = pd.read_csv("C:\\Repos\\MastersProject\\data-analysis\\Data\\userInfo.csv", delimiter=",")

# %%
users_id_dataset = fullDataset[
    [
        "user_id"
    ]
]
users_id_dataset["user_id"] = users_id_dataset["user_id"].str.split(",")

userId_df = pd.DataFrame(columns = ['user_id'])

for index, row in users_id_dataset.iterrows():
    for itemData in row["user_id"]:
        userId_df.loc[len(userId_df)]=[itemData]
        
first_names=fullUserData["fname"].tolist()
last_names=fullUserData["lname"].tolist()
phoneNo=fullUserData["phoneNo"].tolist()

userId_df["fname"] = np.random.choice(first_names, size=len(userId_df))
userId_df["lname"] = np.random.choice(last_names, size=len(userId_df))
userId_df["phoneNo"] = np.random.choice(phoneNo, size=len(userId_df))
userId_df["email"] = userId_df["fname"] + '.' + userId_df["lname"] + '@ecommerce.com'
userId_df["password"] = userId_df["fname"] + '@1234'

userId_df.drop_duplicates(subset=['user_id'], inplace=True)
userId_df.drop_duplicates(subset=['fname','lname'], inplace=True)

users_json_dataset = userId_df.to_dict(orient='records')
# Out:
# C:\Users\srile\AppData\Local\Temp\ipykernel_23836\3317189974.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_id_dataset["user_id"] = users_id_dataset["user_id"].str.split(",")

# %%
len(users_json_dataset)
# Out:
# 5460

# %%
users_json_dataset
# Out:
# [{'user_id': 'AEWAZDZZJLQUYVOVGBEUKSLXHQ5A',
#   'fname': 'Adrian',
#   'lname': 'Mason',
#   'phoneNo': '(881) 481-4161',
#   'email': 'Adrian.Mason@ecommerce.com',
#   'password': 'Adrian@1234'},
#  {'user_id': 'AG5HTSFRRE6NL3M5SGCUQBP7YSCA',
#   'fname': 'Anabel',
#   'lname': 'Dickerson',
#   'phoneNo': '(721) 862-6245',
#   'email': 'Anabel.Dickerson@ecommerce.com',
#   'password': 'Anabel@1234'},
#  {'user_id': 'AH725ST5NW2Y4JZPKUNTIJCUK2BA',
#   'fname': 'Mateo',
#   'lname': 'Burns',
#   'phoneNo': '(484) 857-2371',
#   'email': 'Mateo.Burns@ecommerce.com',
#   'password': 'Mateo@1234'},
#  {'user_id': 'AHV3TXIFCJPMS4D5JATCEUR266MQ',
#   'fname': 'Sawyer',
#   'lname': 'Gibbs',
#   'phoneNo': '(425) 355-7376',
#   'email': 'Sawyer.Gibbs@ecommerce.com',
#   'password': 'Sawyer@1234'},
#  {'user_id': 'AGWIGDEMFIIUAOXYY2QATNBSUGHA',
#   'fname': 'Lara',
#   'lname': 'Mckay',
#   'phoneNo': '(323) 792-5897',
#   'email': 'Lara.Mckay@ecommerce.com',
#   'password': 'Lara@1234'},
#  {'user_id': 'AFSTSLQUV4EVEXWKBOLEFHL2H5YQ',
#   'fname': 'Zoe',
#   'lname': 'Moses',
#   'phoneNo': '(475) 827-6999',
#   'email': 'Zoe.Moses@ecommerce.com',
#   'password': 'Zoe@1234'},
#  {'user_id': 'AGAKDNBHY2FKX7I4ACRGILU7QL7A',
#   'fname': 'Connor',
#   'lname': 'Drake',
#   'phoneNo': '(551) 961-6303',
#   'email': 'Connor.Drake@ecommerce.com',
#   'password': 'Connor@1234'},
#  {'user_id': 'AFNWJUWJRHCC6HN52KMG5AKZY37Q',
#   'fname': 'Randall',
#   'lname': 'Mayer',
#   'phoneNo': '(599) 394-9399',
#   'email': 'Randall.Mayer@ecommerce.com',
#   'password': 'Randall@1234'},
#  {'user_id': 'AEQ2YMXSZWEOHK2EHTNLOS56YTZQ',
#   'fname': 'Ryland',
#   'lname': 'Henry',
#   'phoneNo': '(611) 906-9972',
#   'email': 'Ryland.Henry@ecommerce.com',
#   'password': 'Ryland@1234'},
#  {'user_id': 'AGRVINWECNY7323CWFXZYYIZOFTQ',
#   'fname': 'Caitlyn',
#   'lname': 'Deleon',
#   'phoneNo': '(620) 208-0148',
#   'email': 'Caitlyn.Deleon@ecommerce.com',
#   'password': 'Caitlyn@1234'},
#  {'user_id': 'AHBAT6VLOXWGYDL57KHCNCLPXAKA',
#   'fname': 'Junior',
#   'lname': 'Davila',
#   'phoneNo': '(909) 528-6649',
#   'email': 'Junior.Davila@ecommerce.com',
#   'password': 'Junior@1234'},
#  {'user_id': 'AF7NDY2H6JVYTSQOZP76GCATQ34Q',
#   'fname': 'Abdiel',
#   'lname': 'Mccormick',
#   'phoneNo': '(639) 985-3860',
#   'email': 'Abdiel.Mccormick@ecommerce.com',
#   'password': 'Abdiel@1234'},
#  {'user_id': 'AFV7ZA733ZLME4KNLZPMPCBUNPPA',
#   'fname': 'Carl',
#   'lname': 'Atkinson',
#   'phoneNo': '(415) 867-6082',
#   'email': 'Carl.Atkinson@ecommerce.com',
#   'password': 'Carl@1234'},
#  {'user_id': 'AHFAAPSY2MJ5HYOU2VQDJ7AQY4NQ',
#   'fname': 'Dominic',
#   'lname': 'Hanna',
#   'phoneNo': '(989) 740-8125',
#   'email': 'Dominic.Hanna@ecommerce.com',
#   'password': 'Dominic@1234'},
#  {'user_id': 'AH2WGV2PEBUTICRPBEEVKF24G5LA',
#   'fname': 'Elisabeth',
#   'lname': 'Allen',
#   'phoneNo': '(714) 327-9632',
#   'email': 'Elisabeth.Allen@ecommerce.com',
#   'password': 'Elisabeth@1234'},
#  {'user_id': 'AEP4MK3EKOBDKTGPJTRN5RBDIODA',
#   'fname': 'Jaycee',
#   'lname': 'Frey',
#   'phoneNo': '(846) 752-2712',
#   'email': 'Jaycee.Frey@ecommerce.com',
#   'password': 'Jaycee@1234'},
#  {'user_id': 'AHW6E5LQ2BDYOIVLAJGDH45J5V5Q',
#   'fname': 'Hezekiah',
#   'lname': 'Choi',
#   'phoneNo': '(519) 456-9817',
#   'email': 'Hezekiah.Choi@ecommerce.com',
#   'password': 'Hezekiah@1234'},
#  {'user_id': 'AF74RSGCHPZITVFSZN76K6GKPICA',
#   'fname': 'Conner',
#   'lname': 'Cervantes',
#   'phoneNo': '(436) 894-0505',
#   'email': 'Conner.Cervantes@ecommerce.com',
#   'password': 'Conner@1234'},
#  {'user_id': 'AHDD7ZNB47QA2JLYU53HD4ML3VNQ',
#   'fname': 'Tristian',
#   'lname': 'Schmitt',
#   'phoneNo': '(786) 621-3454',
#   'email': 'Tristian.Schmitt@ecommerce.com',
#   'password': 'Tristian@1234'},
#  {'user_id': 'AHV3ELGDSOWBYUQLXSPDCSHBQRHQ',
#   'fname': 'Silas',
#   'lname': 'Miranda',
#   'phoneNo': '(901) 842-4549',
#   'email': 'Silas.Miranda@ecommerce.com',
#   'password': 'Silas@1234'},
#  {'user_id': 'AEJU4L3ZM2GTILSJZZSNSF6VUOIA',
#   'fname': 'Jamal',
#   'lname': 'Mclaughlin',
#   'phoneNo': '(869) 837-7304',
#   'email': 'Jamal.Mclaughlin@ecommerce.com',
#   'password': 'Jamal@1234'},
#  {'user_id': 'AFVD66VQMSHPDT3A6HBBBGKRXBZA',
#   'fname': 'Efrain',
#   'lname': 'Logan',
#   'phoneNo': '(866) 363-4394',
#   'email': 'Efrain.Logan@ecommerce.com',
#   'password': 'Efrain@1234'},
#  {'user_id': 'AELKHQXVSSG6NHXLFJLLNEFRQQUQ',
#   'fname': 'Jordan',
#   'lname': 'Rowe',
#   'phoneNo': '(233) 990-4215',
#   'email': 'Jordan.Rowe@ecommerce.com',
#   'password': 'Jordan@1234'},
#  {'user_id': 'AGYSMAC6V6RFJJOHG2FIRPOZ6CSQ',
#   'fname': 'Payton',
#   'lname': 'Rosario',
#   'phoneNo': '(635) 973-1543',
#   'email': 'Payton.Rosario@ecommerce.com',
#   'password': 'Payton@1234'},
#  {'user_id': 'AGYLPKPZHVYKKZHOTHCTYVEDAJ4A',
#   'fname': 'Jayvon',
#   'lname': 'Maxwell',
#   'phoneNo': '(879) 409-9408',
#   'email': 'Jayvon.Maxwell@ecommerce.com',
#   'password': 'Jayvon@1234'},
#  {'user_id': 'AGTTU64JMX722LYCN3SOWLFPKPAQ',
#   'fname': 'Keaton',
#   'lname': 'Crawford',
#   'phoneNo': '(654) 880-7445',
#   'email': 'Keaton.Crawford@ecommerce.com',
#   'password': 'Keaton@1234'},
#  {'user_id': 'AFWD4ZTM7473CDWARHCDQKK73MTA',
#   'fname': 'Axel',
#   'lname': 'Padilla',
#   'phoneNo': '(364) 570-2389',
#   'email': 'Axel.Padilla@ecommerce.com',
#   'password': 'Axel@1234'},
#  {'user_id': 'AEXCQM3FDLX3YL3UJWWUIAIUJT4A',
#   'fname': 'Lizeth',
#   'lname': 'Contreras',
#   'phoneNo': '(746) 456-8528',
#   'email': 'Lizeth.Contreras@ecommerce.com',
#   'password': 'Lizeth@1234'},
#  {'user_id': 'AHUKYUWRUVRTB3IQGISXWTSPAWLQ',
#   'fname': 'Rachel',
#   'lname': 'Macias',
#   'phoneNo': '(489) 681-4239',
#   'email': 'Rachel.Macias@ecommerce.com',
#   'password': 'Rachel@1234'},
#  {'user_id': 'AFWW4UEXAJH7EAB5LTMKMSGLUN2Q',
#   'fname': 'Romeo',
#   'lname': 'Petersen',
#   'phoneNo': '(618) 671-2498',
#   'email': 'Romeo.Petersen@ecommerce.com',
#   'password': 'Romeo@1234'},
#  {'user_id': 'AFM5JL37WY7G6MLQUI4WAXUJME7Q',
#   'fname': 'Rafael',
#   'lname': 'Potter',
#   'phoneNo': '(978) 668-5447',
#   'email': 'Rafael.Potter@ecommerce.com',
#   'password': 'Rafael@1234'},
#  {'user_id': 'AFECO24WYFOU2KL7C3DMHTEHRU7Q',
#   'fname': 'Elisa',
#   'lname': 'Arellano',
#   'phoneNo': '(708) 388-9530',
#   'email': 'Elisa.Arellano@ecommerce.com',
#   'password': 'Elisa@1234'},
#  {'user_id': 'AEYJ5I6JZZPOJB6MGWRQOHRQLPSQ',
#   'fname': 'Alissa',
#   'lname': 'Thompson',
#   'phoneNo': '(305) 795-9024',
#   'email': 'Alissa.Thompson@ecommerce.com',
#   'password': 'Alissa@1234'},
#  {'user_id': 'AFY5TVFOMVHGBPBTIJODYDQRZM5Q',
#   'fname': 'Darryl',
#   'lname': 'Nixon',
#   'phoneNo': '(975) 318-9038',
#   'email': 'Darryl.Nixon@ecommerce.com',
#   'password': 'Darryl@1234'},
#  {'user_id': 'AE3O6366WGEQAANKJ76QETTUQQTQ',
#   'fname': 'Theodore',
#   'lname': 'Walton',
#   'phoneNo': '(431) 452-0580',
#   'email': 'Theodore.Walton@ecommerce.com',
#   'password': 'Theodore@1234'},
#  {'user_id': 'AEQIJCPWSBCDKUO5VROXXHWX3PPA',
#   'fname': 'Madden',
#   'lname': 'Olson',
#   'phoneNo': '(964) 573-3274',
#   'email': 'Madden.Olson@ecommerce.com',
#   'password': 'Madden@1234'},
#  {'user_id': 'AGVIAQK2HQ47P7UVXHW2NBAEU7YQ',
#   'fname': 'Elianna',
#   'lname': 'Sexton',
#   'phoneNo': '(904) 739-7762',
#   'email': 'Elianna.Sexton@ecommerce.com',
#   'password': 'Elianna@1234'},
#  {'user_id': 'AE3D5CJ2GDUP5SQ3AAYMVAGDTX7A',
#   'fname': 'Giselle',
#   'lname': 'Perkins',
#   'phoneNo': '(278) 750-0054',
#   'email': 'Giselle.Perkins@ecommerce.com',
#   'password': 'Giselle@1234'},
#  {'user_id': 'AH77IQRYD54XCRMCO7XEAIAYCLPA',
#   'fname': 'Cole',
#   'lname': 'Davidson',
#   'phoneNo': '(968) 989-3455',
#   'email': 'Cole.Davidson@ecommerce.com',
#   'password': 'Cole@1234'},
#  {'user_id': 'AEA2HQHMFG3ZGJFOLLJQ65WKIZUQ',
#   'fname': 'Abbey',
#   'lname': 'Torres',
#   'phoneNo': '(735) 233-2299',
#   'email': 'Abbey.Torres@ecommerce.com',
#   'password': 'Abbey@1234'},
#  {'user_id': 'AGUAYQHARAKR2VZTRP276KAGETKQ',
#   'fname': 'Coby',
#   'lname': 'Charles',
#   'phoneNo': '(729) 270-1692',
#   'email': 'Coby.Charles@ecommerce.com',
#   'password': 'Coby@1234'},
#  {'user_id': 'AFKTST2773VUOKUHE7FCR6QCAURQ',
#   'fname': 'Liberty',
#   'lname': 'Branch',
#   'phoneNo': '(955) 470-5653',
#   'email': 'Liberty.Branch@ecommerce.com',
#   'password': 'Liberty@1234'},
#  {'user_id': 'AEGLHOQOWUUUQEDV6EWXTSHIUE7A',
#   'fname': 'Kali',
#   'lname': 'Galloway',
#   'phoneNo': '(833) 831-5891',
#   'email': 'Kali.Galloway@ecommerce.com',
#   'password': 'Kali@1234'},
#  {'user_id': 'AEHQYGI5L4FFALBMC5XMT5KXSZCA',
#   'fname': 'Edgar',
#   'lname': 'Glover',
#   'phoneNo': '(243) 968-8063',
#   'email': 'Edgar.Glover@ecommerce.com',
#   'password': 'Edgar@1234'},
#  {'user_id': 'AHJFXFGDAXEHIG2ZLUWVMZ3LWPBA',
#   'fname': 'Bailee',
#   'lname': 'Goodwin',
#   'phoneNo': '(892) 593-3819',
#   'email': 'Bailee.Goodwin@ecommerce.com',
#   'password': 'Bailee@1234'},
#  {'user_id': 'AEP4CW3UI7AJ7XM7PAAKVCB6U3ZA',
#   'fname': 'Madeline',
#   'lname': 'Zavala',
#   'phoneNo': '(780) 643-9574',
#   'email': 'Madeline.Zavala@ecommerce.com',
#   'password': 'Madeline@1234'},
#  {'user_id': 'AHIWCPCQ2Z4HWEM7V4HGTLVZQM6Q',
#   'fname': 'Bo',
#   'lname': 'Peck',
#   'phoneNo': '(710) 231-9651',
#   'email': 'Bo.Peck@ecommerce.com',
#   'password': 'Bo@1234'},
#  {'user_id': 'AHT4JDEYWRIQGCA2WAQJ6E2POHCQ',
#   'fname': 'Jazmin',
#   'lname': 'Black',
#   'phoneNo': '(447) 458-7796',
#   'email': 'Jazmin.Black@ecommerce.com',
#   'password': 'Jazmin@1234'},
#  {'user_id': 'AHEVOQADJSSRX7DS325HSFLMP7VQ',
#   'fname': 'Arthur',
#   'lname': 'Turner',
#   'phoneNo': '(798) 646-0853',
#   'email': 'Arthur.Turner@ecommerce.com',
#   'password': 'Arthur@1234'},
#  {'user_id': 'AG7XYZRCSKX6G2OLO7DVZWIZ3PUQ',
#   'fname': 'Makaila',
#   'lname': 'Carter',
#   'phoneNo': '(475) 827-6999',
#   'email': 'Makaila.Carter@ecommerce.com',
#   'password': 'Makaila@1234'},
#  {'user_id': 'AE2THTCCQLBIUSWPF4CPXC6GGP7Q',
#   'fname': 'Corbin',
#   'lname': 'Pope',
#   'phoneNo': '(367) 336-6497',
#   'email': 'Corbin.Pope@ecommerce.com',
#   'password': 'Corbin@1234'},
#  {'user_id': 'AHUJZOV34DFEN55QQ5XOYKVKHV6Q',
#   'fname': 'Urijah',
#   'lname': 'Love',
#   'phoneNo': '(771) 398-2611',
#   'email': 'Urijah.Love@ecommerce.com',
#   'password': 'Urijah@1234'},
#  {'user_id': 'AELX4DI77ZHURZTDLYFU7XMP7R6Q',
#   'fname': 'Alessandro',
#   'lname': 'Leonard',
#   'phoneNo': '(592) 585-0018',
#   'email': 'Alessandro.Leonard@ecommerce.com',
#   'password': 'Alessandro@1234'},
#  {'user_id': 'AE2ODWBBOBD2SITDDIEJ644OSRFQ',
#   'fname': 'Theodore',
#   'lname': 'Benton',
#   'phoneNo': '(404) 882-5481',
#   'email': 'Theodore.Benton@ecommerce.com',
#   'password': 'Theodore@1234'},
#  {'user_id': 'AFLW4WXYQ3G6HU5LBQORDDZO3FOQ',
#   'fname': 'Graham',
#   'lname': 'Brock',
#   'phoneNo': '(723) 964-2363',
#   'email': 'Graham.Brock@ecommerce.com',
#   'password': 'Graham@1234'},
#  {'user_id': 'AGGRC2P6M43GDEWCAHGYAILCSKTQ',
#   'fname': 'Donovan',
#   'lname': 'Maynard',
#   'phoneNo': '(698) 656-3548',
#   'email': 'Donovan.Maynard@ecommerce.com',
#   'password': 'Donovan@1234'},
#  {'user_id': 'AECPFYFQVRUWC3KGNLJIOREFP5LQ',
#   'fname': 'Kieran',
#   'lname': 'Herman',
#   'phoneNo': '(219) 440-0405',
#   'email': 'Kieran.Herman@ecommerce.com',
#   'password': 'Kieran@1234'},
#  {'user_id': 'AGYYVPDD7YG7FYNBXNGXZJT525AQ',
#   'fname': 'Tabitha',
#   'lname': 'Ferrell',
#   'phoneNo': '(522) 291-1976',
#   'email': 'Tabitha.Ferrell@ecommerce.com',
#   'password': 'Tabitha@1234'},
#  {'user_id': 'AHONIZU3ICIEHQIGQ6R2VFRSBXOQ',
#   'fname': 'Konnor',
#   'lname': 'Cohen',
#   'phoneNo': '(942) 308-7201',
#   'email': 'Konnor.Cohen@ecommerce.com',
#   'password': 'Konnor@1234'},
#  {'user_id': 'AFPHD2CRPDZMWMBL7WXRSVYWS5JA',
#   'fname': 'Ashlee',
#   'lname': 'Bass',
#   'phoneNo': '(618) 255-0801',
#   'email': 'Ashlee.Bass@ecommerce.com',
#   'password': 'Ashlee@1234'},
#  {'user_id': 'AEZ346GX3HJ4O4XNRPHCNHXQURMQ',
#   'fname': 'Aniyah',
#   'lname': 'Hudson',
#   'phoneNo': '(989) 911-8923',
#   'email': 'Aniyah.Hudson@ecommerce.com',
#   'password': 'Aniyah@1234'},
#  {'user_id': 'AEPSWFPNECKO34PUC7I56ITGXR6Q',
#   'fname': 'Tania',
#   'lname': 'Raymond',
#   'phoneNo': '(774) 850-5357',
#   'email': 'Tania.Raymond@ecommerce.com',
#   'password': 'Tania@1234'},
#  {'user_id': 'AHWVEHR5DYLVFTO2KF3IZATFQSWQ',
#   'fname': 'Noelle',
#   'lname': 'Oliver',
#   'phoneNo': '(229) 949-1011',
#   'email': 'Noelle.Oliver@ecommerce.com',
#   'password': 'Noelle@1234'},
#  {'user_id': 'AH4QT33M55677I7ISQOAKEQWACYQ',
#   'fname': 'Alberto',
#   'lname': 'Lynch',
#   'phoneNo': '(916) 644-9810',
#   'email': 'Alberto.Lynch@ecommerce.com',
#   'password': 'Alberto@1234'},
#  {'user_id': 'AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA',
#   'fname': 'Leonard',
#   'lname': 'Willis',
#   'phoneNo': '(223) 680-1674',
#   'email': 'Leonard.Willis@ecommerce.com',
#   'password': 'Leonard@1234'},
#  {'user_id': 'AE55KTFVNXYFD5FPYWP2OUPEYNPQ',
#   'fname': 'Maren',
#   'lname': 'Johnston',
#   'phoneNo': '(953) 522-9784',
#   'email': 'Maren.Johnston@ecommerce.com',
#   'password': 'Maren@1234'},
#  {'user_id': 'AEBWA5I4QFCA3P3OBEPMELBGN4GQ',
#   'fname': 'Areli',
#   'lname': 'Martinez',
#   'phoneNo': '(414) 971-8979',
#   'email': 'Areli.Martinez@ecommerce.com',
#   'password': 'Areli@1234'},
#  {'user_id': 'AHMGAC6QM62UXNEOCZIHLHSXPP2Q',
#   'fname': 'Kylie',
#   'lname': 'Ramsey',
#   'phoneNo': '(998) 407-1393',
#   'email': 'Kylie.Ramsey@ecommerce.com',
#   'password': 'Kylie@1234'},
#  {'user_id': 'AFHROSCGIXUPV3FYQ7H5QOD46Q7Q',
#   'fname': 'Bryanna',
#   'lname': 'Bauer',
#   'phoneNo': '(332) 904-4371',
#   'email': 'Bryanna.Bauer@ecommerce.com',
#   'password': 'Bryanna@1234'},
#  {'user_id': 'AEAMIR3CMSA32IDEINSJKHRNANTA',
#   'fname': 'Kaylah',
#   'lname': 'Bernard',
#   'phoneNo': '(687) 258-6364',
#   'email': 'Kaylah.Bernard@ecommerce.com',
#   'password': 'Kaylah@1234'},
#  {'user_id': 'AF355FTXYAKFH5NYPRTE7SL3WO3Q',
#   'fname': 'Heath',
#   'lname': 'Peters',
#   'phoneNo': '(613) 283-2668',
#   'email': 'Heath.Peters@ecommerce.com',
#   'password': 'Heath@1234'},
#  {'user_id': 'AG5DWPD54QGSLWJ6QUFERLPNAX4Q',
#   'fname': 'Brooke',
#   'lname': 'Barajas',
#   'phoneNo': '(694) 797-3590',
#   'email': 'Brooke.Barajas@ecommerce.com',
#   'password': 'Brooke@1234'},
#  {'user_id': 'AFSMISGEYDYIP3Z42UTQU4AKOYZQ',
#   'fname': 'Summer',
#   'lname': 'Galloway',
#   'phoneNo': '(742) 743-2400',
#   'email': 'Summer.Galloway@ecommerce.com',
#   'password': 'Summer@1234'},
#  {'user_id': 'AF5ILQY4KFDTO5XHHBJ42W5DXCZQ',
#   'fname': 'Abigayle',
#   'lname': 'Ellison',
#   'phoneNo': '(997) 710-1884',
#   'email': 'Abigayle.Ellison@ecommerce.com',
#   'password': 'Abigayle@1234'},
#  {'user_id': 'AFBK3X6D3AHEHSYYXPL4L6JEMSLQ',
#   'fname': 'Emerson',
#   'lname': 'Wheeler',
#   'phoneNo': '(769) 848-1040',
#   'email': 'Emerson.Wheeler@ecommerce.com',
#   'password': 'Emerson@1234'},
#  {'user_id': 'AFNB6YVNGE6IT3AWQVSIG2TJ5L3Q',
#   'fname': 'Kayden',
#   'lname': 'Atkinson',
#   'phoneNo': '(716) 928-2219',
#   'email': 'Kayden.Atkinson@ecommerce.com',
#   'password': 'Kayden@1234'},
#  {'user_id': 'AGGKMIGXUM3JRNVY7HZ3JHPJ7WTQ',
#   'fname': 'Cohen',
#   'lname': 'Woodward',
#   'phoneNo': '(704) 802-5995',
#   'email': 'Cohen.Woodward@ecommerce.com',
#   'password': 'Cohen@1234'},
#  {'user_id': 'AFMECPERM2GI2XQJSBWEPZKODISQ',
#   'fname': 'Addyson',
#   'lname': 'Ferrell',
#   'phoneNo': '(976) 806-0505',
#   'email': 'Addyson.Ferrell@ecommerce.com',
#   'password': 'Addyson@1234'},
#  {'user_id': 'AETPKXNOTUEX5GH7WL7XQHDR5M7Q',
#   'fname': 'Esperanza',
#   'lname': 'Pittman',
#   'phoneNo': '(500) 775-4843',
#   'email': 'Esperanza.Pittman@ecommerce.com',
#   'password': 'Esperanza@1234'},
#  {'user_id': 'AERFCJ6BOMVO5YW5XM5Z2ESOIK3A',
#   'fname': 'Angela',
#   'lname': 'James',
#   'phoneNo': '(598) 899-4057',
#   'email': 'Angela.James@ecommerce.com',
#   'password': 'Angela@1234'},
#  {'user_id': 'AGVUE2NFN2MQEOQ4PR525B2ZI5PQ',
#   'fname': 'Susan',
#   'lname': 'Zhang',
#   'phoneNo': '(984) 606-8795',
#   'email': 'Susan.Zhang@ecommerce.com',
#   'password': 'Susan@1234'},
#  {'user_id': 'AFO4M4BQ2WS7A3LPKJY45B5C7DYQ',
#   'fname': 'Omar',
#   'lname': 'Bernard',
#   'phoneNo': '(560) 781-9972',
#   'email': 'Omar.Bernard@ecommerce.com',
#   'password': 'Omar@1234'},
#  {'user_id': 'AG6CREU25N6P2H7RCHNIU6GGJ5BA',
#   'fname': 'Antonio',
#   'lname': 'Blackburn',
#   'phoneNo': '(982) 445-4234',
#   'email': 'Antonio.Blackburn@ecommerce.com',
#   'password': 'Antonio@1234'},
#  {'user_id': 'AHFITGJEF76CXALJZLYP6OIC4EOA',
#   'fname': 'Chaya',
#   'lname': 'Downs',
#   'phoneNo': '(330) 407-2712',
#   'email': 'Chaya.Downs@ecommerce.com',
#   'password': 'Chaya@1234'},
#  {'user_id': 'AG54MN24SX3EMMON4AMBUNL74K3Q',
#   'fname': 'Jayleen',
#   'lname': 'Mullen',
#   'phoneNo': '(456) 505-0502',
#   'email': 'Jayleen.Mullen@ecommerce.com',
#   'password': 'Jayleen@1234'},
#  {'user_id': 'AF3GETWWBGMLASY2KKNNBS2VO6DQ',
#   'fname': 'Zachary',
#   'lname': 'Frazier',
#   'phoneNo': '(966) 377-6492',
#   'email': 'Zachary.Frazier@ecommerce.com',
#   'password': 'Zachary@1234'},
#  {'user_id': 'AHEIPXMFMVWHNPLGUXUIV5XNP2SA',
#   'fname': 'Giovani',
#   'lname': 'Church',
#   'phoneNo': '(774) 850-5357',
#   'email': 'Giovani.Church@ecommerce.com',
#   'password': 'Giovani@1234'},
#  {'user_id': 'AFWQRBBVJWYTYUFQHUJE63S6VXJQ',
#   'fname': 'Alyson',
#   'lname': 'Carlson',
#   'phoneNo': '(450) 452-2642',
#   'email': 'Alyson.Carlson@ecommerce.com',
#   'password': 'Alyson@1234'},
#  {'user_id': 'AFA332YHUPB6I7KMME7SOFX5RKQQ',
#   'fname': 'Alma',
#   'lname': 'Bishop',
#   'phoneNo': '(877) 925-0669',
#   'email': 'Alma.Bishop@ecommerce.com',
#   'password': 'Alma@1234'},
#  {'user_id': 'AH3LHRL5P4YAVOQQCH72G2PJFXSA',
#   'fname': 'Kai',
#   'lname': 'Church',
#   'phoneNo': '(516) 465-9670',
#   'email': 'Kai.Church@ecommerce.com',
#   'password': 'Kai@1234'},
#  {'user_id': 'AGUUHLF34AIEIOE5KULXXVWKBCMA',
#   'fname': 'Gemma',
#   'lname': 'Anthony',
#   'phoneNo': '(834) 980-1795',
#   'email': 'Gemma.Anthony@ecommerce.com',
#   'password': 'Gemma@1234'},
#  {'user_id': 'AHWY6IG3PXBBJMLVFMHHKM25BVCQ',
#   'fname': 'Jazmine',
#   'lname': 'Bernard',
#   'phoneNo': '(341) 816-5468',
#   'email': 'Jazmine.Bernard@ecommerce.com',
#   'password': 'Jazmine@1234'},
#  {'user_id': 'AEOKB3ECJUM6UQOBFKMEMQVVHL4A',
#   'fname': 'Aden',
#   'lname': 'Lawson',
#   'phoneNo': '(307) 730-0622',
#   'email': 'Aden.Lawson@ecommerce.com',
#   'password': 'Aden@1234'},
#  {'user_id': 'AEYA6LQE25O2P6C7XV62XM3YV2EQ',
#   'fname': 'Edwin',
#   'lname': 'Dennis',
#   'phoneNo': '(583) 633-6287',
#   'email': 'Edwin.Dennis@ecommerce.com',
#   'password': 'Edwin@1234'},
#  {'user_id': 'AHMKSLALVS62JUHSHAI3FUXWDYYA',
#   'fname': 'Devan',
#   'lname': 'Miller',
#   'phoneNo': '(557) 433-4556',
#   'email': 'Devan.Miller@ecommerce.com',
#   'password': 'Devan@1234'},
#  {'user_id': 'AFZIZOK5KDBOB5QCHUQRR2ZWUYKA',
#   'fname': 'Cedric',
#   'lname': 'Pittman',
#   'phoneNo': '(399) 868-0147',
#   'email': 'Cedric.Pittman@ecommerce.com',
#   'password': 'Cedric@1234'},
#  {'user_id': 'AHMKXORT3VNMB75C3EUBYMFYELFQ',
#   'fname': 'Quinton',
#   'lname': 'Cox',
#   'phoneNo': '(656) 649-6607',
#   'email': 'Quinton.Cox@ecommerce.com',
#   'password': 'Quinton@1234'},
#  {'user_id': 'AEKJRELVNMICYPOYTKMVF52YX2WQ',
#   'fname': 'Calvin',
#   'lname': 'Avery',
#   'phoneNo': '(975) 770-8454',
#   'email': 'Calvin.Avery@ecommerce.com',
#   'password': 'Calvin@1234'},
#  {'user_id': 'AHQPBXZSJ3XZILPJVXE4BN7ZL26A',
#   'fname': 'Scott',
#   'lname': 'Roman',
#   'phoneNo': '(704) 556-5186',
#   'email': 'Scott.Roman@ecommerce.com',
#   'password': 'Scott@1234'},
#  {'user_id': 'AGELSEJKLWPVNPXQ7DGK63PEQF5A',
#   'fname': 'Silas',
#   'lname': 'Roth',
#   'phoneNo': '(843) 707-9229',
#   'email': 'Silas.Roth@ecommerce.com',
#   'password': 'Silas@1234'},
#  {'user_id': 'AGGBXJFPXZVOJMMB6MMQOPLCJWGA',
#   'fname': 'Kierra',
#   'lname': 'Leach',
#   'phoneNo': '(611) 906-9972',
#   'email': 'Kierra.Leach@ecommerce.com',
#   'password': 'Kierra@1234'},
#  {'user_id': 'AEWA5TH6PMRZXMFY5MHCIU2MNFHA',
#   'fname': 'Pedro',
#   'lname': 'Lynch',
#   'phoneNo': '(340) 494-1041',
#   'email': 'Pedro.Lynch@ecommerce.com',
#   'password': 'Pedro@1234'},
#  {'user_id': 'AHPDFQLNLMNV5X4QNH6J7IUMREAQ',
#   'fname': 'Deegan',
#   'lname': 'Howell',
#   'phoneNo': '(503) 214-3536',
#   'email': 'Deegan.Howell@ecommerce.com',
#   'password': 'Deegan@1234'},
#  {'user_id': 'AGKQKPUOEC3LQR7GHBQYAHPTU4SA',
#   'fname': 'Kolton',
#   'lname': 'Vazquez',
#   'phoneNo': '(632) 502-6571',
#   'email': 'Kolton.Vazquez@ecommerce.com',
#   'password': 'Kolton@1234'},
#  {'user_id': 'AF477BP57JM7Z4JD4PYB2K33R6AQ',
#   'fname': 'Shawn',
#   'lname': 'Sharp',
#   'phoneNo': '(575) 556-3007',
#   'email': 'Shawn.Sharp@ecommerce.com',
#   'password': 'Shawn@1234'},
#  {'user_id': 'AGTDD34Y77OB36JNYQWQDN7MHECQ',
#   'fname': 'Kara',
#   'lname': 'Atkinson',
#   'phoneNo': '(353) 770-5389',
#   'email': 'Kara.Atkinson@ecommerce.com',
#   'password': 'Kara@1234'},
#  {'user_id': 'AG7POKBSWQUO4VOYD4HDWYKMMJ4Q',
#   'fname': 'Denzel',
#   'lname': 'Zavala',
#   'phoneNo': '(355) 209-7524',
#   'email': 'Denzel.Zavala@ecommerce.com',
#   'password': 'Denzel@1234'},
#  {'user_id': 'AFZS6H2ZFJEJHRWIJ3IYL7V6KRPA',
#   'fname': 'Abraham',
#   'lname': 'Chan',
#   'phoneNo': '(502) 816-0503',
#   'email': 'Abraham.Chan@ecommerce.com',
#   'password': 'Abraham@1234'},
#  {'user_id': 'AHCYM2ECKI2MNOIDHDG4PT6IIN6A',
#   'fname': 'Jerimiah',
#   'lname': 'Wang',
#   'phoneNo': '(482) 455-5297',
#   'email': 'Jerimiah.Wang@ecommerce.com',
#   'password': 'Jerimiah@1234'},
#  {'user_id': 'AECZ4IP3TBM4EUG52BZAOQV3EKIA',
#   'fname': 'Nataly',
#   'lname': 'Cherry',
#   'phoneNo': '(865) 493-4421',
#   'email': 'Nataly.Cherry@ecommerce.com',
#   'password': 'Nataly@1234'},
#  {'user_id': 'AH6RQDXZYKAUPNBOYC4NAZERTFOQ',
#   'fname': 'Rylan',
#   'lname': 'Clayton',
#   'phoneNo': '(687) 258-6364',
#   'email': 'Rylan.Clayton@ecommerce.com',
#   'password': 'Rylan@1234'},
#  {'user_id': 'AFTVETL4HGH4KRUF4NXGJUEDPBAQ',
#   'fname': 'Matilda',
#   'lname': 'Ramsey',
#   'phoneNo': '(311) 545-4384',
#   'email': 'Matilda.Ramsey@ecommerce.com',
#   'password': 'Matilda@1234'},
#  {'user_id': 'AF2IRSQZKMBGX44YDNUPYRHWXOZQ',
#   'fname': 'Isis',
#   'lname': 'Holloway',
#   'phoneNo': '(586) 612-8576',
#   'email': 'Isis.Holloway@ecommerce.com',
#   'password': 'Isis@1234'},
#  {'user_id': 'AF6VSSXOI3Y4PZCNRJ3L27NCXPYA',
#   'fname': 'Fatima',
#   'lname': 'Dodson',
#   'phoneNo': '(928) 381-2339',
#   'email': 'Fatima.Dodson@ecommerce.com',
#   'password': 'Fatima@1234'},
#  {'user_id': 'AHQKC4MLLVOPBTKJFDBGTXFRKLYQ',
#   'fname': 'Humberto',
#   'lname': 'Macias',
#   'phoneNo': '(386) 866-6793',
#   'email': 'Humberto.Macias@ecommerce.com',
#   'password': 'Humberto@1234'},
#  {'user_id': 'AGX5ELLH3KJJ4CY2DJJOXDSOEI6Q',
#   'fname': 'Phoenix',
#   'lname': 'Hodges',
#   'phoneNo': '(431) 915-7064',
#   'email': 'Phoenix.Hodges@ecommerce.com',
#   'password': 'Phoenix@1234'},
#  {'user_id': 'AGJ23TWSY6YFMAVSEAOAUEWO4QLQ',
#   'fname': 'Keegan',
#   'lname': 'Macias',
#   'phoneNo': '(767) 814-2401',
#   'email': 'Keegan.Macias@ecommerce.com',
#   'password': 'Keegan@1234'},
#  {'user_id': 'AFOHB4M2RWSUQ3SSZWPMD2FPH6PQ',
#   'fname': 'Nathalia',
#   'lname': 'Reeves',
#   'phoneNo': '(437) 349-7856',
#   'email': 'Nathalia.Reeves@ecommerce.com',
#   'password': 'Nathalia@1234'},
#  {'user_id': 'AFVHKKOI25DAQSETPL7Z5W5SIVUA',
#   'fname': 'Jaylon',
#   'lname': 'Larsen',
#   'phoneNo': '(396) 680-9893',
#   'email': 'Jaylon.Larsen@ecommerce.com',
#   'password': 'Jaylon@1234'},
#  {'user_id': 'AE55WJERHR4C7SEAIWX4JJHFSZBA',
#   'fname': 'Harry',
#   'lname': 'Nixon',
#   'phoneNo': '(289) 373-0698',
#   'email': 'Harry.Nixon@ecommerce.com',
#   'password': 'Harry@1234'},
#  {'user_id': 'AGDOVGWZKEQ3M6DA2GHV6WUZT5SA',
#   'fname': 'Selena',
#   'lname': 'Mckay',
#   'phoneNo': '(307) 349-9845',
#   'email': 'Selena.Mckay@ecommerce.com',
#   'password': 'Selena@1234'},
#  {'user_id': 'AGEUXHN7U2Q26CM6TFOTW7GZXFXQ',
#   'fname': 'Brenden',
#   'lname': 'Frost',
#   'phoneNo': '(355) 209-7524',
#   'email': 'Brenden.Frost@ecommerce.com',
#   'password': 'Brenden@1234'},
#  {'user_id': 'AHYXZVXUY3QTBP7IBFIUBSZVH2XQ',
#   'fname': 'Reese',
#   'lname': 'Alvarez',
#   'phoneNo': '(576) 789-8221',
#   'email': 'Reese.Alvarez@ecommerce.com',
#   'password': 'Reese@1234'},
#  {'user_id': 'AGO4OKG6KVBAAE52Q62JBKHRDFFQ',
#   'fname': 'Quinton',
#   'lname': 'Benson',
#   'phoneNo': '(760) 789-3592',
#   'email': 'Quinton.Benson@ecommerce.com',
#   'password': 'Quinton@1234'},
#  {'user_id': 'AGOARJLTS744KQC3BTKT5KQVOJUA',
#   'fname': 'Ricky',
#   'lname': 'Barrett',
#   'phoneNo': '(487) 449-8194',
#   'email': 'Ricky.Barrett@ecommerce.com',
#   'password': 'Ricky@1234'},
#  {'user_id': 'AF6XISKAQXTX3Q5RUF2M2VKOJ66A',
#   'fname': 'Damaris',
#   'lname': 'Anthony',
#   'phoneNo': '(482) 384-6981',
#   'email': 'Damaris.Anthony@ecommerce.com',
#   'password': 'Damaris@1234'},
#  {'user_id': 'AEP6PYK2DLTD5UCMURSUNUE4IE5A',
#   'fname': 'Thaddeus',
#   'lname': 'Bishop',
#   'phoneNo': '(752) 467-8023',
#   'email': 'Thaddeus.Bishop@ecommerce.com',
#   'password': 'Thaddeus@1234'},
#  {'user_id': 'AHJSNMHQQWE6LMFRATH5LLJBQQXQ',
#   'fname': 'Zachariah',
#   'lname': 'Collier',
#   'phoneNo': '(806) 491-3251',
#   'email': 'Zachariah.Collier@ecommerce.com',
#   'password': 'Zachariah@1234'},
#  {'user_id': 'AEYHTCWWZYU3JQBU6SLNFFT3OMVQ',
#   'fname': 'Gianni',
#   'lname': 'Roth',
#   'phoneNo': '(532) 356-4160',
#   'email': 'Gianni.Roth@ecommerce.com',
#   'password': 'Gianni@1234'},
#  {'user_id': 'AENQPV63OVBZHJ7L7V37M2ADFY7Q',
#   'fname': 'Diana',
#   'lname': 'Ayala',
#   'phoneNo': '(443) 296-7908',
#   'email': 'Diana.Ayala@ecommerce.com',
#   'password': 'Diana@1234'},
#  {'user_id': 'AH7J7BCTWAMK2REWT4AMA2V5DPUQ',
#   'fname': 'Tyshawn',
#   'lname': 'Lutz',
#   'phoneNo': '(375) 666-6507',
#   'email': 'Tyshawn.Lutz@ecommerce.com',
#   'password': 'Tyshawn@1234'},
#  {'user_id': 'AFZSC27UUKDN5VYQVMAPYZNQTULA',
#   'fname': 'Marvin',
#   'lname': 'Galloway',
#   'phoneNo': '(648) 703-9050',
#   'email': 'Marvin.Galloway@ecommerce.com',
#   'password': 'Marvin@1234'},
#  {'user_id': 'AHM56NVJXROPTI5WICZITI4YAZAA',
#   'fname': 'Makhi',
#   'lname': 'Mccormick',
#   'phoneNo': '(292) 570-7174',
#   'email': 'Makhi.Mccormick@ecommerce.com',
#   'password': 'Makhi@1234'},
#  {'user_id': 'AEWZZXQWEU2QSVBCT7AJQ3FXMZWA',
#   'fname': 'Rigoberto',
#   'lname': 'Russo',
#   'phoneNo': '(216) 557-1206',
#   'email': 'Rigoberto.Russo@ecommerce.com',
#   'password': 'Rigoberto@1234'},
#  {'user_id': 'AFBLTBDVC23HRPXW2OQ2JDV3BNNQ',
#   'fname': 'Keyla',
#   'lname': 'Lam',
#   'phoneNo': '(504) 922-5863',
#   'email': 'Keyla.Lam@ecommerce.com',
#   'password': 'Keyla@1234'},
#  {'user_id': 'AGCX23QVQFBCYCAUWQNM4YHMKMQA',
#   'fname': 'Malaki',
#   'lname': 'Khan',
#   'phoneNo': '(990) 890-2535',
#   'email': 'Malaki.Khan@ecommerce.com',
#   'password': 'Malaki@1234'},
#  {'user_id': 'AHB43CZ4RHLJ5S6CBOWX6MEI7J4Q',
#   'fname': 'Ian',
#   'lname': 'Ferrell',
#   'phoneNo': '(510) 435-0672',
#   'email': 'Ian.Ferrell@ecommerce.com',
#   'password': 'Ian@1234'},
#  {'user_id': 'AHP24JLRZ2DTLBEX22A6DVUJDSBA',
#   'fname': 'Moriah',
#   'lname': 'Miranda',
#   'phoneNo': '(805) 302-3920',
#   'email': 'Moriah.Miranda@ecommerce.com',
#   'password': 'Moriah@1234'},
#  {'user_id': 'AGLKKKJCKHZ32S7MCK46JWDZ2A3A',
#   'fname': 'Casey',
#   'lname': 'Bradley',
#   'phoneNo': '(706) 483-2198',
#   'email': 'Casey.Bradley@ecommerce.com',
#   'password': 'Casey@1234'},
#  {'user_id': 'AHXCZCBKCKFAOJJ2GOCQS3OKPQOQ',
#   'fname': 'Emery',
#   'lname': 'Arnold',
#   'phoneNo': '(248) 379-7232',
#   'email': 'Emery.Arnold@ecommerce.com',
#   'password': 'Emery@1234'},
#  {'user_id': 'AHZ4UBDUCUMY6IGCR67LB4P5RBXA',
#   'fname': 'Yasmin',
#   'lname': 'Jenkins',
#   'phoneNo': '(204) 763-2444',
#   'email': 'Yasmin.Jenkins@ecommerce.com',
#   'password': 'Yasmin@1234'},
#  {'user_id': 'AHCGV72I3RKXOSSUNK3SQOB677NA',
#   'fname': 'Ava',
#   'lname': 'Odonnell',
#   'phoneNo': '(300) 247-8586',
#   'email': 'Ava.Odonnell@ecommerce.com',
#   'password': 'Ava@1234'},
#  {'user_id': 'AFTCOTLY72MCSV5WHMHSZ67ZZG6A',
#   'fname': 'Cristopher',
#   'lname': 'Hinton',
#   'phoneNo': '(208) 915-2747',
#   'email': 'Cristopher.Hinton@ecommerce.com',
#   'password': 'Cristopher@1234'},
#  {'user_id': 'AEF55HUCR2L3DMBXVV4SGD55JKIQ',
#   'fname': 'Giada',
#   'lname': 'Drake',
#   'phoneNo': '(290) 294-5736',
#   'email': 'Giada.Drake@ecommerce.com',
#   'password': 'Giada@1234'},
#  {'user_id': 'AGA2PZGWMQIRA46VYOTICFE7KCBA',
#   'fname': 'Rebekah',
#   'lname': 'Haynes',
#   'phoneNo': '(756) 866-1197',
#   'email': 'Rebekah.Haynes@ecommerce.com',
#   'password': 'Rebekah@1234'},
#  {'user_id': 'AHI2QJ4CLTCQWACDIC2LDFJPDAPA',
#   'fname': 'Zaiden',
#   'lname': 'Stuart',
#   'phoneNo': '(896) 404-1506',
#   'email': 'Zaiden.Stuart@ecommerce.com',
#   'password': 'Zaiden@1234'},
#  {'user_id': 'AEXAFY7V2ZRZI2GD2J6KDOWBZUBQ',
#   'fname': 'Bruno',
#   'lname': 'Hill',
#   'phoneNo': '(445) 477-7114',
#   'email': 'Bruno.Hill@ecommerce.com',
#   'password': 'Bruno@1234'},
#  {'user_id': 'AHAEBXTXQDY355AGFMFX3Z2VAAUQ',
#   'fname': 'Kendall',
#   'lname': 'Rowe',
#   'phoneNo': '(941) 635-7925',
#   'email': 'Kendall.Rowe@ecommerce.com',
#   'password': 'Kendall@1234'},
#  {'user_id': 'AETRIARSUFSMNG5LFJZMW6CBJMMQ',
#   'fname': 'Andy',
#   'lname': 'Medina',
#   'phoneNo': '(231) 578-4292',
#   'email': 'Andy.Medina@ecommerce.com',
#   'password': 'Andy@1234'},
#  {'user_id': 'AEHQQTEDMSXRGSBDDEIH3JF4AOMQ',
#   'fname': 'Aron',
#   'lname': 'Lozano',
#   'phoneNo': '(837) 350-1706',
#   'email': 'Aron.Lozano@ecommerce.com',
#   'password': 'Aron@1234'},
#  {'user_id': 'AGMG74N6WQGI376W7GEJJ4XD3ARQ',
#   'fname': 'Annie',
#   'lname': 'Sexton',
#   'phoneNo': '(851) 510-0489',
#   'email': 'Annie.Sexton@ecommerce.com',
#   'password': 'Annie@1234'},
#  {'user_id': 'AG7QMBEFFY2LJJKKEVWMJU2BMNRQ',
#   'fname': 'Lance',
#   'lname': 'Santana',
#   'phoneNo': '(982) 785-2786',
#   'email': 'Lance.Santana@ecommerce.com',
#   'password': 'Lance@1234'},
#  {'user_id': 'AHDFR3PDKEBV72HXRL3RJJLS3YYA',
#   'fname': 'Hudson',
#   'lname': 'Padilla',
#   'phoneNo': '(723) 740-3705',
#   'email': 'Hudson.Padilla@ecommerce.com',
#   'password': 'Hudson@1234'},
#  {'user_id': 'AHYUZ2BLKNN6UJLFYWCXCEFZTOVQ',
#   'fname': 'Aaliyah',
#   'lname': 'Dickson',
#   'phoneNo': '(285) 528-5097',
#   'email': 'Aaliyah.Dickson@ecommerce.com',
#   'password': 'Aaliyah@1234'},
#  {'user_id': 'AHBST4ZJ5665DV2TCR4W4J2OI3DA',
#   'fname': 'Hailee',
#   'lname': 'Ayala',
#   'phoneNo': '(962) 977-6195',
#   'email': 'Hailee.Ayala@ecommerce.com',
#   'password': 'Hailee@1234'},
#  {'user_id': 'AGHPOFCHZ73Q2Q2IFTCJLUSEL2NQ',
#   'fname': 'Kennedi',
#   'lname': 'Warren',
#   'phoneNo': '(849) 310-4825',
#   'email': 'Kennedi.Warren@ecommerce.com',
#   'password': 'Kennedi@1234'},
#  {'user_id': 'AHOMYGLSLJLCOT7Z24PZSVJY3LJQ',
#   'fname': 'Emmett',
#   'lname': 'Frazier',
#   'phoneNo': '(946) 788-2030',
#   'email': 'Emmett.Frazier@ecommerce.com',
#   'password': 'Emmett@1234'},
#  {'user_id': 'AESJE2EZD7S7WOYBN7RE7ZF3J2MA',
#   'fname': 'Skyla',
#   'lname': 'Hartman',
#   'phoneNo': '(821) 294-8397',
#   'email': 'Skyla.Hartman@ecommerce.com',
#   'password': 'Skyla@1234'},
#  {'user_id': 'AF23GXF525XSMXPJBEHP4SPKOZNQ',
#   'fname': 'Ayla',
#   'lname': 'Warner',
#   'phoneNo': '(735) 233-2299',
#   'email': 'Ayla.Warner@ecommerce.com',
#   'password': 'Ayla@1234'},
#  {'user_id': 'AFX5NHAAOUKKENAT6GWNKY3X5YTQ',
#   'fname': 'Rishi',
#   'lname': 'Jarvis',
#   'phoneNo': '(735) 690-4919',
#   'email': 'Rishi.Jarvis@ecommerce.com',
#   'password': 'Rishi@1234'},
#  {'user_id': 'AFWJSD4AVIM6DC3YA63G2QPENQSQ',
#   'fname': 'Zaiden',
#   'lname': 'Murray',
#   'phoneNo': '(939) 803-5897',
#   'email': 'Zaiden.Murray@ecommerce.com',
#   'password': 'Zaiden@1234'},
#  {'user_id': 'AGKSW3FNH3REYN3OKPKJN4KWXLMQ',
#   'fname': 'Zaid',
#   'lname': 'Haley',
#   'phoneNo': '(521) 590-3629',
#   'email': 'Zaid.Haley@ecommerce.com',
#   'password': 'Zaid@1234'},
#  {'user_id': 'AEI7HJU4RFV6NR5WSRDQV5ZSRYSA',
#   'fname': 'Eric',
#   'lname': 'Hodge',
#   'phoneNo': '(571) 310-8181',
#   'email': 'Eric.Hodge@ecommerce.com',
#   'password': 'Eric@1234'},
#  {'user_id': 'AGFN3SLEECW6DYL2CVGLIHJCVVHA',
#   'fname': 'Keaton',
#   'lname': 'Hutchinson',
#   'phoneNo': '(614) 315-0309',
#   'email': 'Keaton.Hutchinson@ecommerce.com',
#   'password': 'Keaton@1234'},
#  {'user_id': 'AGY7ZX7WDDSGAZJBPPS3MCIL7U7A',
#   'fname': 'Emilia',
#   'lname': 'Costa',
#   'phoneNo': '(628) 283-0805',
#   'email': 'Emilia.Costa@ecommerce.com',
#   'password': 'Emilia@1234'},
#  {'user_id': 'AEX422U2J6S45PAKDJIFJB7WNVLQ',
#   'fname': 'Zariah',
#   'lname': 'Ochoa',
#   'phoneNo': '(888) 533-1688',
#   'email': 'Zariah.Ochoa@ecommerce.com',
#   'password': 'Zariah@1234'},
#  {'user_id': 'AEHU6ETDR7HVQOGLKITDETHZEO7A',
#   'fname': 'Fatima',
#   'lname': 'Mosley',
#   'phoneNo': '(704) 556-5186',
#   'email': 'Fatima.Mosley@ecommerce.com',
#   'password': 'Fatima@1234'},
#  {'user_id': 'AE7VL5JTR7ZZ67UPBM6KP2NYEOYQ',
#   'fname': 'Kiley',
#   'lname': 'Ware',
#   'phoneNo': '(659) 520-2413',
#   'email': 'Kiley.Ware@ecommerce.com',
#   'password': 'Kiley@1234'},
#  {'user_id': 'AFIU4APGHOFMXEOVMSQMYKMZ46QQ',
#   'fname': 'Gustavo',
#   'lname': 'Hall',
#   'phoneNo': '(754) 871-0394',
#   'email': 'Gustavo.Hall@ecommerce.com',
#   'password': 'Gustavo@1234'},
#  {'user_id': 'AEOFYPCJJQYCKISUR6EC66IZH23Q',
#   'fname': 'Irvin',
#   'lname': 'Yang',
#   'phoneNo': '(767) 814-2401',
#   'email': 'Irvin.Yang@ecommerce.com',
#   'password': 'Irvin@1234'},
#  {'user_id': 'AFZSMXS2MILXOSTT2ZEJDE3W7TLQ',
#   'fname': 'Matias',
#   'lname': 'Barajas',
#   'phoneNo': '(382) 792-6993',
#   'email': 'Matias.Barajas@ecommerce.com',
#   'password': 'Matias@1234'},
#  {'user_id': 'AFREYXJZFUSZT7YHDJ4JOF67O6VQ',
#   'fname': 'Johnathon',
#   'lname': 'Munoz',
#   'phoneNo': '(268) 540-5457',
#   'email': 'Johnathon.Munoz@ecommerce.com',
#   'password': 'Johnathon@1234'},
#  {'user_id': 'AGMQDZGGSEBXX4KBJOBAGIFI36OA',
#   'fname': 'Carlee',
#   'lname': 'Giles',
#   'phoneNo': '(512) 355-1299',
#   'email': 'Carlee.Giles@ecommerce.com',
#   'password': 'Carlee@1234'},
#  {'user_id': 'AHJ7INNUX3KZSEZRJKFMRJAX7TZA',
#   'fname': 'Angela',
#   'lname': 'Cole',
#   'phoneNo': '(815) 496-3696',
#   'email': 'Angela.Cole@ecommerce.com',
#   'password': 'Angela@1234'},
#  {'user_id': 'AGYTCTSUZJJZTK2XVADTQI5MYUFQ',
#   'fname': 'Jewel',
#   'lname': 'Moore',
#   'phoneNo': '(890) 429-6163',
#   'email': 'Jewel.Moore@ecommerce.com',
#   'password': 'Jewel@1234'},
#  {'user_id': 'AFZHLQMILG47ZESR5TLNB5QK66HQ',
#   'fname': 'Killian',
#   'lname': 'Maddox',
#   'phoneNo': '(292) 292-5309',
#   'email': 'Killian.Maddox@ecommerce.com',
#   'password': 'Killian@1234'},
#  {'user_id': 'AEOM4KLP4SKKVSOCAMP7ORLGPGUA',
#   'fname': 'Blaze',
#   'lname': 'Ashley',
#   'phoneNo': '(929) 370-7846',
#   'email': 'Blaze.Ashley@ecommerce.com',
#   'password': 'Blaze@1234'},
#  {'user_id': 'AE4VKQV43AJEZDWE4WVJWFDY6RVA',
#   'fname': 'Ben',
#   'lname': 'Sanders',
#   'phoneNo': '(768) 671-5134',
#   'email': 'Ben.Sanders@ecommerce.com',
#   'password': 'Ben@1234'},
#  {'user_id': 'AGAUULKME2K6WYOHPLL5XT5XLQGA',
#   'fname': 'Dustin',
#   'lname': 'Mata',
#   'phoneNo': '(509) 711-5783',
#   'email': 'Dustin.Mata@ecommerce.com',
#   'password': 'Dustin@1234'},
#  {'user_id': 'AFP5TMKVX6PTNYNMLHFCVDXCTN4A',
#   'fname': 'Camilla',
#   'lname': 'Wilson',
#   'phoneNo': '(500) 775-4843',
#   'email': 'Camilla.Wilson@ecommerce.com',
#   'password': 'Camilla@1234'},
#  {'user_id': 'AGNYTWD4ORSSUWNGICU3TRNRMRIA',
#   'fname': 'Andre',
#   'lname': 'Johns',
#   'phoneNo': '(252) 414-9940',
#   'email': 'Andre.Johns@ecommerce.com',
#   'password': 'Andre@1234'},
#  {'user_id': 'AGQCT5HPQJXUN2FVZNCBSEQIYDPQ',
#   'fname': 'Kaitlyn',
#   'lname': 'Simmons',
#   'phoneNo': '(356) 851-4229',
#   'email': 'Kaitlyn.Simmons@ecommerce.com',
#   'password': 'Kaitlyn@1234'},
#  {'user_id': 'AHWMHRT7TOMXLYI3XYM4K4OY3NEQ',
#   'fname': 'Drew',
#   'lname': 'Riggs',
#   'phoneNo': '(595) 515-2899',
#   'email': 'Drew.Riggs@ecommerce.com',
#   'password': 'Drew@1234'},
#  {'user_id': 'AEXIFRBO4546MRMJHYKE2AH26VCQ',
#   'fname': 'Ariana',
#   'lname': 'Guzman',
#   'phoneNo': '(799) 378-7111',
#   'email': 'Ariana.Guzman@ecommerce.com',
#   'password': 'Ariana@1234'},
#  {'user_id': 'AGV3IEFANZCKECFGUM42MRH5FNOA',
#   'fname': 'Mira',
#   'lname': 'Osborne',
#   'phoneNo': '(848) 683-4678',
#   'email': 'Mira.Osborne@ecommerce.com',
#   'password': 'Mira@1234'},
#  {'user_id': 'AEBO7NWCNXKT4AESAN443HQH35FQ',
#   'fname': 'Emmalee',
#   'lname': 'Fletcher',
#   'phoneNo': '(972) 692-9149',
#   'email': 'Emmalee.Fletcher@ecommerce.com',
#   'password': 'Emmalee@1234'},
#  {'user_id': 'AE7GD3VRRYQEAHDR7FXJIR23INYA',
#   'fname': 'Callie',
#   'lname': 'Gibbs',
#   'phoneNo': '(602) 738-4483',
#   'email': 'Callie.Gibbs@ecommerce.com',
#   'password': 'Callie@1234'},
#  {'user_id': 'AHPAW24BI5X2GCX5M2LHI72VSJJQ',
#   'fname': 'Mara',
#   'lname': 'Marquez',
#   'phoneNo': '(307) 730-0622',
#   'email': 'Mara.Marquez@ecommerce.com',
#   'password': 'Mara@1234'},
#  {'user_id': 'AE2VXY4CFO36MDSIMPG43XHNF4GA',
#   'fname': 'Ernesto',
#   'lname': 'Rasmussen',
#   'phoneNo': '(938) 822-0050',
#   'email': 'Ernesto.Rasmussen@ecommerce.com',
#   'password': 'Ernesto@1234'},
#  {'user_id': 'AHHQEKUNVETALN7DTRHUQ2WAWEKQ',
#   'fname': 'Kasen',
#   'lname': 'Spence',
#   'phoneNo': '(485) 801-1044',
#   'email': 'Kasen.Spence@ecommerce.com',
#   'password': 'Kasen@1234'},
#  {'user_id': 'AFMIFTNTUD5PIHGONWOTRMMZ5EBA',
#   'fname': 'Kiana',
#   'lname': 'Ramos',
#   'phoneNo': '(368) 316-5912',
#   'email': 'Kiana.Ramos@ecommerce.com',
#   'password': 'Kiana@1234'},
#  {'user_id': 'AHOJBIZVVIIFJKRREY4B6ESVA4KA',
#   'fname': 'Clarissa',
#   'lname': 'Martinez',
#   'phoneNo': '(257) 431-8263',
#   'email': 'Clarissa.Martinez@ecommerce.com',
#   'password': 'Clarissa@1234'},
#  {'user_id': 'AFUT7ANZTZYGLXU65EQ2D5OP6UMA',
#   'fname': 'Zayne',
#   'lname': 'Luna',
#   'phoneNo': '(593) 933-5049',
#   'email': 'Zayne.Luna@ecommerce.com',
#   'password': 'Zayne@1234'},
#  {'user_id': 'AGT7YYJVUC6ZHRKQHVUQZMDNLXEA',
#   'fname': 'Emmett',
#   'lname': 'Contreras',
#   'phoneNo': '(413) 827-4668',
#   'email': 'Emmett.Contreras@ecommerce.com',
#   'password': 'Emmett@1234'},
#  {'user_id': 'AE7OMK3IQJR2U2JZE2HQ4BKSPA6A',
#   'fname': 'Carl',
#   'lname': 'Frazier',
#   'phoneNo': '(608) 865-6389',
#   'email': 'Carl.Frazier@ecommerce.com',
#   'password': 'Carl@1234'},
#  {'user_id': 'AGCRCU432TIF4J2EL7GBEWOIULGQ',
#   'fname': 'Evangeline',
#   'lname': 'Tapia',
#   'phoneNo': '(461) 901-0399',
#   'email': 'Evangeline.Tapia@ecommerce.com',
#   'password': 'Evangeline@1234'},
#  {'user_id': 'AERQBL3BISJQVHO3RLOOA4HKZX5A',
#   'fname': 'Mariela',
#   'lname': 'Harding',
#   'phoneNo': '(551) 683-4679',
#   'email': 'Mariela.Harding@ecommerce.com',
#   'password': 'Mariela@1234'},
#  {'user_id': 'AHIWNZ2HBQAHVE4OWODM6WH4PMOQ',
#   'fname': 'Tristin',
#   'lname': 'Yang',
#   'phoneNo': '(653) 856-2498',
#   'email': 'Tristin.Yang@ecommerce.com',
#   'password': 'Tristin@1234'},
#  {'user_id': 'AH2347WTE3DZ3TIZUB5LCLZPAYEQ',
#   'fname': 'Ellis',
#   'lname': 'Norton',
#   'phoneNo': '(643) 782-5424',
#   'email': 'Ellis.Norton@ecommerce.com',
#   'password': 'Ellis@1234'},
#  {'user_id': 'AHIH3QL5XONYJWEXF7VKLFHZBDJA',
#   'fname': 'Emilia',
#   'lname': 'Rush',
#   'phoneNo': '(458) 891-0367',
#   'email': 'Emilia.Rush@ecommerce.com',
#   'password': 'Emilia@1234'},
#  {'user_id': 'AHDIDVECFGA6OQRNUBPUO6366UGQ',
#   'fname': 'Mara',
#   'lname': 'Ritter',
#   'phoneNo': '(936) 228-1968',
#   'email': 'Mara.Ritter@ecommerce.com',
#   'password': 'Mara@1234'},
#  {'user_id': 'AFSII6HTAHTHGXERUNDOISNWZUNQ',
#   'fname': 'Kai',
#   'lname': 'Wise',
#   'phoneNo': '(608) 403-0188',
#   'email': 'Kai.Wise@ecommerce.com',
#   'password': 'Kai@1234'},
#  {'user_id': 'AF64ON4HPPVD43H6PK3CHPTTYSSQ',
#   'fname': 'Declan',
#   'lname': 'Gallagher',
#   'phoneNo': '(381) 894-2013',
#   'email': 'Declan.Gallagher@ecommerce.com',
#   'password': 'Declan@1234'},
#  {'user_id': 'AELNBR4H6235Y7NVYNCGNABDIDFQ',
#   'fname': 'Ashleigh',
#   'lname': 'Lyons',
#   'phoneNo': '(244) 540-1204',
#   'email': 'Ashleigh.Lyons@ecommerce.com',
#   'password': 'Ashleigh@1234'},
#  {'user_id': 'AF35OXRSRJ335IGMNW5FYCJDLHOA',
#   'fname': 'Kale',
#   'lname': 'Shepherd',
#   'phoneNo': '(248) 410-6176',
#   'email': 'Kale.Shepherd@ecommerce.com',
#   'password': 'Kale@1234'},
#  {'user_id': 'AE3CFONNMANNC5QPYIAXV67EUYUQ',
#   'fname': 'Jazmine',
#   'lname': 'Dunlap',
#   'phoneNo': '(482) 711-5484',
#   'email': 'Jazmine.Dunlap@ecommerce.com',
#   'password': 'Jazmine@1234'},
#  {'user_id': 'AHCWRQHRUAVMTMUH5NYNB3P4NWEA',
#   'fname': 'Landon',
#   'lname': 'Mullins',
#   'phoneNo': '(772) 691-4296',
#   'email': 'Landon.Mullins@ecommerce.com',
#   'password': 'Landon@1234'},
#  {'user_id': 'AGKZVBLHK472MSGAAUABFRZL7SYQ',
#   'fname': 'Jesus',
#   'lname': 'Moody',
#   'phoneNo': '(372) 606-5091',
#   'email': 'Jesus.Moody@ecommerce.com',
#   'password': 'Jesus@1234'},
#  {'user_id': 'AF42EMTPEJAL4LNEPPX77TN77UHA',
#   'fname': 'Andreas',
#   'lname': 'Mckay',
#   'phoneNo': '(223) 874-3412',
#   'email': 'Andreas.Mckay@ecommerce.com',
#   'password': 'Andreas@1234'},
#  {'user_id': 'AHBMZRY43T2GTYDVNFMUVASIBTPA',
#   'fname': 'Adan',
#   'lname': 'Andersen',
#   'phoneNo': '(611) 906-9972',
#   'email': 'Adan.Andersen@ecommerce.com',
#   'password': 'Adan@1234'},
#  {'user_id': 'AECCRE6ZTCPFGPVWDNY3IYYHCMOQ',
#   'fname': 'Chaim',
#   'lname': 'Edwards',
#   'phoneNo': '(583) 773-2341',
#   'email': 'Chaim.Edwards@ecommerce.com',
#   'password': 'Chaim@1234'},
#  {'user_id': 'AHOURK4XKLPPC4VHEDJ25NP64NPQ',
#   'fname': 'Deacon',
#   'lname': 'Liu',
#   'phoneNo': '(352) 284-6378',
#   'email': 'Deacon.Liu@ecommerce.com',
#   'password': 'Deacon@1234'},
#  {'user_id': 'AFC5K7RQQYKFB5PV47KAX2CHVIIQ',
#   'fname': 'Nayeli',
#   'lname': 'Simpson',
#   'phoneNo': '(315) 367-4306',
#   'email': 'Nayeli.Simpson@ecommerce.com',
#   'password': 'Nayeli@1234'},
#  {'user_id': 'AHEVOBT5PFXMIS5A7GAXRG52XARQ',
#   'fname': 'Coby',
#   'lname': 'Rich',
#   'phoneNo': '(749) 674-0231',
#   'email': 'Coby.Rich@ecommerce.com',
#   'password': 'Coby@1234'},
#  {'user_id': 'AHNOMOD65QU6QKFP3AMH5QPGQO6A',
#   'fname': 'Makhi',
#   'lname': 'Hardy',
#   'phoneNo': '(466) 438-9432',
#   'email': 'Makhi.Hardy@ecommerce.com',
#   'password': 'Makhi@1234'},
#  {'user_id': 'AGN2VH6RTYG5CM3YVH34VGYJFO4A',
#   'fname': 'Tania',
#   'lname': 'Mathews',
#   'phoneNo': '(378) 926-3688',
#   'email': 'Tania.Mathews@ecommerce.com',
#   'password': 'Tania@1234'},
#  {'user_id': 'AF6SKHWKK53BMAI6UVJA5FJMLK3A',
#   'fname': 'Audrey',
#   'lname': 'Suarez',
#   'phoneNo': '(922) 264-8563',
#   'email': 'Audrey.Suarez@ecommerce.com',
#   'password': 'Audrey@1234'},
#  {'user_id': 'AHIWSTMUSIYZAZQAMOLMPJHR7NMA',
#   'fname': 'Niko',
#   'lname': 'Austin',
#   'phoneNo': '(519) 940-8940',
#   'email': 'Niko.Austin@ecommerce.com',
#   'password': 'Niko@1234'},
#  {'user_id': 'AHYDC5KBSNP2LD5ZV5SXO3CQSCDQ',
#   'fname': 'Kendrick',
#   'lname': 'Tucker',
#   'phoneNo': '(646) 283-7574',
#   'email': 'Kendrick.Tucker@ecommerce.com',
#   'password': 'Kendrick@1234'},
#  {'user_id': 'AGACLGW4IBQOHLA6UJBIUNGVBRMQ',
#   'fname': 'Adalynn',
#   'lname': 'Thomas',
#   'phoneNo': '(867) 872-3231',
#   'email': 'Adalynn.Thomas@ecommerce.com',
#   'password': 'Adalynn@1234'},
#  {'user_id': 'AGFX4BFHOC6FXDFPD2O24RCD32NQ',
#   'fname': 'Charity',
#   'lname': 'Wilkinson',
#   'phoneNo': '(667) 753-7351',
#   'email': 'Charity.Wilkinson@ecommerce.com',
#   'password': 'Charity@1234'},
#  {'user_id': 'AGMXX5UGO3VXFAN2HOVYOWQYTRYA',
#   'fname': 'Gabriella',
#   'lname': 'Callahan',
#   'phoneNo': '(919) 402-0185',
#   'email': 'Gabriella.Callahan@ecommerce.com',
#   'password': 'Gabriella@1234'},
#  {'user_id': 'AGNGZAPY5HMB7OOQAXQ3MH5OLVSA',
#   'fname': 'Daphne',
#   'lname': 'Warren',
#   'phoneNo': '(474) 827-1115',
#   'email': 'Daphne.Warren@ecommerce.com',
#   'password': 'Daphne@1234'},
#  {'user_id': 'AHR4VQLVSWORK3A35U3QA6IOEEBA',
#   'fname': 'Omar',
#   'lname': 'Heath',
#   'phoneNo': '(327) 666-0358',
#   'email': 'Omar.Heath@ecommerce.com',
#   'password': 'Omar@1234'},
#  {'user_id': 'AFXQSBDW6232K22UMJWF5PMYX5RQ',
#   'fname': 'Bridger',
#   'lname': 'Maxwell',
#   'phoneNo': '(500) 775-4843',
#   'email': 'Bridger.Maxwell@ecommerce.com',
#   'password': 'Bridger@1234'},
#  {'user_id': 'AG4IENR3HNMEINBTJS3PET6VQY3Q',
#   'fname': 'Jaydon',
#   'lname': 'Solomon',
#   'phoneNo': '(249) 240-7527',
#   'email': 'Jaydon.Solomon@ecommerce.com',
#   'password': 'Jaydon@1234'},
#  {'user_id': 'AEYIYXI67FZ3H57OBTA2BGZBGTHQ',
#   'fname': 'Bryanna',
#   'lname': 'Kim',
#   'phoneNo': '(907) 783-7935',
#   'email': 'Bryanna.Kim@ecommerce.com',
#   'password': 'Bryanna@1234'},
#  {'user_id': 'AFUSP4NL7DIIS7CADTLDHGFLNOMQ',
#   'fname': 'Arthur',
#   'lname': 'Hatfield',
#   'phoneNo': '(805) 582-4263',
#   'email': 'Arthur.Hatfield@ecommerce.com',
#   'password': 'Arthur@1234'},
#  {'user_id': 'AEJG6XAZFMVQ7NRKCXG3ZCC3DIVA',
#   'fname': 'Landon',
#   'lname': 'Gould',
#   'phoneNo': '(746) 409-9539',
#   'email': 'Landon.Gould@ecommerce.com',
#   'password': 'Landon@1234'},
#  {'user_id': 'AFIS3N547NISE4TGX3YU6F4X2AGQ',
#   'fname': 'Tiffany',
#   'lname': 'Blake',
#   'phoneNo': '(326) 430-8751',
#   'email': 'Tiffany.Blake@ecommerce.com',
#   'password': 'Tiffany@1234'},
#  {'user_id': 'AGIJM2HE6GKI3I75OJ7PODHPP67Q',
#   'fname': 'Lucille',
#   'lname': 'Atkinson',
#   'phoneNo': '(333) 543-0304',
#   'email': 'Lucille.Atkinson@ecommerce.com',
#   'password': 'Lucille@1234'},
#  {'user_id': 'AGNXWXFWLOYZAYJ5PRIM2NB57E4A',
#   'fname': 'Nina',
#   'lname': 'Davila',
#   'phoneNo': '(431) 915-7064',
#   'email': 'Nina.Davila@ecommerce.com',
#   'password': 'Nina@1234'},
#  {'user_id': 'AGZU6C2XL3X2B4NEWLQJDSJ75QGA',
#   'fname': 'Aidyn',
#   'lname': 'Salas',
#   'phoneNo': '(813) 366-5060',
#   'email': 'Aidyn.Salas@ecommerce.com',
#   'password': 'Aidyn@1234'},
#  {'user_id': 'AHY62YAUHMMGFKSBGCECVGKXY2UQ',
#   'fname': 'Madeleine',
#   'lname': 'Pearson',
#   'phoneNo': '(507) 687-2232',
#   'email': 'Madeleine.Pearson@ecommerce.com',
#   'password': 'Madeleine@1234'},
#  {'user_id': 'AEMGDIDXCHHDMTAJHRNXBUWISFQQ',
#   'fname': 'Phoenix',
#   'lname': 'Martinez',
#   'phoneNo': '(362) 223-5093',
#   'email': 'Phoenix.Martinez@ecommerce.com',
#   'password': 'Phoenix@1234'},
#  {'user_id': 'AHQNYNRXESALGWMUFS6ITFGOVGMQ',
#   'fname': 'Audrey',
#   'lname': 'Hester',
#   'phoneNo': '(795) 725-5960',
#   'email': 'Audrey.Hester@ecommerce.com',
#   'password': 'Audrey@1234'},
#  {'user_id': 'AH7GOHZT6M5G6ELWPDTVZVKRZ7ZA',
#   'fname': 'Helen',
#   'lname': 'Peck',
#   'phoneNo': '(235) 390-6364',
#   'email': 'Helen.Peck@ecommerce.com',
#   'password': 'Helen@1234'},
#  {'user_id': 'AEHIRIOGHJKVTFYHFZVQ322CMZMA',
#   'fname': 'Jaliyah',
#   'lname': 'Roberson',
#   'phoneNo': '(418) 315-9231',
#   'email': 'Jaliyah.Roberson@ecommerce.com',
#   'password': 'Jaliyah@1234'},
#  {'user_id': 'AFUU5Q42TD7WLXRGKOBMRGUZWRFQ',
#   'fname': 'Kaylee',
#   'lname': 'Delgado',
#   'phoneNo': '(617) 888-2257',
#   'email': 'Kaylee.Delgado@ecommerce.com',
#   'password': 'Kaylee@1234'},
#  {'user_id': 'AFUV6WMMWSY6UM3P6ATQ6SME3H7A',
#   'fname': 'Ayaan',
#   'lname': 'Espinoza',
#   'phoneNo': '(719) 907-5273',
#   'email': 'Ayaan.Espinoza@ecommerce.com',
#   'password': 'Ayaan@1234'},
#  {'user_id': 'AEOIHOJD3O5MYSVWZOBDUJGYWZGQ',
#   'fname': 'Ignacio',
#   'lname': 'Cooper',
#   'phoneNo': '(848) 201-1544',
#   'email': 'Ignacio.Cooper@ecommerce.com',
#   'password': 'Ignacio@1234'},
#  {'user_id': 'AF6LAYTAGSTBKL2QUF3WFB6OMCPQ',
#   'fname': 'Jaylen',
#   'lname': 'Dillon',
#   'phoneNo': '(415) 474-6088',
#   'email': 'Jaylen.Dillon@ecommerce.com',
#   'password': 'Jaylen@1234'},
#  {'user_id': 'AHKXH7KSF7CPJCJMHB6B35VPTETA',
#   'fname': 'Helen',
#   'lname': 'Cuevas',
#   'phoneNo': '(382) 296-5465',
#   'email': 'Helen.Cuevas@ecommerce.com',
#   'password': 'Helen@1234'},
#  {'user_id': 'AFELQLNWTS4QJNCCA4ZDTWHVORJQ',
#   'fname': 'Justice',
#   'lname': 'Callahan',
#   'phoneNo': '(829) 455-6759',
#   'email': 'Justice.Callahan@ecommerce.com',
#   'password': 'Justice@1234'},
#  {'user_id': 'AGGE54AKRMX2XMQWQQTSUOPL7CHA',
#   'fname': 'Kylee',
#   'lname': 'Frye',
#   'phoneNo': '(869) 837-7304',
#   'email': 'Kylee.Frye@ecommerce.com',
#   'password': 'Kylee@1234'},
#  {'user_id': 'AG7ZAJNX4XZ5LTA4NLWBHTCX2V5A',
#   'fname': 'Amari',
#   'lname': 'Dillon',
#   'phoneNo': '(415) 867-6082',
#   'email': 'Amari.Dillon@ecommerce.com',
#   'password': 'Amari@1234'},
#  {'user_id': 'AGYSVNZMQT5LOVKHSCYDE7OAPKVA',
#   'fname': 'Milagros',
#   'lname': 'Walls',
#   'phoneNo': '(999) 976-6185',
#   'email': 'Milagros.Walls@ecommerce.com',
#   'password': 'Milagros@1234'},
#  {'user_id': 'AHAI6EM7F7W3GV3SUIDSKWTBJOSA',
#   'fname': 'Naima',
#   'lname': 'Dorsey',
#   'phoneNo': '(911) 945-7842',
#   'email': 'Naima.Dorsey@ecommerce.com',
#   'password': 'Naima@1234'},
#  {'user_id': 'AEGZSNGSJJAEMJ3RRNVZTKUILOHA',
#   'fname': 'Hillary',
#   'lname': 'Romero',
#   'phoneNo': '(361) 420-1776',
#   'email': 'Hillary.Romero@ecommerce.com',
#   'password': 'Hillary@1234'},
#  {'user_id': 'AGX46OTZ7C4VDXH4UA7ZAZIZUMYQ',
#   'fname': 'Corbin',
#   'lname': 'Schwartz',
#   'phoneNo': '(648) 703-9050',
#   'email': 'Corbin.Schwartz@ecommerce.com',
#   'password': 'Corbin@1234'},
#  {'user_id': 'AEDLLY6JXNCVYIW227SBCPVYHNUA',
#   'fname': 'Kaylee',
#   'lname': 'Baxter',
#   'phoneNo': '(723) 740-3705',
#   'email': 'Kaylee.Baxter@ecommerce.com',
#   'password': 'Kaylee@1234'},
#  {'user_id': 'AGTJ44UNO6K5X567YLQPYGN3TV4Q',
#   'fname': 'Aliya',
#   'lname': 'Golden',
#   'phoneNo': '(962) 294-5567',
#   'email': 'Aliya.Golden@ecommerce.com',
#   'password': 'Aliya@1234'},
#  {'user_id': 'AFYCBABBI2GCQRSCKIRHPLQNO72A',
#   'fname': 'Efrain',
#   'lname': 'Lutz',
#   'phoneNo': '(469) 975-3710',
# ...
#   'password': 'Braylon@1234'},
#  {'user_id': 'AGHLM2F6LPX3PYPF4W6YUX52R5OQ',
#   'fname': 'Augustus',
#   'lname': 'Stout',
#   'phoneNo': '(331) 226-2084',
#   'email': 'Augustus.Stout@ecommerce.com',
#   'password': 'Augustus@1234'},
#  {'user_id': 'AF7ZGA2MQVDGPQEW5EUSVLMFVHLQ',
#   'fname': 'Bernard',
#   'lname': 'Roberson',
#   'phoneNo': '(402) 999-9023',
#   'email': 'Bernard.Roberson@ecommerce.com',
#   'password': 'Bernard@1234'},
#  {'user_id': 'AGWAYDRCPJOSWY4HN36O4426WURQ',
#   'fname': 'Nico',
#   'lname': 'Blevins',
#   'phoneNo': '(269) 426-2291',
#   'email': 'Nico.Blevins@ecommerce.com',
#   'password': 'Nico@1234'},
#  {'user_id': 'AESC2XA7GTS3MWJPWIDTYCEI2IHQ',
#   'fname': 'Justice',
#   'lname': 'Rich',
#   'phoneNo': '(366) 905-3769',
#   'email': 'Justice.Rich@ecommerce.com',
#   'password': 'Justice@1234'},
#  {'user_id': 'AF6FFBO27Q2ZHS3XLEOUHWYQO54A',
#   'fname': 'Delilah',
#   'lname': 'Velasquez',
#   'phoneNo': '(256) 656-8263',
#   'email': 'Delilah.Velasquez@ecommerce.com',
#   'password': 'Delilah@1234'},
#  {'user_id': 'AEAGYWE74P5OI4Z3ORHAZICQDQRQ',
#   'fname': 'Conor',
#   'lname': 'Matthews',
#   'phoneNo': '(921) 499-0070',
#   'email': 'Conor.Matthews@ecommerce.com',
#   'password': 'Conor@1234'},
#  {'user_id': 'AEPRC35M4Z7QIXQHVEKTQFXGRF5A',
#   'fname': 'Sanaa',
#   'lname': 'Warren',
#   'phoneNo': '(805) 966-6011',
#   'email': 'Sanaa.Warren@ecommerce.com',
#   'password': 'Sanaa@1234'},
#  {'user_id': 'AFUZEMCPQIOHL22WG2RGLYM2K5RA',
#   'fname': 'Wyatt',
#   'lname': 'Richards',
#   'phoneNo': '(506) 737-3612',
#   'email': 'Wyatt.Richards@ecommerce.com',
#   'password': 'Wyatt@1234'},
#  {'user_id': 'AFNCOFWA5EFVOLGS76TME4OZIVVA',
#   'fname': 'Adalynn',
#   'lname': 'Rhodes',
#   'phoneNo': '(689) 932-9591',
#   'email': 'Adalynn.Rhodes@ecommerce.com',
#   'password': 'Adalynn@1234'},
#  {'user_id': 'AHBJBV6WJVE3MCI2KEVCYKVO5QDA',
#   'fname': 'Payton',
#   'lname': 'Gonzalez',
#   'phoneNo': '(259) 235-4640',
#   'email': 'Payton.Gonzalez@ecommerce.com',
#   'password': 'Payton@1234'},
#  {'user_id': 'AG5P7BKN4M3JH7HW64UV4Y2QZGHA',
#   'fname': 'Jensen',
#   'lname': 'Huynh',
#   'phoneNo': '(775) 251-4441',
#   'email': 'Jensen.Huynh@ecommerce.com',
#   'password': 'Jensen@1234'},
#  {'user_id': 'AHDAOL3TEKGCQABAYFZPBP2ZYFFA',
#   'fname': 'Jaqueline',
#   'lname': 'Moyer',
#   'phoneNo': '(432) 696-5613',
#   'email': 'Jaqueline.Moyer@ecommerce.com',
#   'password': 'Jaqueline@1234'},
#  {'user_id': 'AESBDPT5NJJQVWGWS3PL6R2QOCMA',
#   'fname': 'Iris',
#   'lname': 'Moon',
#   'phoneNo': '(904) 846-1992',
#   'email': 'Iris.Moon@ecommerce.com',
#   'password': 'Iris@1234'},
#  {'user_id': 'AHNB5VMFI3KABWXMDVQWOSYUTGFA',
#   'fname': 'Anahi',
#   'lname': 'Kent',
#   'phoneNo': '(274) 829-3478',
#   'email': 'Anahi.Kent@ecommerce.com',
#   'password': 'Anahi@1234'},
#  {'user_id': 'AHSRABDEXI6YGGABA5VV6JPKXISA',
#   'fname': 'Rene',
#   'lname': 'Wise',
#   'phoneNo': '(303) 956-0310',
#   'email': 'Rene.Wise@ecommerce.com',
#   'password': 'Rene@1234'},
#  {'user_id': 'AHLR63PRHYHZRWZST4RFYKDX7HBA',
#   'fname': 'Gabriel',
#   'lname': 'Guzman',
#   'phoneNo': '(620) 343-3055',
#   'email': 'Gabriel.Guzman@ecommerce.com',
#   'password': 'Gabriel@1234'},
#  {'user_id': 'AGPOF37T2T45CVYABSTSCPILMNZA',
#   'fname': 'Kaylynn',
#   'lname': 'Roy',
#   'phoneNo': '(466) 235-2001',
#   'email': 'Kaylynn.Roy@ecommerce.com',
#   'password': 'Kaylynn@1234'},
#  {'user_id': 'AFLXEGOLHUOVKYQTGGKQHW7ROJKQ',
#   'fname': 'Zechariah',
#   'lname': 'Luna',
#   'phoneNo': '(326) 430-8751',
#   'email': 'Zechariah.Luna@ecommerce.com',
#   'password': 'Zechariah@1234'},
#  {'user_id': 'AHVAHTQWBVQ564OYZLFO3ABDUUMQ',
#   'fname': 'Roy',
#   'lname': 'Khan',
#   'phoneNo': '(412) 874-6874',
#   'email': 'Roy.Khan@ecommerce.com',
#   'password': 'Roy@1234'},
#  {'user_id': 'AEL2DJG4RDMKBB4U7T7FB2D4QL6A',
#   'fname': 'Lena',
#   'lname': 'Carter',
#   'phoneNo': '(983) 411-6955',
#   'email': 'Lena.Carter@ecommerce.com',
#   'password': 'Lena@1234'},
#  {'user_id': 'AEZLG2GOZ4US63MFG3TTGRIOWQVQ',
#   'fname': 'Daphne',
#   'lname': 'Dalton',
#   'phoneNo': '(709) 699-3071',
#   'email': 'Daphne.Dalton@ecommerce.com',
#   'password': 'Daphne@1234'},
#  {'user_id': 'AH5FQ2OMFSPNFEWKR7XRHAQXYDNA',
#   'fname': 'Ayla',
#   'lname': 'Bryan',
#   'phoneNo': '(404) 448-3406',
#   'email': 'Ayla.Bryan@ecommerce.com',
#   'password': 'Ayla@1234'},
#  {'user_id': 'AHCWB47L2VDCBKURUGKDLNC3BLAA',
#   'fname': 'Autumn',
#   'lname': 'Norton',
#   'phoneNo': '(320) 937-2523',
#   'email': 'Autumn.Norton@ecommerce.com',
#   'password': 'Autumn@1234'},
#  {'user_id': 'AHSLVN2FXVPUVWTY5Y2GW5STS5ZA',
#   'fname': 'Andres',
#   'lname': 'Watson',
#   'phoneNo': '(583) 633-6287',
#   'email': 'Andres.Watson@ecommerce.com',
#   'password': 'Andres@1234'},
#  {'user_id': 'AEU3NDBYUVLPYDRFVCIY6IPVUA7A',
#   'fname': 'Alexandria',
#   'lname': 'Greene',
#   'phoneNo': '(627) 233-6056',
#   'email': 'Alexandria.Greene@ecommerce.com',
#   'password': 'Alexandria@1234'},
#  {'user_id': 'AFH4EKSLJGS4ZDREEEO5PLDGDWUA',
#   'fname': 'Ryan',
#   'lname': 'Carpenter',
#   'phoneNo': '(525) 947-3311',
#   'email': 'Ryan.Carpenter@ecommerce.com',
#   'password': 'Ryan@1234'},
#  {'user_id': 'AHQCV7O3JOMFFMD7EGIZ2NGSU6JQ',
#   'fname': 'Aimee',
#   'lname': 'Holder',
#   'phoneNo': '(746) 409-9539',
#   'email': 'Aimee.Holder@ecommerce.com',
#   'password': 'Aimee@1234'},
#  {'user_id': 'AGTB6FEDSOBJNAVZSDSY73YUVTXQ',
#   'fname': 'Steven',
#   'lname': 'Duarte',
#   'phoneNo': '(942) 787-4832',
#   'email': 'Steven.Duarte@ecommerce.com',
#   'password': 'Steven@1234'},
#  {'user_id': 'AFHULRP4IR7O4FQKWKI266O7VZQQ',
#   'fname': 'Reuben',
#   'lname': 'Dennis',
#   'phoneNo': '(266) 402-8649',
#   'email': 'Reuben.Dennis@ecommerce.com',
#   'password': 'Reuben@1234'},
#  {'user_id': 'AFKYLJ2CLPR7FIWD2MBXNIER7R3A',
#   'fname': 'Rayna',
#   'lname': 'Ortega',
#   'phoneNo': '(333) 543-0304',
#   'email': 'Rayna.Ortega@ecommerce.com',
#   'password': 'Rayna@1234'},
#  {'user_id': 'AFJRW562LETJUBBZYVI6VZA35WPQ',
#   'fname': 'Giovani',
#   'lname': 'Griffin',
#   'phoneNo': '(661) 401-2537',
#   'email': 'Giovani.Griffin@ecommerce.com',
#   'password': 'Giovani@1234'},
#  {'user_id': 'AEEMPL2VIRNJTYATMFPHFSHI4IOA',
#   'fname': 'Theodore',
#   'lname': 'Khan',
#   'phoneNo': '(221) 514-8353',
#   'email': 'Theodore.Khan@ecommerce.com',
#   'password': 'Theodore@1234'},
#  {'user_id': 'AGKQQC7ST26N5VFAHMURX3R2RAJA',
#   'fname': 'Mark',
#   'lname': 'Tucker',
#   'phoneNo': '(621) 258-4120',
#   'email': 'Mark.Tucker@ecommerce.com',
#   'password': 'Mark@1234'},
#  {'user_id': 'AFICI6GI5DCTRS6JVCYRPATIPXSQ',
#   'fname': 'Stephany',
#   'lname': 'Steele',
#   'phoneNo': '(532) 356-4160',
#   'email': 'Stephany.Steele@ecommerce.com',
#   'password': 'Stephany@1234'},
#  {'user_id': 'AEOHCZKNWRXT3H4Q66WMEMB672IA',
#   'fname': 'Javier',
#   'lname': 'Gaines',
#   'phoneNo': '(854) 464-6395',
#   'email': 'Javier.Gaines@ecommerce.com',
#   'password': 'Javier@1234'},
#  {'user_id': 'AGUSIMQLSTJXNHNX4OT5KEJZO2NQ',
#   'fname': 'Miracle',
#   'lname': 'Mcneil',
#   'phoneNo': '(611) 619-7054',
#   'email': 'Miracle.Mcneil@ecommerce.com',
#   'password': 'Miracle@1234'},
#  {'user_id': 'AFLVRNJ3FWTYVR2QR7LMMAXOR2VQ',
#   'fname': 'Moses',
#   'lname': 'Savage',
#   'phoneNo': '(757) 377-4416',
#   'email': 'Moses.Savage@ecommerce.com',
#   'password': 'Moses@1234'},
#  {'user_id': 'AGYNRF4LKWIYRL2EOCVDINQ62RAQ',
#   'fname': 'Chad',
#   'lname': 'Schwartz',
#   'phoneNo': '(250) 231-0252',
#   'email': 'Chad.Schwartz@ecommerce.com',
#   'password': 'Chad@1234'},
#  {'user_id': 'AHUGZ3YEQ27J3KSESPRFRAKNF3LA',
#   'fname': 'Madeleine',
#   'lname': 'Vaughan',
#   'phoneNo': '(614) 278-2630',
#   'email': 'Madeleine.Vaughan@ecommerce.com',
#   'password': 'Madeleine@1234'},
#  {'user_id': 'AGBP6M4EOJSBHZTYTH2T4BKNJ7MQ',
#   'fname': 'Katrina',
#   'lname': 'Livingston',
#   'phoneNo': '(249) 949-4800',
#   'email': 'Katrina.Livingston@ecommerce.com',
#   'password': 'Katrina@1234'},
#  {'user_id': 'AECZ7LYEACIXJTSOCFWLHVZLJPEA',
#   'fname': 'Weston',
#   'lname': 'Hunter',
#   'phoneNo': '(527) 757-6408',
#   'email': 'Weston.Hunter@ecommerce.com',
#   'password': 'Weston@1234'},
#  {'user_id': 'AHOHKZ6CPYXLBXPKLZCDT7HHD6CA',
#   'fname': 'Chelsea',
#   'lname': 'Norman',
#   'phoneNo': '(294) 689-5218',
#   'email': 'Chelsea.Norman@ecommerce.com',
#   'password': 'Chelsea@1234'},
#  {'user_id': 'AHILWO2P2PT6EKK2HS4EALRJIQ7Q',
#   'fname': 'Jocelyn',
#   'lname': 'Price',
#   'phoneNo': '(909) 528-6649',
#   'email': 'Jocelyn.Price@ecommerce.com',
#   'password': 'Jocelyn@1234'},
#  {'user_id': 'AGBF4IFXPQPS3KTL2RET4NAYKSZA',
#   'fname': 'Kathryn',
#   'lname': 'Woods',
#   'phoneNo': '(905) 538-9621',
#   'email': 'Kathryn.Woods@ecommerce.com',
#   'password': 'Kathryn@1234'},
#  {'user_id': 'AF3WE2A3BJW3ZK2XTUU7GTQ5P2IA',
#   'fname': 'Easton',
#   'lname': 'Watson',
#   'phoneNo': '(468) 252-9191',
#   'email': 'Easton.Watson@ecommerce.com',
#   'password': 'Easton@1234'},
#  {'user_id': 'AGWS7K3SXNU4RJUBPYYEVO76HULQ',
#   'fname': 'Graham',
#   'lname': 'Waller',
#   'phoneNo': '(874) 397-0762',
#   'email': 'Graham.Waller@ecommerce.com',
#   'password': 'Graham@1234'},
#  {'user_id': 'AGDSPVKPPJG2FSNEYACD45GIJ7WQ',
#   'fname': 'Darrell',
#   'lname': 'Carter',
#   'phoneNo': '(449) 216-7951',
#   'email': 'Darrell.Carter@ecommerce.com',
#   'password': 'Darrell@1234'},
#  {'user_id': 'AFSG7IWPY64B6DNMUDVXYCEK4G4A',
#   'fname': 'Aliyah',
#   'lname': 'Salas',
#   'phoneNo': '(305) 494-5537',
#   'email': 'Aliyah.Salas@ecommerce.com',
#   'password': 'Aliyah@1234'},
#  {'user_id': 'AGABMXBJYA3LSM5LIRNXL3HMHTLA',
#   'fname': 'Porter',
#   'lname': 'Franco',
#   'phoneNo': '(741) 324-0142',
#   'email': 'Porter.Franco@ecommerce.com',
#   'password': 'Porter@1234'},
#  {'user_id': 'AHBNWKWV73LMUFENL6T43ZEP2ASQ',
#   'fname': 'Justice',
#   'lname': 'Schmidt',
#   'phoneNo': '(490) 876-4840',
#   'email': 'Justice.Schmidt@ecommerce.com',
#   'password': 'Justice@1234'},
#  {'user_id': 'AHH74UTDYQPVBMM4HEEMRAU2DNMQ',
#   'fname': 'Kaylynn',
#   'lname': 'Short',
#   'phoneNo': '(725) 533-2838',
#   'email': 'Kaylynn.Short@ecommerce.com',
#   'password': 'Kaylynn@1234'},
#  {'user_id': 'AEZYVA7F52G2DCIUPCDUKGNHJ6LA',
#   'fname': 'Jaden',
#   'lname': 'Roberson',
#   'phoneNo': '(756) 866-1197',
#   'email': 'Jaden.Roberson@ecommerce.com',
#   'password': 'Jaden@1234'},
#  {'user_id': 'AEZTZPXHRSWDF5D35QHDQE7QJJCA',
#   'fname': 'Nina',
#   'lname': 'Fletcher',
#   'phoneNo': '(263) 313-8056',
#   'email': 'Nina.Fletcher@ecommerce.com',
#   'password': 'Nina@1234'},
#  {'user_id': 'AHR6VGN4EOF4UK4ZISINZJ4EFUTA',
#   'fname': 'Bailee',
#   'lname': 'Morris',
#   'phoneNo': '(246) 388-3897',
#   'email': 'Bailee.Morris@ecommerce.com',
#   'password': 'Bailee@1234'},
#  {'user_id': 'AEPLVJ2BAVC57LGFBTZCH2YBNJMQ',
#   'fname': 'Dylan',
#   'lname': 'Luna',
#   'phoneNo': '(272) 689-1446',
#   'email': 'Dylan.Luna@ecommerce.com',
#   'password': 'Dylan@1234'},
#  {'user_id': 'AE7BIR5NP6B6UA6DSJE23BBYJGHQ',
#   'fname': 'Melany',
#   'lname': 'Friedman',
#   'phoneNo': '(849) 310-4825',
#   'email': 'Melany.Friedman@ecommerce.com',
#   'password': 'Melany@1234'},
#  {'user_id': 'AHEJQ5MN7YJB4A3XTDSTTZID3WKQ',
#   'fname': 'Teagan',
#   'lname': 'Garner',
#   'phoneNo': '(315) 367-4306',
#   'email': 'Teagan.Garner@ecommerce.com',
#   'password': 'Teagan@1234'},
#  {'user_id': 'AEHR3J2Y6MUL5B3J5KJNJAH24JDQ',
#   'fname': 'Lindsey',
#   'lname': 'Cuevas',
#   'phoneNo': '(420) 429-3339',
#   'email': 'Lindsey.Cuevas@ecommerce.com',
#   'password': 'Lindsey@1234'},
#  {'user_id': 'AFKKM4SXCCLJDRUQUZ6J4W7HLDYQ',
#   'fname': 'Uriah',
#   'lname': 'Richmond',
#   'phoneNo': '(786) 621-3454',
#   'email': 'Uriah.Richmond@ecommerce.com',
#   'password': 'Uriah@1234'},
#  {'user_id': 'AHHPWPWUPOBG2CH3CD4GHCKZP3VA',
#   'fname': 'Kendrick',
#   'lname': 'Roth',
#   'phoneNo': '(936) 441-6441',
#   'email': 'Kendrick.Roth@ecommerce.com',
#   'password': 'Kendrick@1234'},
#  {'user_id': 'AGS3GOEZIOT6QABCS7GSKSRF6ZOA',
#   'fname': 'Giovanna',
#   'lname': 'Warren',
#   'phoneNo': '(282) 833-6599',
#   'email': 'Giovanna.Warren@ecommerce.com',
#   'password': 'Giovanna@1234'},
#  {'user_id': 'AE2NS3LUBQ33MFLYXAFBOTZOUO5Q',
#   'fname': 'Hugh',
#   'lname': 'Carroll',
#   'phoneNo': '(685) 212-4596',
#   'email': 'Hugh.Carroll@ecommerce.com',
#   'password': 'Hugh@1234'},
#  {'user_id': 'AFMTLEM5MPBZOB3YBELL32ZO7W6Q',
#   'fname': 'Moses',
#   'lname': 'Hickman',
#   'phoneNo': '(361) 420-1776',
#   'email': 'Moses.Hickman@ecommerce.com',
#   'password': 'Moses@1234'},
#  {'user_id': 'AFNCKSDO4JTIY2GAW4HZDSB5AXYQ',
#   'fname': 'Naima',
#   'lname': 'Duncan',
#   'phoneNo': '(761) 537-7321',
#   'email': 'Naima.Duncan@ecommerce.com',
#   'password': 'Naima@1234'},
#  {'user_id': 'AHB4PR4VAIZKTQDBHC5P3IQ2B72A',
#   'fname': 'Reed',
#   'lname': 'Hardy',
#   'phoneNo': '(438) 899-5205',
#   'email': 'Reed.Hardy@ecommerce.com',
#   'password': 'Reed@1234'},
#  {'user_id': 'AFTGBV2EOMQJUYBEV47YD4UEI24Q',
#   'fname': 'Kathryn',
#   'lname': 'Kim',
#   'phoneNo': '(371) 215-4345',
#   'email': 'Kathryn.Kim@ecommerce.com',
#   'password': 'Kathryn@1234'},
#  {'user_id': 'AFXA73X6367FW6C7AQNXOTR7BZ3A',
#   'fname': 'Josue',
#   'lname': 'Chase',
#   'phoneNo': '(608) 403-0188',
#   'email': 'Josue.Chase@ecommerce.com',
#   'password': 'Josue@1234'},
#  {'user_id': 'AF5B3NOBEX5PXWD4SBDB5KE7JP5A',
#   'fname': 'Adrian',
#   'lname': 'Alexander',
#   'phoneNo': '(987) 821-2441',
#   'email': 'Adrian.Alexander@ecommerce.com',
#   'password': 'Adrian@1234'},
#  {'user_id': 'AET2WYQTCLGU3TB7VHZHJYJ4HMWQ',
#   'fname': 'Christina',
#   'lname': 'Koch',
#   'phoneNo': '(307) 730-0622',
#   'email': 'Christina.Koch@ecommerce.com',
#   'password': 'Christina@1234'},
#  {'user_id': 'AF2LCFC5G6OATXBE73BMIXC5PNHA',
#   'fname': 'Jamal',
#   'lname': 'Hanna',
#   'phoneNo': '(525) 947-3311',
#   'email': 'Jamal.Hanna@ecommerce.com',
#   'password': 'Jamal@1234'},
#  {'user_id': 'AFJZOVZXLGXGULVMNOYLFI5TO4GQ',
#   'fname': 'Kylee',
#   'lname': 'Turner',
#   'phoneNo': '(874) 763-1461',
#   'email': 'Kylee.Turner@ecommerce.com',
#   'password': 'Kylee@1234'},
#  {'user_id': 'AEYQETW4Z4P4AT5KURWYCVXIV6QA',
#   'fname': 'Dustin',
#   'lname': 'Morrow',
#   'phoneNo': '(323) 792-5897',
#   'email': 'Dustin.Morrow@ecommerce.com',
#   'password': 'Dustin@1234'},
#  {'user_id': 'AH7AIXAIDIIIIZOPOOS4T3B7UI4A',
#   'fname': 'Nayeli',
#   'lname': 'Braun',
#   'phoneNo': '(418) 315-9231',
#   'email': 'Nayeli.Braun@ecommerce.com',
#   'password': 'Nayeli@1234'},
#  {'user_id': 'AF537NCMNYM56KBWSILNOUOEI5CA',
#   'fname': 'Rosemary',
#   'lname': 'Nash',
#   'phoneNo': '(265) 241-6060',
#   'email': 'Rosemary.Nash@ecommerce.com',
#   'password': 'Rosemary@1234'},
#  {'user_id': 'AH34W5DLRK5DLTLP73YKFLTTKWAQ',
#   'fname': 'Joseph',
#   'lname': 'Cooke',
#   'phoneNo': '(719) 849-3714',
#   'email': 'Joseph.Cooke@ecommerce.com',
#   'password': 'Joseph@1234'},
#  {'user_id': 'AE7KUNNQKS6JSHH7QVFPPRKCS4BQ',
#   'fname': 'Rylan',
#   'lname': 'Oliver',
#   'phoneNo': '(463) 998-9598',
#   'email': 'Rylan.Oliver@ecommerce.com',
#   'password': 'Rylan@1234'},
#  {'user_id': 'AEEWMW6LV5AVBCW6OTUO2TRYKY2A',
#   'fname': 'Abraham',
#   'lname': 'Sherman',
#   'phoneNo': '(924) 821-0596',
#   'email': 'Abraham.Sherman@ecommerce.com',
#   'password': 'Abraham@1234'},
#  {'user_id': 'AFYNKZR2T74OJU2LN2FKK7FM5BLQ',
#   'fname': 'Leanna',
#   'lname': 'Jarvis',
#   'phoneNo': '(665) 286-2415',
#   'email': 'Leanna.Jarvis@ecommerce.com',
#   'password': 'Leanna@1234'},
#  {'user_id': 'AEE3BW7DUIDZY367EH44OKNKDJDA',
#   'fname': 'Eliana',
#   'lname': 'Saunders',
#   'phoneNo': '(309) 716-7148',
#   'email': 'Eliana.Saunders@ecommerce.com',
#   'password': 'Eliana@1234'},
#  {'user_id': 'AEVZZKWDBY3YYS4AKWTRMY7ILF3Q',
#   'fname': 'Micaela',
#   'lname': 'Hogan',
#   'phoneNo': '(374) 529-7532',
#   'email': 'Micaela.Hogan@ecommerce.com',
#   'password': 'Micaela@1234'},
#  {'user_id': 'AFSFGSG745WPTJKCZ2FOAR2DMFCA',
#   'fname': 'Alvin',
#   'lname': 'Travis',
#   'phoneNo': '(881) 558-7314',
#   'email': 'Alvin.Travis@ecommerce.com',
#   'password': 'Alvin@1234'},
#  {'user_id': 'AHFYGVFMNT5FXKSBIHW7ANUJD22Q',
#   'fname': 'Deven',
#   'lname': 'Dalton',
#   'phoneNo': '(322) 464-3878',
#   'email': 'Deven.Dalton@ecommerce.com',
#   'password': 'Deven@1234'},
#  {'user_id': 'AESPOE5Z2FMNU577LDO7HKJCEDOA',
#   'fname': 'Jase',
#   'lname': 'Cuevas',
#   'phoneNo': '(333) 633-6062',
#   'email': 'Jase.Cuevas@ecommerce.com',
#   'password': 'Jase@1234'},
#  {'user_id': 'AGMOIJFKHOE7RTSMQPHKM5AO7EPQ',
#   'fname': 'Amanda',
#   'lname': 'Crane',
#   'phoneNo': '(405) 709-7802',
#   'email': 'Amanda.Crane@ecommerce.com',
#   'password': 'Amanda@1234'},
#  ...]
